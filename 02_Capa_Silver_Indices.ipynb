# %% [markdown]
# # Limpieza y enriquecimiento de índices bursátiles – Capa Silver

# %% [markdown]
# **Descripcion:**<br>
# Toma los archivos Parquet de la capa *Bronze* que contienen precios diarios históricos de los principales índices bursátiles de EE. UU. y construye un **panel diario completo** imputando fechas faltantes mediante *forward‑fill*, calculando rendimientos diarios y marcando la calidad de cada registro. El resultado se escribe como Parquet particionado por `ticker/year` en la capa *Silver* dentro de Azure Data Lake Storage Gen2.<br>
#
# **Objetivos**:<br>
# - Leer y consolidar todos los datos Bronze de índices.<br>
# - Construir un calendario uniforme (sin huecos) para cada índice.<br>
# - Imputar valores faltantes de precios y volumen mediante *forward‑fill*.<br>
# - Registrar la procedencia** de cada punto con la columna `data_quality_flag` ("source" vs "ffill").<br>
# - Calcular el rendimiento diario (`daily_return`)** con precisión de 6 decimales.<br>
# - Persistir en Parquet particionado** (`ticker` / `year`) en la capa Silver para lecturas eficientes.

# %% [markdown]
# ## 1. Configuración básica, librerías y Parámetros globales del pipeline

# %%
# ================================================================
# 1.1 Configuración básica y librerías
# ================================================================
import os, io, pandas as pd, datetime as dt
import numpy as np  # para vectorización de cálculos
from dotenv import load_dotenv  # lee variables de entorno locales
import adlfs                              # interfaz fsspec para ADLS

# Utilidades propias para subir archivos y obtener un cliente ADLS
from utils_adls import upload_bytes, _client, CONTAINER

# Carga credenciales (AZ_STORAGE_ACCOUNT, AZ_ACCOUNT_KEY, etc.)--
load_dotenv()
ACCOUNT  = os.getenv("AZ_STORAGE_ACCOUNT")
KEY      = os.getenv("AZ_ACCOUNT_KEY")

# Prefijos / rutas de trabajo -----------------------------------
BRONZE_PREFIX = "bronze/indices"
SILVER_PREFIX = "silver/indices_clean"
LOCAL_TMP     = "data/silver_tmp"; os.makedirs(LOCAL_TMP, exist_ok=True)

# Instancia del sistema de archivos ADLS vía fsspec ------------
fs = adlfs.AzureBlobFileSystem(account_name=ACCOUNT,
                               account_key=KEY,
                               use_ssl=True)

# %% [markdown]
# ## 2. Leer Capa Bronze, limpieza y muestreo de datos iniciales

# %%
# ================================================================
# 2.1 Leer Bronze
# ================================================================
# Carga parquet Bronze -------------------------------------------
#   • Localiza todos los Parquet de Bronze (particionados por year).
#   • Concatena en un único DataFrame ordenado por ticker + date.
# -----------------------------------------------------------------

CONTAINER = "market"                                # contenedor ADLS
BRONZE_PREFIX = f"{CONTAINER}/bronze/indices"       # prefijo completo

# Lista recursiva de archivos Year‑Partitioned
paths = fs.glob(f"{BRONZE_PREFIX}/*/year=*/*.parquet")

# Lectura perezosa (abre cada blob como archivo binario)
open_files = [fs.open(p, "rb") for p in paths]

# DataFrame consolidado
bronze_df = (
    pd.concat(pd.read_parquet(f) for f in open_files)
      .sort_values(["ticker", "date"])
)
bronze_df.tail(30)
# Out:
#           date         close          high           low          open  \
# 110 2025-06-12  60366.988281  60378.179688  59969.980469  60189.710938
# 111 2025-06-13  59645.230469  60366.988281  59511.320312  60366.988281
# 112 2025-06-16  60226.660156  60399.500000  59645.230469  59645.230469
# 113 2025-06-17  59723.570312  60226.660156  59661.531250  60226.660156
# 114 2025-06-18  59744.488281  60108.558594  59651.929688  59723.570312
# 115 2025-06-20  59614.179688  60116.371094  59457.750000  59744.488281
# 116 2025-06-23  60174.429688  60206.789062  59321.781250  59614.179688
# 117 2025-06-24  60870.570312  60964.851562  60174.429688  60174.429688
# 118 2025-06-25  60801.589844  61020.851562  60707.968750  60870.570312
# 119 2025-06-26  61334.011719  61380.960938  60801.589844  60801.589844
# 120 2025-06-27  61629.238281  61803.238281  61225.601562  61334.019531
# 121 2025-06-30  61940.589844  62036.398438  61629.238281  61629.238281
# 122 2025-07-01  61912.238281  62059.128906  61847.019531  61940.589844
# 123 2025-07-02  62255.648438  62257.738281  61827.371094  61912.238281
# 124 2025-07-03  62778.980469  62821.218750  62255.648438  62255.648438
# 125 2025-07-07  62264.601562  62778.980469  61973.441406  62778.980469
# 126 2025-07-08  62238.921875  62422.359375  62168.328125  62264.601562
# 127 2025-07-09  62633.140625  62668.820312  62238.921875  62238.921875
# 128 2025-07-10  62801.601562  62911.949219  62515.359375  62633.140625
# 129 2025-07-11  62540.230469  62801.601562  62366.171875  62801.601562
# 130 2025-07-14  62679.429688  62721.031250  62375.589844  62540.230469
# 131 2025-07-15  62339.199219  62979.308594  62324.730469  62679.429688
# 132 2025-07-16  62577.238281  62624.039062  61914.339844  62339.199219
# 133 2025-07-17  62956.121094  63033.390625  62570.191406  62577.238281
# 134 2025-07-18  62947.539062  63148.851562  62826.929688  62956.121094
# 135 2025-07-21  62981.320312  63327.730469  62947.539062  62947.539062
# 136 2025-07-22  63076.570312  63149.789062  62757.300781  62981.320312
# 137 2025-07-23  63586.968750  63594.929688  63076.570312  63076.570312
# 138 2025-07-24  63560.398438  63745.820312  63559.718750  63586.968750
# 139 2025-07-25  63834.250000  63898.480469  63560.398438  63560.398438
#
#      volume        ticker  year
# 110       0  WILSHIRE5000  2025
# 111       0  WILSHIRE5000  2025
# 112       0  WILSHIRE5000  2025
# 113       0  WILSHIRE5000  2025
# 114       0  WILSHIRE5000  2025
# 115       0  WILSHIRE5000  2025
# 116       0  WILSHIRE5000  2025
# 117       0  WILSHIRE5000  2025
# 118       0  WILSHIRE5000  2025
# 119       0  WILSHIRE5000  2025
# 120       0  WILSHIRE5000  2025
# 121       0  WILSHIRE5000  2025
# 122       0  WILSHIRE5000  2025
# 123       0  WILSHIRE5000  2025
# 124       0  WILSHIRE5000  2025
# 125       0  WILSHIRE5000  2025
# 126       0  WILSHIRE5000  2025
# 127       0  WILSHIRE5000  2025
# 128       0  WILSHIRE5000  2025
# 129       0  WILSHIRE5000  2025
# 130       0  WILSHIRE5000  2025
# 131       0  WILSHIRE5000  2025
# 132       0  WILSHIRE5000  2025
# 133       0  WILSHIRE5000  2025
# 134       0  WILSHIRE5000  2025
# 135       0  WILSHIRE5000  2025
# 136       0  WILSHIRE5000  2025
# 137       0  WILSHIRE5000  2025
# 138       0  WILSHIRE5000  2025
# 139       0  WILSHIRE5000  2025

# %%
# ================================================================
# 2.2 Limpieza y enriquecimiento de Bronze
# ================================================================
#   • Para cada ticker se construye el calendario diario completo.
#   • Se imputan valores con forward‑fill y se crea una bandera de calidad.
#   • Se calcula el retorno porcentual diario si existe la columna 'close'.
# ----------------------------------------------------------------

# Rango de fechas overall (desde el primer al último día disponible)
date_range = pd.date_range(
    bronze_df["date"].min(),
    bronze_df["date"].max(),
    freq="D"
)

panel_list = []  # almacenará cada panel de ticker limpio

for tk, grp in bronze_df.groupby("ticker"):
    # ---------------- sub‑bloque por ticker --------------------
    grp = grp.set_index("date").sort_index()

    # calendario completo
    filled = grp.reindex(date_range)

    # Identificar NAs originales (antes de imputación)
    orig_na = filled["close"].isna() if "close" in filled.columns else pd.Series(False, index=filled.index)

    # Forward‑fill de columnas numéricas
    want_numeric = ["open", "high", "low", "close", "adj_close", "volume"]
    numeric_cols = [c for c in want_numeric if c in filled.columns]
    filled[numeric_cols] = filled[numeric_cols].ffill()

    # Forward‑fill de metadatos (ingest_ts, source) para trazabilidad
    for c in ["ingest_ts", "source"]:
        if c in filled.columns:
            filled[c] = filled[c].ffill()

    # Flag de calidad: 'source' si el valor es real, 'ffill' si fue imputado
    filled["data_quality_flag"] = np.where(orig_na, "ffill", "source")

    # Cálculo de retorno diario (% change) si existe 'close'
    if "close" in filled.columns:
        filled["daily_return"] = filled["close"].pct_change().round(6)

    # Añade metadatos y acumula resultado
    filled = (
        filled.reset_index()
              .rename(columns={"index": "date"})
              .assign(ticker=tk,
                      year=lambda x: x["date"].dt.year)
    )
    panel_list.append(filled)


# DataFrame Silver final --------------------------------------
silver_df = (
    pd.concat(panel_list, ignore_index=True)
      .sort_values(["ticker", "date"])
)

silver_df.head()
# Out:
#         date        close         high          low         open      volume  \
# 0 1992-01-02  3172.399902  3172.629883  3139.310059  3152.100098  23550000.0
# 1 1992-01-03  3201.500000  3210.639893  3165.919922  3172.399902  23620000.0
# 2 1992-01-04  3201.500000  3210.639893  3165.919922  3172.399902  23620000.0
# 3 1992-01-05  3201.500000  3210.639893  3165.919922  3172.399902  23620000.0
# 4 1992-01-06  3200.100098  3213.330078  3191.860107  3201.500000  27280000.0
#
#   ticker  year data_quality_flag  daily_return
# 0   DJIA  1992            source           NaN
# 1   DJIA  1992            source      0.009173
# 2   DJIA  1992             ffill      0.000000
# 3   DJIA  1992             ffill      0.000000
# 4   DJIA  1992            source     -0.000437

# %% [markdown]
# ## 3. Escribir capa Silver (Local y Azure Data Lake Storage)

# %%
# ================================================================
# 3.1 Escribir Silver local + subir a ADLS
# ================================================================
#   • Parquet particionado `ticker/year`.
#   • Carga cada archivo al contenedor ADLS en la ruta Silver.
# ------------------------------------------------------------------------------

for (tk, yr), sub in silver_df.groupby(["ticker", "year"]):
    # Guarda archivo temporal local
    tmp_file = f"{LOCAL_TMP}/{tk}_{yr}.parquet"
    sub.to_parquet(tmp_file, index=False, engine="pyarrow")

    # Sube a ADLS (sobrescribe si existe)
    remote = f"{SILVER_PREFIX}/{tk}/year={yr}/{tk}_{yr}.parquet"
    with open(tmp_file, "rb") as f:
        upload_bytes(remote, f.read())       # overwrite=True
    print(f"▲ {remote}  ({len(sub)} filas)")
# Out:
# ▲ silver/indices_clean/DJIA/year=1992/DJIA_1992.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=1993/DJIA_1993.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=1994/DJIA_1994.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=1995/DJIA_1995.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=1996/DJIA_1996.parquet  (366 filas)
# ▲ silver/indices_clean/DJIA/year=1997/DJIA_1997.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=1998/DJIA_1998.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=1999/DJIA_1999.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2000/DJIA_2000.parquet  (366 filas)
# ▲ silver/indices_clean/DJIA/year=2001/DJIA_2001.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2002/DJIA_2002.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2003/DJIA_2003.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2004/DJIA_2004.parquet  (366 filas)
# ▲ silver/indices_clean/DJIA/year=2005/DJIA_2005.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2006/DJIA_2006.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2007/DJIA_2007.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2008/DJIA_2008.parquet  (366 filas)
# ▲ silver/indices_clean/DJIA/year=2009/DJIA_2009.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2010/DJIA_2010.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2011/DJIA_2011.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2012/DJIA_2012.parquet  (366 filas)
# ▲ silver/indices_clean/DJIA/year=2013/DJIA_2013.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2014/DJIA_2014.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2015/DJIA_2015.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2016/DJIA_2016.parquet  (366 filas)
# ▲ silver/indices_clean/DJIA/year=2017/DJIA_2017.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2018/DJIA_2018.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2019/DJIA_2019.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2020/DJIA_2020.parquet  (366 filas)
# ▲ silver/indices_clean/DJIA/year=2021/DJIA_2021.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2022/DJIA_2022.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2023/DJIA_2023.parquet  (365 filas)
# ▲ silver/indices_clean/DJIA/year=2024/DJIA_2024.parquet  (366 filas)
# ▲ silver/indices_clean/DJIA/year=2025/DJIA_2025.parquet  (206 filas)
# ▲ silver/indices_clean/NASDAQ/year=1992/NASDAQ_1992.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=1993/NASDAQ_1993.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=1994/NASDAQ_1994.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=1995/NASDAQ_1995.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=1996/NASDAQ_1996.parquet  (366 filas)
# ▲ silver/indices_clean/NASDAQ/year=1997/NASDAQ_1997.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=1998/NASDAQ_1998.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=1999/NASDAQ_1999.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2000/NASDAQ_2000.parquet  (366 filas)
# ▲ silver/indices_clean/NASDAQ/year=2001/NASDAQ_2001.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2002/NASDAQ_2002.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2003/NASDAQ_2003.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2004/NASDAQ_2004.parquet  (366 filas)
# ▲ silver/indices_clean/NASDAQ/year=2005/NASDAQ_2005.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2006/NASDAQ_2006.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2007/NASDAQ_2007.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2008/NASDAQ_2008.parquet  (366 filas)
# ▲ silver/indices_clean/NASDAQ/year=2009/NASDAQ_2009.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2010/NASDAQ_2010.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2011/NASDAQ_2011.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2012/NASDAQ_2012.parquet  (366 filas)
# ▲ silver/indices_clean/NASDAQ/year=2013/NASDAQ_2013.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2014/NASDAQ_2014.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2015/NASDAQ_2015.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2016/NASDAQ_2016.parquet  (366 filas)
# ▲ silver/indices_clean/NASDAQ/year=2017/NASDAQ_2017.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2018/NASDAQ_2018.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2019/NASDAQ_2019.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2020/NASDAQ_2020.parquet  (366 filas)
# ▲ silver/indices_clean/NASDAQ/year=2021/NASDAQ_2021.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2022/NASDAQ_2022.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2023/NASDAQ_2023.parquet  (365 filas)
# ▲ silver/indices_clean/NASDAQ/year=2024/NASDAQ_2024.parquet  (366 filas)
# ▲ silver/indices_clean/NASDAQ/year=2025/NASDAQ_2025.parquet  (206 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=1992/RUSSELL2000_1992.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=1993/RUSSELL2000_1993.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=1994/RUSSELL2000_1994.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=1995/RUSSELL2000_1995.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=1996/RUSSELL2000_1996.parquet  (366 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=1997/RUSSELL2000_1997.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=1998/RUSSELL2000_1998.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=1999/RUSSELL2000_1999.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2000/RUSSELL2000_2000.parquet  (366 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2001/RUSSELL2000_2001.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2002/RUSSELL2000_2002.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2003/RUSSELL2000_2003.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2004/RUSSELL2000_2004.parquet  (366 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2005/RUSSELL2000_2005.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2006/RUSSELL2000_2006.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2007/RUSSELL2000_2007.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2008/RUSSELL2000_2008.parquet  (366 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2009/RUSSELL2000_2009.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2010/RUSSELL2000_2010.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2011/RUSSELL2000_2011.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2012/RUSSELL2000_2012.parquet  (366 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2013/RUSSELL2000_2013.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2014/RUSSELL2000_2014.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2015/RUSSELL2000_2015.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2016/RUSSELL2000_2016.parquet  (366 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2017/RUSSELL2000_2017.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2018/RUSSELL2000_2018.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2019/RUSSELL2000_2019.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2020/RUSSELL2000_2020.parquet  (366 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2021/RUSSELL2000_2021.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2022/RUSSELL2000_2022.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2023/RUSSELL2000_2023.parquet  (365 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2024/RUSSELL2000_2024.parquet  (366 filas)
# ▲ silver/indices_clean/RUSSELL2000/year=2025/RUSSELL2000_2025.parquet  (206 filas)
# ▲ silver/indices_clean/SP500/year=1992/SP500_1992.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=1993/SP500_1993.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=1994/SP500_1994.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=1995/SP500_1995.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=1996/SP500_1996.parquet  (366 filas)
# ▲ silver/indices_clean/SP500/year=1997/SP500_1997.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=1998/SP500_1998.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=1999/SP500_1999.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2000/SP500_2000.parquet  (366 filas)
# ▲ silver/indices_clean/SP500/year=2001/SP500_2001.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2002/SP500_2002.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2003/SP500_2003.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2004/SP500_2004.parquet  (366 filas)
# ▲ silver/indices_clean/SP500/year=2005/SP500_2005.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2006/SP500_2006.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2007/SP500_2007.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2008/SP500_2008.parquet  (366 filas)
# ▲ silver/indices_clean/SP500/year=2009/SP500_2009.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2010/SP500_2010.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2011/SP500_2011.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2012/SP500_2012.parquet  (366 filas)
# ▲ silver/indices_clean/SP500/year=2013/SP500_2013.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2014/SP500_2014.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2015/SP500_2015.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2016/SP500_2016.parquet  (366 filas)
# ▲ silver/indices_clean/SP500/year=2017/SP500_2017.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2018/SP500_2018.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2019/SP500_2019.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2020/SP500_2020.parquet  (366 filas)
# ▲ silver/indices_clean/SP500/year=2021/SP500_2021.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2022/SP500_2022.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2023/SP500_2023.parquet  (365 filas)
# ▲ silver/indices_clean/SP500/year=2024/SP500_2024.parquet  (366 filas)
# ▲ silver/indices_clean/SP500/year=2025/SP500_2025.parquet  (206 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=1992/WILSHIRE5000_1992.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=1993/WILSHIRE5000_1993.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=1994/WILSHIRE5000_1994.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=1995/WILSHIRE5000_1995.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=1996/WILSHIRE5000_1996.parquet  (366 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=1997/WILSHIRE5000_1997.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=1998/WILSHIRE5000_1998.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=1999/WILSHIRE5000_1999.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2000/WILSHIRE5000_2000.parquet  (366 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2001/WILSHIRE5000_2001.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2002/WILSHIRE5000_2002.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2003/WILSHIRE5000_2003.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2004/WILSHIRE5000_2004.parquet  (366 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2005/WILSHIRE5000_2005.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2006/WILSHIRE5000_2006.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2007/WILSHIRE5000_2007.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2008/WILSHIRE5000_2008.parquet  (366 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2009/WILSHIRE5000_2009.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2010/WILSHIRE5000_2010.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2011/WILSHIRE5000_2011.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2012/WILSHIRE5000_2012.parquet  (366 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2013/WILSHIRE5000_2013.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2014/WILSHIRE5000_2014.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2015/WILSHIRE5000_2015.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2016/WILSHIRE5000_2016.parquet  (366 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2017/WILSHIRE5000_2017.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2018/WILSHIRE5000_2018.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2019/WILSHIRE5000_2019.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2020/WILSHIRE5000_2020.parquet  (366 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2021/WILSHIRE5000_2021.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2022/WILSHIRE5000_2022.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2023/WILSHIRE5000_2023.parquet  (365 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2024/WILSHIRE5000_2024.parquet  (366 filas)
# ▲ silver/indices_clean/WILSHIRE5000/year=2025/WILSHIRE5000_2025.parquet  (206 filas)

# %%
"""
**No funciona de momento***
# incremental Silver

Incremental Silver – índices bursátiles
Lee Bronze del año vigente, crea panel diario con forward-fill,
y sube a silver/indices_clean/… únicamente las fechas posteriores
a la última ya guardada en Silver.


import os, io, datetime as dt, pandas as pd, numpy as np
from dotenv import load_dotenv
import adlfs
from utils_adls import _client, upload_bytes, CONTAINER

# ─────────────────── 0. Config  ─────────────────────────────────────────
load_dotenv()
ACCOUNT   = os.getenv("AZ_STORAGE_ACCOUNT")
KEY       = os.getenv("AZ_ACCOUNT_KEY")

BRONZE_PREFIX = "market/bronze/indices"        # contenedor + carpeta
SILVER_PREFIX = "market/silver/indices_clean"  # destino Silver
LOCAL_TMP     = "data/silver_tmp"; os.makedirs(LOCAL_TMP, exist_ok=True)

fs  = adlfs.AzureBlobFileSystem(account_name=ACCOUNT, account_key=KEY)
svc = _client()

# ────────────────── 1. Leer Bronze (solo año actual) ────────────────────
year_now = dt.date.today().year
paths = fs.glob(f"{BRONZE_PREFIX}/*/year={year_now}/*.parquet")
if not paths:
    print("⚠️  No hay ficheros Bronze para el año actual"); exit()

open_files = [fs.open(p, "rb") for p in paths]
bronze_df  = pd.concat(pd.read_parquet(f) for f in open_files)

# ────────────────── 2. Construir silver_df (panel diario) ───────────────
date_range = pd.date_range(bronze_df["date"].min(),
                           bronze_df["date"].max(),
                           freq="D")

panel_list = []
for tk, grp in bronze_df.groupby("ticker"):
    grp = grp.set_index("date").sort_index()
    filled = grp.reindex(date_range)

    # ** forward-fill **
    want_num = ["open", "high", "low", "close", "adj_close", "volume"]
    num_cols = [c for c in want_num if c in filled.columns]
    orig_na  = filled["close"].isna() if "close" in filled.columns else pd.Series(False, index=filled.index)

    filled[num_cols] = filled[num_cols].ffill()
    for c in ["ingest_ts", "source"]:
        if c in filled.columns: filled[c] = filled[c].ffill()

    filled["data_quality_flag"] = np.where(orig_na, "ffill", "source")
    if "close" in filled.columns:
        filled["daily_return"] = filled["close"].pct_change().round(6)

    filled = (filled.reset_index()
                     .rename(columns={"index":"date"})
                     .assign(ticker=tk,
                             year=lambda x: x["date"].dt.year))
    panel_list.append(filled)

silver_df = (pd.concat(panel_list)
               .query("year == @year_now")      # aseguramos solo año actual
               .sort_values(["ticker","date"])
               .reset_index(drop=True))

# ────────────────── 3. Filtra solo filas nuevas ────────────────────────
def last_date_silver(ticker:str, year:int):
    file_path = f"{SILVER_PREFIX}/{ticker}/year={year}/{ticker}_{year}.parquet"
    full_path = f"{CONTAINER}/{file_path}"
    if not fs.exists(full_path):
        return None
    with fs.open(full_path, "rb") as f:
        return pd.read_parquet(f, columns=["date"])["date"].max().date()

uploads = 0
for (tk, yr), sub in silver_df.groupby(["ticker","year"]):
    last_dt = last_date_silver(tk, yr)
    if last_dt:
        sub = sub[sub["date"] > pd.to_datetime(last_dt)]
    if sub.empty:
        print(f"{tk} {yr}: sin novedades"); continue

    tmp = f"{LOCAL_TMP}/{tk}_{yr}.parquet"
    sub.to_parquet(tmp, index=False)

    remote = f"{SILVER_PREFIX}/{tk}/year={yr}/{tk}_{yr}.parquet"
    with open(tmp, "rb") as f:
        upload_bytes(remote, f.read())         # overwrite=True
    uploads += len(sub)
    print(f"▲ {tk} {yr}: +{len(sub)} filas cargadas")

print("✅ Incremental Silver terminado – filas nuevas:", uploads)
"""
# Out:
# '\n**No funciona de momento***\n# incremental Silver\n\nIncremental Silver – índices bursátiles\nLee Bronze del año vigente, crea panel diario con forward-fill,\ny sube a silver/indices_clean/… únicamente las fechas posteriores\na la última ya guardada en Silver.\n\n\nimport os, io, datetime as dt, pandas as pd, numpy as np\nfrom dotenv import load_dotenv\nimport adlfs\nfrom utils_adls import _client, upload_bytes, CONTAINER\n\n# ─────────────────── 0. Config  ─────────────────────────────────────────\nload_dotenv()\nACCOUNT   = os.getenv("AZ_STORAGE_ACCOUNT")\nKEY       = os.getenv("AZ_ACCOUNT_KEY")\n\nBRONZE_PREFIX = "market/bronze/indices"        # contenedor + carpeta\nSILVER_PREFIX = "market/silver/indices_clean"  # destino Silver\nLOCAL_TMP     = "data/silver_tmp"; os.makedirs(LOCAL_TMP, exist_ok=True)\n\nfs  = adlfs.AzureBlobFileSystem(account_name=ACCOUNT, account_key=KEY)\nsvc = _client()\n\n# ────────────────── 1. Leer Bronze (solo año actual) ────────────────────\nyear_now = dt.date.today().year\npaths = fs.glob(f"{BRONZE_PREFIX}/*/year={year_now}/*.parquet")\nif not paths:\n    print("⚠️  No hay ficheros Bronze para el año actual"); exit()\n\nopen_files = [fs.open(p, "rb") for p in paths]\nbronze_df  = pd.concat(pd.read_parquet(f) for f in open_files)\n\n# ────────────────── 2. Construir silver_df (panel diario) ───────────────\ndate_range = pd.date_range(bronze_df["date"].min(),\n                           bronze_df["date"].max(),\n                           freq="D")\n\npanel_list = []\nfor tk, grp in bronze_df.groupby("ticker"):\n    grp = grp.set_index("date").sort_index()\n    filled = grp.reindex(date_range)\n\n    # ** forward-fill **\n    want_num = ["open", "high", "low", "close", "adj_close", "volume"]\n    num_cols = [c for c in want_num if c in filled.columns]\n    orig_na  = filled["close"].isna() if "close" in filled.columns else pd.Series(False, index=filled.index)\n\n    filled[num_cols] = filled[num_cols].ffill()\n    for c in ["ingest_ts", "source"]:\n        if c in filled.columns: filled[c] = filled[c].ffill()\n\n    filled["data_quality_flag"] = np.where(orig_na, "ffill", "source")\n    if "close" in filled.columns:\n        filled["daily_return"] = filled["close"].pct_change().round(6)\n\n    filled = (filled.reset_index()\n                     .rename(columns={"index":"date"})\n                     .assign(ticker=tk,\n                             year=lambda x: x["date"].dt.year))\n    panel_list.append(filled)\n\nsilver_df = (pd.concat(panel_list)\n               .query("year == @year_now")      # aseguramos solo año actual\n               .sort_values(["ticker","date"])\n               .reset_index(drop=True))\n\n# ────────────────── 3. Filtra solo filas nuevas ────────────────────────\ndef last_date_silver(ticker:str, year:int):\n    file_path = f"{SILVER_PREFIX}/{ticker}/year={year}/{ticker}_{year}.parquet"\n    full_path = f"{CONTAINER}/{file_path}"\n    if not fs.exists(full_path):\n        return None\n    with fs.open(full_path, "rb") as f:\n        return pd.read_parquet(f, columns=["date"])["date"].max().date()\n\nuploads = 0\nfor (tk, yr), sub in silver_df.groupby(["ticker","year"]):\n    last_dt = last_date_silver(tk, yr)\n    if last_dt:\n        sub = sub[sub["date"] > pd.to_datetime(last_dt)]\n    if sub.empty:\n        print(f"{tk} {yr}: sin novedades"); continue\n\n    tmp = f"{LOCAL_TMP}/{tk}_{yr}.parquet"\n    sub.to_parquet(tmp, index=False)\n\n    remote = f"{SILVER_PREFIX}/{tk}/year={yr}/{tk}_{yr}.parquet"\n    with open(tmp, "rb") as f:\n        upload_bytes(remote, f.read())         # overwrite=True\n    uploads += len(sub)\n    print(f"▲ {tk} {yr}: +{len(sub)} filas cargadas")\n\nprint("✅ Incremental Silver terminado – filas nuevas:", uploads)\n'
