# %% [markdown]
# # Construcción de features financieros – Capa Gold

# %% [markdown]
# **Descripcion:**<br>
# Toma los precios diarios de índices bursátiles (capa *Silver/indices_clean*) y las series macroeconómicas limpias (*Silver/macros_clean*), los fusiona en un calendario maestro diario y genera un conjunto de **features técnicos** (lags, medias móviles, volatilidad, RSI‑14) junto con la variable objetivo de retorno a 5 días.  Los datos resultantes se almacenan particionados por año en la capa *Gold* del data‑lake para su uso directo en modelado ML o análisis avanzado.<br>
#
# **Objetivos**:<br>
# - Leer eficientemente los datos *Silver* de índices y macro desde ADLS.<br>
# - Construir un panel diario completo que combine precios y variables macro.<br>
# - Generar features técnicos estándar para cada índice (lag 1/5, SMA‑20/50, volatilidad 20‑días, RSI‑14).<br>
# - Calcular la variable objetivo (retorno a 5 días) para entrenamiento supervisado.<br>
# - Persistir la capa *Gold* en formato Parquet, particionada por `year=YYYY` y `ticker`, lista para consumo.<br>
# - Operar incrementalmente: si una partición existe se sobreescribe sólo si hay nuevas fechas.<br>

# %% [markdown]
# ## 1. Configuración básica, librerías y Parámetros globales del pipeline

# %%
# ================================================================
# 1.1 Configuración básica y librerías
# ================================================================
import os, io, datetime as dt, pandas as pd, numpy as np
from dotenv import load_dotenv
import adlfs    # fsspec‑ADLS
from utils_adls import upload_bytes, _client, CONTAINER   # helpers propios

# Variables de entorno (cuenta & clave de Azure) -----------------
load_dotenv()
ACCOUNT = os.getenv("AZ_STORAGE_ACCOUNT")
KEY = os.getenv("AZ_ACCOUNT_KEY")

# Prefijos internos al contenedor «market» (sin incluirlo en la ruta)
SILVER_IDX_PREFIX  = "silver/indices_clean"
SILVER_MAC_PREFIX  = "silver/macros_clean"
GOLD_PREFIX        = "gold/features"          # <ticker>/year=YYYY/…

LOCAL_TMP = "data/gold_tmp"; os.makedirs(LOCAL_TMP, exist_ok=True)

# fsspec filesystem y cliente ADLS -----------------------------
fs  = adlfs.AzureBlobFileSystem(account_name=ACCOUNT, account_key=KEY)
svc = _client()

# Lista explícita de índices a procesar -----------------------
tickers = ["SP500", "DJIA", "NASDAQ", "RUSSELL2000", "WILSHIRE5000"]
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## 2. Carga de datos Silver (Indices y variables Macroeconomicas)

# %%
# ================================================================
# 2.1 Carga Silver índices y macro
# ================================================================
# • Lee todos los Parquet Silver de índices y macro usando fsspec.
# • Crea tablas "wide" para CLOSE, retornos diarios y variables macro.
# ----------------------------------------------------------------

# Rutas absolutas dentro del contenedor (market/…) ---------------
paths_idx = fs.glob(f"{CONTAINER}/{SILVER_IDX_PREFIX}/*/year=*/*.parquet")
paths_mac = fs.glob(f"{CONTAINER}/{SILVER_MAC_PREFIX}/*/year=*/*.parquet")

# Carga y concatena ---------------------------------------------
idx_df = pd.concat(pd.read_parquet(fs.open(p, "rb")) for p in paths_idx)
mac_df = pd.concat(pd.read_parquet(fs.open(p, "rb")) for p in paths_mac)

# Índices en formato wide ---------------------------------------
close_wide = idx_df.pivot(index="date", columns="ticker", values="close").ffill()
ret_wide   = idx_df.pivot(index="date", columns="ticker", values="daily_return")

# Macros a wide (ffill ya aplicado en Silver) -------------------
macro_wide = mac_df.pivot(index="date", columns="series", values="value").ffill().bfill()

# Calendario maestro --------------------------------------------
date_range = pd.date_range(close_wide.index.min(), close_wide.index.max(), freq="D")
base = pd.DataFrame(index=date_range).join(macro_wide, how="left")

# %%
macro_wide.head()
# Out:
# series        ANFCI  BAA10Y  BAMLH0A0HYM2  CPIAUCSL  DCOILWTICO  DFII10  \
# date
# 1992-01-01 -0.79596    2.33          3.13     138.3       19.43    2.43
# 1992-01-02 -0.79596    2.33          3.13     138.3       19.43    2.43
# 1992-01-03 -0.79596    2.26          3.13     138.3       19.22    2.43
# 1992-01-04 -0.79596    2.26          3.13     138.3       19.22    2.43
# 1992-01-05 -0.79596    2.26          3.13     138.3       19.22    2.43
#
# series      DGS10  DGS2  DTWEXBGS  FEDFUNDS       GDP   HOUST      ICSA  \
# date
# 1992-01-01   6.78  4.77  101.4155      4.03  6363.102  1176.0  432000.0
# 1992-01-02   6.78  4.77  101.4155      4.03  6363.102  1176.0  432000.0
# 1992-01-03   6.85  4.80  101.4155      4.03  6363.102  1176.0  432000.0
# 1992-01-04   6.85  4.80  101.4155      4.03  6363.102  1176.0  432000.0
# 1992-01-05   6.85  4.80  101.4155      4.03  6363.102  1176.0  432000.0
#
# series       INDPRO    M2SL     NFCI    PAYEMS  PERMIT  STLFSI2  T10Y2Y  \
# date
# 1992-01-01  61.4823  3381.2 -0.67185  108365.0  1077.0  -0.3803    2.01
# 1992-01-02  61.4823  3381.2 -0.67185  108365.0  1077.0  -0.3803    2.01
# 1992-01-03  61.4823  3381.2 -0.67185  108365.0  1077.0  -0.3803    2.05
# 1992-01-04  61.4823  3381.2 -0.67185  108365.0  1077.0  -0.3803    2.05
# 1992-01-05  61.4823  3381.2 -0.67185  108365.0  1077.0  -0.3803    2.05
#
# series      T10Y3M  T5YIE  TEDRATE  THREEFYTP10  UMCSENT  UNRATE  VIXCLS  \
# date
# 1992-01-01    2.82    1.3     0.33       2.0654     67.5     7.3   18.95
# 1992-01-02    2.82    1.3     0.33       2.0654     67.5     7.3   18.95
# 1992-01-03    2.90    1.3     0.34       2.1013     67.5     7.3   18.75
# 1992-01-04    2.90    1.3     0.34       2.1013     67.5     7.3   18.75
# 1992-01-05    2.90    1.3     0.34       2.1013     67.5     7.3   18.75
#
# series         WALCL
# date
# 1992-01-01  719542.0
# 1992-01-02  719542.0
# 1992-01-03  719542.0
# 1992-01-04  719542.0
# 1992-01-05  719542.0

# %%
display(mac_df.tail(25))
# Out:
#           date      value series  year                         ingest_ts  \
# 184 2025-07-04  6659598.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 185 2025-07-05  6659598.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 186 2025-07-06  6659598.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 187 2025-07-07  6659598.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 188 2025-07-08  6659598.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 189 2025-07-09  6661912.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 190 2025-07-10  6661912.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 191 2025-07-11  6661912.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 192 2025-07-12  6661912.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 193 2025-07-13  6661912.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 194 2025-07-14  6661912.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 195 2025-07-15  6661912.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 196 2025-07-16  6659273.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 197 2025-07-17  6659273.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 198 2025-07-18  6659273.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 199 2025-07-19  6659273.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 200 2025-07-20  6659273.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 201 2025-07-21  6659273.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 202 2025-07-22  6659273.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 203 2025-07-23  6657715.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 204 2025-07-24  6657715.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 205 2025-07-25  6657715.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 206 2025-07-26  6657715.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 207 2025-07-27  6657715.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
# 208 2025-07-28  6657715.0  WALCL  2025  2025-07-28T06:57:06.165976+00:00
#
#     source data_quality_flag
# 184   FRED             ffill
# 185   FRED             ffill
# 186   FRED             ffill
# 187   FRED             ffill
# 188   FRED             ffill
# 189   FRED            source
# 190   FRED             ffill
# 191   FRED             ffill
# 192   FRED             ffill
# 193   FRED             ffill
# 194   FRED             ffill
# 195   FRED             ffill
# 196   FRED            source
# 197   FRED             ffill
# 198   FRED             ffill
# 199   FRED             ffill
# 200   FRED             ffill
# 201   FRED             ffill
# 202   FRED             ffill
# 203   FRED            source
# 204   FRED             ffill
# 205   FRED             ffill
# 206   FRED             ffill
# 207   FRED             ffill
# 208   FRED             ffill

# %% [markdown]
# ## 3. Funciones de features técnicos

# %%
# ================================================================
# 3.1 Funciones de features técnicos
# ================================================================
# add_tech_features: dado un DataFrame y una columna de precios agrega:
#   • Lags (1 y 5 días)
#   • Medias móviles (20 y 50)
#   • Volatilidad (desv. estándar de log‑returns 20‑d)
#   • RSI‑14
# Devuelve el DataFrame enriquecido (in‑place).
# ---------------------------------------------------------------

def add_tech_features(df: pd.DataFrame, price_col: str, prefix: str):
    p = df[price_col]
    lr = np.log(p / p.shift(1))

    df[f"{prefix}_lag1"]   = p.shift(1)
    df[f"{prefix}_lag5"]   = p.shift(5)
    df[f"{prefix}_sma20"]  = p.rolling(20).mean()
    df[f"{prefix}_sma50"]  = p.rolling(50).mean()
    df[f"{prefix}_vol20"]  = lr.rolling(20).std()

    # ► RSI‑14 --------------------------------------------------
    delta = p.diff()
    gain  = delta.clip(lower=0).rolling(14).mean()
    loss  = (-delta.clip(upper=0)).rolling(14).mean()
    rs    = gain / loss
    df[f"{prefix}_rsi14"] = 100 - (100 / (1 + rs))

    # ► Bandas de Bollinger -------------------------------------
    rolling_std = p.rolling(20).std()
    df[f"{prefix}_std20"] = rolling_std
    df[f"{prefix}_bollinger_upper"] = df[f"{prefix}_sma20"] + 2 * rolling_std
    df[f"{prefix}_bollinger_lower"] = df[f"{prefix}_sma20"] - 2 * rolling_std
    
    return df

# %%
# ================================================================
# 3.2 Generación y persistencia de features en la capa Gold
# ================================================================
# Para cada índice:
#   - Copia el calendario maestro + variables macro.
#   - Añade la serie de precios y retornos del índice.
#   - Crea features técnicos y la variable target (retorno a 5 días).
#   - Escribe Parquet particionado por año en la capa Gold y sube al lake.
# ----------------------------------------------------------------

for tk in tickers:
    print(f"▶ Procesando {tk} …")

    # --- ensamblar panel ticker + macro -------------------------
    df = base.copy()
    df[tk]       = close_wide[tk]
    df[f"{tk}_ret"] = ret_wide[tk]

    # Añadir features técnicos ----------------------------------
    df = add_tech_features(df, price_col=tk, prefix=tk.lower())

    # Variables objetivo: retorno futuro a 5, 20 y 180 días ------
    for h in [5, 20, 180]:
        df[f"y_{tk.lower()}_ret_{h}d"] = df[tk].shift(-h) / df[tk] - 1

    # Filtra filas con dato real (precio existe) ----------------
    df = df[df[tk].notna()].copy()
    df["year"] = df.index.year

     # Formato tidy ---------------------------------------------
    df.reset_index(inplace=True); df.rename(columns={"index":"date"}, inplace=True)

    # --- persistencia por partición año ------------------------
    for yr, part in df.groupby("year"):
        tmp = f"{LOCAL_TMP}/{tk}_{yr}.parquet"
        part.to_parquet(tmp, index=False, engine="pyarrow")

        remote = f"{GOLD_PREFIX}/{tk}/year={yr}/{tk}_{yr}.parquet"
        with open(tmp, "rb") as f:
            upload_bytes(remote, f.read())  # overwrite=True para idempotencia
        print(f"   ▲ {tk} {yr} -> {remote}  ({len(part)} filas)")

print("✅ Gold por índice creado")
# Out:
# ▶ Procesando SP500 …
#    ▲ SP500 1992 -> gold/features/SP500/year=1992/SP500_1992.parquet  (365 filas)
#    ▲ SP500 1993 -> gold/features/SP500/year=1993/SP500_1993.parquet  (365 filas)
#    ▲ SP500 1994 -> gold/features/SP500/year=1994/SP500_1994.parquet  (365 filas)
#    ▲ SP500 1995 -> gold/features/SP500/year=1995/SP500_1995.parquet  (365 filas)
#    ▲ SP500 1996 -> gold/features/SP500/year=1996/SP500_1996.parquet  (366 filas)
#    ▲ SP500 1997 -> gold/features/SP500/year=1997/SP500_1997.parquet  (365 filas)
#    ▲ SP500 1998 -> gold/features/SP500/year=1998/SP500_1998.parquet  (365 filas)
#    ▲ SP500 1999 -> gold/features/SP500/year=1999/SP500_1999.parquet  (365 filas)
#    ▲ SP500 2000 -> gold/features/SP500/year=2000/SP500_2000.parquet  (366 filas)
#    ▲ SP500 2001 -> gold/features/SP500/year=2001/SP500_2001.parquet  (365 filas)
#    ▲ SP500 2002 -> gold/features/SP500/year=2002/SP500_2002.parquet  (365 filas)
#    ▲ SP500 2003 -> gold/features/SP500/year=2003/SP500_2003.parquet  (365 filas)
#    ▲ SP500 2004 -> gold/features/SP500/year=2004/SP500_2004.parquet  (366 filas)
#    ▲ SP500 2005 -> gold/features/SP500/year=2005/SP500_2005.parquet  (365 filas)
#    ▲ SP500 2006 -> gold/features/SP500/year=2006/SP500_2006.parquet  (365 filas)
#    ▲ SP500 2007 -> gold/features/SP500/year=2007/SP500_2007.parquet  (365 filas)
#    ▲ SP500 2008 -> gold/features/SP500/year=2008/SP500_2008.parquet  (366 filas)
#    ▲ SP500 2009 -> gold/features/SP500/year=2009/SP500_2009.parquet  (365 filas)
#    ▲ SP500 2010 -> gold/features/SP500/year=2010/SP500_2010.parquet  (365 filas)
#    ▲ SP500 2011 -> gold/features/SP500/year=2011/SP500_2011.parquet  (365 filas)
#    ▲ SP500 2012 -> gold/features/SP500/year=2012/SP500_2012.parquet  (366 filas)
#    ▲ SP500 2013 -> gold/features/SP500/year=2013/SP500_2013.parquet  (365 filas)
#    ▲ SP500 2014 -> gold/features/SP500/year=2014/SP500_2014.parquet  (365 filas)
#    ▲ SP500 2015 -> gold/features/SP500/year=2015/SP500_2015.parquet  (365 filas)
#    ▲ SP500 2016 -> gold/features/SP500/year=2016/SP500_2016.parquet  (366 filas)
#    ▲ SP500 2017 -> gold/features/SP500/year=2017/SP500_2017.parquet  (365 filas)
#    ▲ SP500 2018 -> gold/features/SP500/year=2018/SP500_2018.parquet  (365 filas)
#    ▲ SP500 2019 -> gold/features/SP500/year=2019/SP500_2019.parquet  (365 filas)
#    ▲ SP500 2020 -> gold/features/SP500/year=2020/SP500_2020.parquet  (366 filas)
#    ▲ SP500 2021 -> gold/features/SP500/year=2021/SP500_2021.parquet  (365 filas)
#    ▲ SP500 2022 -> gold/features/SP500/year=2022/SP500_2022.parquet  (365 filas)
#    ▲ SP500 2023 -> gold/features/SP500/year=2023/SP500_2023.parquet  (365 filas)
#    ▲ SP500 2024 -> gold/features/SP500/year=2024/SP500_2024.parquet  (366 filas)
#    ▲ SP500 2025 -> gold/features/SP500/year=2025/SP500_2025.parquet  (206 filas)
# ▶ Procesando DJIA …
#    ▲ DJIA 1992 -> gold/features/DJIA/year=1992/DJIA_1992.parquet  (365 filas)
#    ▲ DJIA 1993 -> gold/features/DJIA/year=1993/DJIA_1993.parquet  (365 filas)
#    ▲ DJIA 1994 -> gold/features/DJIA/year=1994/DJIA_1994.parquet  (365 filas)
#    ▲ DJIA 1995 -> gold/features/DJIA/year=1995/DJIA_1995.parquet  (365 filas)
#    ▲ DJIA 1996 -> gold/features/DJIA/year=1996/DJIA_1996.parquet  (366 filas)
#    ▲ DJIA 1997 -> gold/features/DJIA/year=1997/DJIA_1997.parquet  (365 filas)
#    ▲ DJIA 1998 -> gold/features/DJIA/year=1998/DJIA_1998.parquet  (365 filas)
#    ▲ DJIA 1999 -> gold/features/DJIA/year=1999/DJIA_1999.parquet  (365 filas)
#    ▲ DJIA 2000 -> gold/features/DJIA/year=2000/DJIA_2000.parquet  (366 filas)
#    ▲ DJIA 2001 -> gold/features/DJIA/year=2001/DJIA_2001.parquet  (365 filas)
#    ▲ DJIA 2002 -> gold/features/DJIA/year=2002/DJIA_2002.parquet  (365 filas)
#    ▲ DJIA 2003 -> gold/features/DJIA/year=2003/DJIA_2003.parquet  (365 filas)
#    ▲ DJIA 2004 -> gold/features/DJIA/year=2004/DJIA_2004.parquet  (366 filas)
#    ▲ DJIA 2005 -> gold/features/DJIA/year=2005/DJIA_2005.parquet  (365 filas)
#    ▲ DJIA 2006 -> gold/features/DJIA/year=2006/DJIA_2006.parquet  (365 filas)
#    ▲ DJIA 2007 -> gold/features/DJIA/year=2007/DJIA_2007.parquet  (365 filas)
#    ▲ DJIA 2008 -> gold/features/DJIA/year=2008/DJIA_2008.parquet  (366 filas)
#    ▲ DJIA 2009 -> gold/features/DJIA/year=2009/DJIA_2009.parquet  (365 filas)
#    ▲ DJIA 2010 -> gold/features/DJIA/year=2010/DJIA_2010.parquet  (365 filas)
#    ▲ DJIA 2011 -> gold/features/DJIA/year=2011/DJIA_2011.parquet  (365 filas)
#    ▲ DJIA 2012 -> gold/features/DJIA/year=2012/DJIA_2012.parquet  (366 filas)
#    ▲ DJIA 2013 -> gold/features/DJIA/year=2013/DJIA_2013.parquet  (365 filas)
#    ▲ DJIA 2014 -> gold/features/DJIA/year=2014/DJIA_2014.parquet  (365 filas)
#    ▲ DJIA 2015 -> gold/features/DJIA/year=2015/DJIA_2015.parquet  (365 filas)
#    ▲ DJIA 2016 -> gold/features/DJIA/year=2016/DJIA_2016.parquet  (366 filas)
#    ▲ DJIA 2017 -> gold/features/DJIA/year=2017/DJIA_2017.parquet  (365 filas)
#    ▲ DJIA 2018 -> gold/features/DJIA/year=2018/DJIA_2018.parquet  (365 filas)
#    ▲ DJIA 2019 -> gold/features/DJIA/year=2019/DJIA_2019.parquet  (365 filas)
#    ▲ DJIA 2020 -> gold/features/DJIA/year=2020/DJIA_2020.parquet  (366 filas)
#    ▲ DJIA 2021 -> gold/features/DJIA/year=2021/DJIA_2021.parquet  (365 filas)
#    ▲ DJIA 2022 -> gold/features/DJIA/year=2022/DJIA_2022.parquet  (365 filas)
#    ▲ DJIA 2023 -> gold/features/DJIA/year=2023/DJIA_2023.parquet  (365 filas)
#    ▲ DJIA 2024 -> gold/features/DJIA/year=2024/DJIA_2024.parquet  (366 filas)
#    ▲ DJIA 2025 -> gold/features/DJIA/year=2025/DJIA_2025.parquet  (206 filas)
# ▶ Procesando NASDAQ …
#    ▲ NASDAQ 1992 -> gold/features/NASDAQ/year=1992/NASDAQ_1992.parquet  (365 filas)
#    ▲ NASDAQ 1993 -> gold/features/NASDAQ/year=1993/NASDAQ_1993.parquet  (365 filas)
#    ▲ NASDAQ 1994 -> gold/features/NASDAQ/year=1994/NASDAQ_1994.parquet  (365 filas)
#    ▲ NASDAQ 1995 -> gold/features/NASDAQ/year=1995/NASDAQ_1995.parquet  (365 filas)
#    ▲ NASDAQ 1996 -> gold/features/NASDAQ/year=1996/NASDAQ_1996.parquet  (366 filas)
#    ▲ NASDAQ 1997 -> gold/features/NASDAQ/year=1997/NASDAQ_1997.parquet  (365 filas)
#    ▲ NASDAQ 1998 -> gold/features/NASDAQ/year=1998/NASDAQ_1998.parquet  (365 filas)
#    ▲ NASDAQ 1999 -> gold/features/NASDAQ/year=1999/NASDAQ_1999.parquet  (365 filas)
#    ▲ NASDAQ 2000 -> gold/features/NASDAQ/year=2000/NASDAQ_2000.parquet  (366 filas)
#    ▲ NASDAQ 2001 -> gold/features/NASDAQ/year=2001/NASDAQ_2001.parquet  (365 filas)
#    ▲ NASDAQ 2002 -> gold/features/NASDAQ/year=2002/NASDAQ_2002.parquet  (365 filas)
#    ▲ NASDAQ 2003 -> gold/features/NASDAQ/year=2003/NASDAQ_2003.parquet  (365 filas)
#    ▲ NASDAQ 2004 -> gold/features/NASDAQ/year=2004/NASDAQ_2004.parquet  (366 filas)
#    ▲ NASDAQ 2005 -> gold/features/NASDAQ/year=2005/NASDAQ_2005.parquet  (365 filas)
#    ▲ NASDAQ 2006 -> gold/features/NASDAQ/year=2006/NASDAQ_2006.parquet  (365 filas)
#    ▲ NASDAQ 2007 -> gold/features/NASDAQ/year=2007/NASDAQ_2007.parquet  (365 filas)
#    ▲ NASDAQ 2008 -> gold/features/NASDAQ/year=2008/NASDAQ_2008.parquet  (366 filas)
#    ▲ NASDAQ 2009 -> gold/features/NASDAQ/year=2009/NASDAQ_2009.parquet  (365 filas)
#    ▲ NASDAQ 2010 -> gold/features/NASDAQ/year=2010/NASDAQ_2010.parquet  (365 filas)
#    ▲ NASDAQ 2011 -> gold/features/NASDAQ/year=2011/NASDAQ_2011.parquet  (365 filas)
#    ▲ NASDAQ 2012 -> gold/features/NASDAQ/year=2012/NASDAQ_2012.parquet  (366 filas)
#    ▲ NASDAQ 2013 -> gold/features/NASDAQ/year=2013/NASDAQ_2013.parquet  (365 filas)
#    ▲ NASDAQ 2014 -> gold/features/NASDAQ/year=2014/NASDAQ_2014.parquet  (365 filas)
#    ▲ NASDAQ 2015 -> gold/features/NASDAQ/year=2015/NASDAQ_2015.parquet  (365 filas)
#    ▲ NASDAQ 2016 -> gold/features/NASDAQ/year=2016/NASDAQ_2016.parquet  (366 filas)
#    ▲ NASDAQ 2017 -> gold/features/NASDAQ/year=2017/NASDAQ_2017.parquet  (365 filas)
#    ▲ NASDAQ 2018 -> gold/features/NASDAQ/year=2018/NASDAQ_2018.parquet  (365 filas)
#    ▲ NASDAQ 2019 -> gold/features/NASDAQ/year=2019/NASDAQ_2019.parquet  (365 filas)
#    ▲ NASDAQ 2020 -> gold/features/NASDAQ/year=2020/NASDAQ_2020.parquet  (366 filas)
#    ▲ NASDAQ 2021 -> gold/features/NASDAQ/year=2021/NASDAQ_2021.parquet  (365 filas)
#    ▲ NASDAQ 2022 -> gold/features/NASDAQ/year=2022/NASDAQ_2022.parquet  (365 filas)
#    ▲ NASDAQ 2023 -> gold/features/NASDAQ/year=2023/NASDAQ_2023.parquet  (365 filas)
#    ▲ NASDAQ 2024 -> gold/features/NASDAQ/year=2024/NASDAQ_2024.parquet  (366 filas)
#    ▲ NASDAQ 2025 -> gold/features/NASDAQ/year=2025/NASDAQ_2025.parquet  (206 filas)
# ▶ Procesando RUSSELL2000 …
#    ▲ RUSSELL2000 1992 -> gold/features/RUSSELL2000/year=1992/RUSSELL2000_1992.parquet  (365 filas)
#    ▲ RUSSELL2000 1993 -> gold/features/RUSSELL2000/year=1993/RUSSELL2000_1993.parquet  (365 filas)
#    ▲ RUSSELL2000 1994 -> gold/features/RUSSELL2000/year=1994/RUSSELL2000_1994.parquet  (365 filas)
#    ▲ RUSSELL2000 1995 -> gold/features/RUSSELL2000/year=1995/RUSSELL2000_1995.parquet  (365 filas)
#    ▲ RUSSELL2000 1996 -> gold/features/RUSSELL2000/year=1996/RUSSELL2000_1996.parquet  (366 filas)
#    ▲ RUSSELL2000 1997 -> gold/features/RUSSELL2000/year=1997/RUSSELL2000_1997.parquet  (365 filas)
#    ▲ RUSSELL2000 1998 -> gold/features/RUSSELL2000/year=1998/RUSSELL2000_1998.parquet  (365 filas)
#    ▲ RUSSELL2000 1999 -> gold/features/RUSSELL2000/year=1999/RUSSELL2000_1999.parquet  (365 filas)
#    ▲ RUSSELL2000 2000 -> gold/features/RUSSELL2000/year=2000/RUSSELL2000_2000.parquet  (366 filas)
#    ▲ RUSSELL2000 2001 -> gold/features/RUSSELL2000/year=2001/RUSSELL2000_2001.parquet  (365 filas)
#    ▲ RUSSELL2000 2002 -> gold/features/RUSSELL2000/year=2002/RUSSELL2000_2002.parquet  (365 filas)
#    ▲ RUSSELL2000 2003 -> gold/features/RUSSELL2000/year=2003/RUSSELL2000_2003.parquet  (365 filas)
#    ▲ RUSSELL2000 2004 -> gold/features/RUSSELL2000/year=2004/RUSSELL2000_2004.parquet  (366 filas)
#    ▲ RUSSELL2000 2005 -> gold/features/RUSSELL2000/year=2005/RUSSELL2000_2005.parquet  (365 filas)
#    ▲ RUSSELL2000 2006 -> gold/features/RUSSELL2000/year=2006/RUSSELL2000_2006.parquet  (365 filas)
#    ▲ RUSSELL2000 2007 -> gold/features/RUSSELL2000/year=2007/RUSSELL2000_2007.parquet  (365 filas)
#    ▲ RUSSELL2000 2008 -> gold/features/RUSSELL2000/year=2008/RUSSELL2000_2008.parquet  (366 filas)
#    ▲ RUSSELL2000 2009 -> gold/features/RUSSELL2000/year=2009/RUSSELL2000_2009.parquet  (365 filas)
#    ▲ RUSSELL2000 2010 -> gold/features/RUSSELL2000/year=2010/RUSSELL2000_2010.parquet  (365 filas)
#    ▲ RUSSELL2000 2011 -> gold/features/RUSSELL2000/year=2011/RUSSELL2000_2011.parquet  (365 filas)
#    ▲ RUSSELL2000 2012 -> gold/features/RUSSELL2000/year=2012/RUSSELL2000_2012.parquet  (366 filas)
#    ▲ RUSSELL2000 2013 -> gold/features/RUSSELL2000/year=2013/RUSSELL2000_2013.parquet  (365 filas)
#    ▲ RUSSELL2000 2014 -> gold/features/RUSSELL2000/year=2014/RUSSELL2000_2014.parquet  (365 filas)
#    ▲ RUSSELL2000 2015 -> gold/features/RUSSELL2000/year=2015/RUSSELL2000_2015.parquet  (365 filas)
#    ▲ RUSSELL2000 2016 -> gold/features/RUSSELL2000/year=2016/RUSSELL2000_2016.parquet  (366 filas)
#    ▲ RUSSELL2000 2017 -> gold/features/RUSSELL2000/year=2017/RUSSELL2000_2017.parquet  (365 filas)
#    ▲ RUSSELL2000 2018 -> gold/features/RUSSELL2000/year=2018/RUSSELL2000_2018.parquet  (365 filas)
#    ▲ RUSSELL2000 2019 -> gold/features/RUSSELL2000/year=2019/RUSSELL2000_2019.parquet  (365 filas)
#    ▲ RUSSELL2000 2020 -> gold/features/RUSSELL2000/year=2020/RUSSELL2000_2020.parquet  (366 filas)
#    ▲ RUSSELL2000 2021 -> gold/features/RUSSELL2000/year=2021/RUSSELL2000_2021.parquet  (365 filas)
#    ▲ RUSSELL2000 2022 -> gold/features/RUSSELL2000/year=2022/RUSSELL2000_2022.parquet  (365 filas)
#    ▲ RUSSELL2000 2023 -> gold/features/RUSSELL2000/year=2023/RUSSELL2000_2023.parquet  (365 filas)
#    ▲ RUSSELL2000 2024 -> gold/features/RUSSELL2000/year=2024/RUSSELL2000_2024.parquet  (366 filas)
#    ▲ RUSSELL2000 2025 -> gold/features/RUSSELL2000/year=2025/RUSSELL2000_2025.parquet  (206 filas)
# ▶ Procesando WILSHIRE5000 …
#    ▲ WILSHIRE5000 1992 -> gold/features/WILSHIRE5000/year=1992/WILSHIRE5000_1992.parquet  (365 filas)
#    ▲ WILSHIRE5000 1993 -> gold/features/WILSHIRE5000/year=1993/WILSHIRE5000_1993.parquet  (365 filas)
#    ▲ WILSHIRE5000 1994 -> gold/features/WILSHIRE5000/year=1994/WILSHIRE5000_1994.parquet  (365 filas)
#    ▲ WILSHIRE5000 1995 -> gold/features/WILSHIRE5000/year=1995/WILSHIRE5000_1995.parquet  (365 filas)
#    ▲ WILSHIRE5000 1996 -> gold/features/WILSHIRE5000/year=1996/WILSHIRE5000_1996.parquet  (366 filas)
#    ▲ WILSHIRE5000 1997 -> gold/features/WILSHIRE5000/year=1997/WILSHIRE5000_1997.parquet  (365 filas)
#    ▲ WILSHIRE5000 1998 -> gold/features/WILSHIRE5000/year=1998/WILSHIRE5000_1998.parquet  (365 filas)
#    ▲ WILSHIRE5000 1999 -> gold/features/WILSHIRE5000/year=1999/WILSHIRE5000_1999.parquet  (365 filas)
#    ▲ WILSHIRE5000 2000 -> gold/features/WILSHIRE5000/year=2000/WILSHIRE5000_2000.parquet  (366 filas)
#    ▲ WILSHIRE5000 2001 -> gold/features/WILSHIRE5000/year=2001/WILSHIRE5000_2001.parquet  (365 filas)
#    ▲ WILSHIRE5000 2002 -> gold/features/WILSHIRE5000/year=2002/WILSHIRE5000_2002.parquet  (365 filas)
#    ▲ WILSHIRE5000 2003 -> gold/features/WILSHIRE5000/year=2003/WILSHIRE5000_2003.parquet  (365 filas)
#    ▲ WILSHIRE5000 2004 -> gold/features/WILSHIRE5000/year=2004/WILSHIRE5000_2004.parquet  (366 filas)
#    ▲ WILSHIRE5000 2005 -> gold/features/WILSHIRE5000/year=2005/WILSHIRE5000_2005.parquet  (365 filas)
#    ▲ WILSHIRE5000 2006 -> gold/features/WILSHIRE5000/year=2006/WILSHIRE5000_2006.parquet  (365 filas)
#    ▲ WILSHIRE5000 2007 -> gold/features/WILSHIRE5000/year=2007/WILSHIRE5000_2007.parquet  (365 filas)
#    ▲ WILSHIRE5000 2008 -> gold/features/WILSHIRE5000/year=2008/WILSHIRE5000_2008.parquet  (366 filas)
#    ▲ WILSHIRE5000 2009 -> gold/features/WILSHIRE5000/year=2009/WILSHIRE5000_2009.parquet  (365 filas)
#    ▲ WILSHIRE5000 2010 -> gold/features/WILSHIRE5000/year=2010/WILSHIRE5000_2010.parquet  (365 filas)
#    ▲ WILSHIRE5000 2011 -> gold/features/WILSHIRE5000/year=2011/WILSHIRE5000_2011.parquet  (365 filas)
#    ▲ WILSHIRE5000 2012 -> gold/features/WILSHIRE5000/year=2012/WILSHIRE5000_2012.parquet  (366 filas)
#    ▲ WILSHIRE5000 2013 -> gold/features/WILSHIRE5000/year=2013/WILSHIRE5000_2013.parquet  (365 filas)
#    ▲ WILSHIRE5000 2014 -> gold/features/WILSHIRE5000/year=2014/WILSHIRE5000_2014.parquet  (365 filas)
#    ▲ WILSHIRE5000 2015 -> gold/features/WILSHIRE5000/year=2015/WILSHIRE5000_2015.parquet  (365 filas)
#    ▲ WILSHIRE5000 2016 -> gold/features/WILSHIRE5000/year=2016/WILSHIRE5000_2016.parquet  (366 filas)
#    ▲ WILSHIRE5000 2017 -> gold/features/WILSHIRE5000/year=2017/WILSHIRE5000_2017.parquet  (365 filas)
#    ▲ WILSHIRE5000 2018 -> gold/features/WILSHIRE5000/year=2018/WILSHIRE5000_2018.parquet  (365 filas)
#    ▲ WILSHIRE5000 2019 -> gold/features/WILSHIRE5000/year=2019/WILSHIRE5000_2019.parquet  (365 filas)
#    ▲ WILSHIRE5000 2020 -> gold/features/WILSHIRE5000/year=2020/WILSHIRE5000_2020.parquet  (366 filas)
#    ▲ WILSHIRE5000 2021 -> gold/features/WILSHIRE5000/year=2021/WILSHIRE5000_2021.parquet  (365 filas)
#    ▲ WILSHIRE5000 2022 -> gold/features/WILSHIRE5000/year=2022/WILSHIRE5000_2022.parquet  (365 filas)
#    ▲ WILSHIRE5000 2023 -> gold/features/WILSHIRE5000/year=2023/WILSHIRE5000_2023.parquet  (365 filas)
#    ▲ WILSHIRE5000 2024 -> gold/features/WILSHIRE5000/year=2024/WILSHIRE5000_2024.parquet  (366 filas)
#    ▲ WILSHIRE5000 2025 -> gold/features/WILSHIRE5000/year=2025/WILSHIRE5000_2025.parquet  (206 filas)
# ✅ Gold por índice creado

# %% [markdown]
# ## 4. Inspección rapida de resultados

# %%
# ================================================================
# 4.1 Inspección de los resultados
# ================================================================
for idx in tickers:                                            # ['SP500', ...]
    paths = fs.glob(f"{CONTAINER}/{GOLD_PREFIX}/{idx}/year=*/*.parquet")
    print(f"\n===== {idx}: {len(paths)} archivos encontrados =====")
    for p in paths[:5]:
        print(" •", p)

    if not paths:                          # si aún no hay particiones para el índice
        continue

    # Muestra esquema y primeras filas del último archivo (normalmente el año +reciente)
    sample_path = paths[-1]
    df_sample = pd.read_parquet(fs.open(sample_path, "rb"))

    print("\nColumnas y tipos:")
    print(df_sample.dtypes)

    print("\nPrimeras 5 filas:")
    display(df_sample.head())
# Out:
# ===== SP500: 34 archivos encontrados =====
#  • market/gold/features/SP500/year=1992/SP500_1992.parquet
#  • market/gold/features/SP500/year=1993/SP500_1993.parquet
#  • market/gold/features/SP500/year=1994/SP500_1994.parquet
#  • market/gold/features/SP500/year=1995/SP500_1995.parquet
#  • market/gold/features/SP500/year=1996/SP500_1996.parquet
#
# Columnas y tipos:
# date                     datetime64[ns]
# ANFCI                           float64
# BAA10Y                          float64
# BAMLH0A0HYM2                    float64
# CPIAUCSL                        float64
# DCOILWTICO                      float64
# DFII10                          float64
# DGS10                           float64
# DGS2                            float64
# DTWEXBGS                        float64
# FEDFUNDS                        float64
# GDP                             float64
# HOUST                           float64
# ICSA                            float64
# INDPRO                          float64
# M2SL                            float64
# NFCI                            float64
# PAYEMS                          float64
# PERMIT                          float64
# STLFSI2                         float64
# T10Y2Y                          float64
# T10Y3M                          float64
# T5YIE                           float64
# TEDRATE                         float64
# THREEFYTP10                     float64
# UMCSENT                         float64
# UNRATE                          float64
# VIXCLS                          float64
# WALCL                           float64
# SP500                           float64
# SP500_ret                       float64
# sp500_lag1                      float64
# sp500_lag5                      float64
# sp500_sma20                     float64
# sp500_sma50                     float64
# sp500_vol20                     float64
# sp500_rsi14                     float64
# sp500_std20                     float64
# sp500_bollinger_upper           float64
# sp500_bollinger_lower           float64
# y_sp500_ret_5d                  float64
# y_sp500_ret_20d                 float64
# y_sp500_ret_180d                float64
# year                              int32
# dtype: object
#
# Primeras 5 filas:
#         date    ANFCI  BAA10Y  BAMLH0A0HYM2  CPIAUCSL  DCOILWTICO  DFII10  \
# 0 2025-01-01 -0.49691    1.42          2.92   317.603       72.44    2.24
# 1 2025-01-02 -0.49691    1.45          2.88   317.603       73.79    2.23
# 2 2025-01-03 -0.49995    1.44          2.81   317.603       74.64    2.26
# 3 2025-01-04 -0.49995    1.44          2.81   317.603       74.64    2.26
# 4 2025-01-05 -0.49995    1.44          2.81   317.603       74.64    2.26
#
#    DGS10  DGS2  DTWEXBGS  FEDFUNDS        GDP   HOUST      ICSA    INDPRO  \
# 0   4.58  4.25  129.4880      4.48  29962.047  1514.0  209000.0  103.0447
# 1   4.57  4.25  129.6666      4.48  29962.047  1514.0  209000.0  103.0447
# 2   4.60  4.28  129.6721      4.48  29962.047  1514.0  209000.0  103.0447
# 3   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
# 4   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
#
#       M2SL     NFCI    PAYEMS  PERMIT  STLFSI2  T10Y2Y  T10Y3M  T5YIE  \
# 0  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.33    0.21   2.38
# 1  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.32    0.21   2.41
# 2  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 3  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 4  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
#
#    TEDRATE  THREEFYTP10  UMCSENT  UNRATE  VIXCLS      WALCL        SP500  \
# 0     0.09       0.6872     74.0     4.1   17.35  6852491.0  5881.629883
# 1     0.09       0.6851     74.0     4.1   17.93  6852491.0  5868.549805
# 2     0.09       0.7016     74.0     4.1   16.13  6852491.0  5942.470215
# 3     0.09       0.7016     74.0     4.1   16.13  6852491.0  5942.470215
# 4     0.09       0.7016     74.0     4.1   16.13  6852491.0  5942.470215
#
#    SP500_ret   sp500_lag1   sp500_lag5  sp500_sma20  sp500_sma50  sp500_vol20  \
# 0   0.000000  5881.629883  5970.839844  5974.210449  5989.426377     0.008688
# 1  -0.002224  5881.629883  5970.839844  5965.083447  5987.089775     0.008683
# 2   0.012596  5868.549805  5970.839844  5959.652466  5986.955781     0.009233
# 3   0.000000  5942.470215  5906.939941  5954.221484  5988.392783     0.009233
# 4   0.000000  5942.470215  5881.629883  5947.640991  5989.829785     0.009170
#
#    sp500_rsi14  sp500_std20  sp500_bollinger_upper  sp500_bollinger_lower  \
# 0    51.407300    70.881458            6115.973365            5832.447534
# 1    50.213344    72.201154            6109.485756            5820.681138
# 2    51.638480    69.422988            6098.498442            5820.806490
# 3    51.638480    66.060578            6086.342640            5822.100329
# 4    51.638480    59.745932            6067.132855            5828.149128
#
#    y_sp500_ret_5d  y_sp500_ret_20d  y_sp500_ret_180d  year
# 0        0.015939         0.028497          0.054971  2025
# 1        0.006898         0.037117          0.056140  2025
# 2       -0.004076         0.029658          0.047951  2025
# 3       -0.004076         0.026718          0.056690  2025
# 4       -0.019425         0.026718          0.056690  2025
# ===== DJIA: 34 archivos encontrados =====
#  • market/gold/features/DJIA/year=1992/DJIA_1992.parquet
#  • market/gold/features/DJIA/year=1993/DJIA_1993.parquet
#  • market/gold/features/DJIA/year=1994/DJIA_1994.parquet
#  • market/gold/features/DJIA/year=1995/DJIA_1995.parquet
#  • market/gold/features/DJIA/year=1996/DJIA_1996.parquet
#
# Columnas y tipos:
# date                    datetime64[ns]
# ANFCI                          float64
# BAA10Y                         float64
# BAMLH0A0HYM2                   float64
# CPIAUCSL                       float64
# DCOILWTICO                     float64
# DFII10                         float64
# DGS10                          float64
# DGS2                           float64
# DTWEXBGS                       float64
# FEDFUNDS                       float64
# GDP                            float64
# HOUST                          float64
# ICSA                           float64
# INDPRO                         float64
# M2SL                           float64
# NFCI                           float64
# PAYEMS                         float64
# PERMIT                         float64
# STLFSI2                        float64
# T10Y2Y                         float64
# T10Y3M                         float64
# T5YIE                          float64
# TEDRATE                        float64
# THREEFYTP10                    float64
# UMCSENT                        float64
# UNRATE                         float64
# VIXCLS                         float64
# WALCL                          float64
# DJIA                           float64
# DJIA_ret                       float64
# djia_lag1                      float64
# djia_lag5                      float64
# djia_sma20                     float64
# djia_sma50                     float64
# djia_vol20                     float64
# djia_rsi14                     float64
# djia_std20                     float64
# djia_bollinger_upper           float64
# djia_bollinger_lower           float64
# y_djia_ret_5d                  float64
# y_djia_ret_20d                 float64
# y_djia_ret_180d                float64
# year                             int32
# dtype: object
#
# Primeras 5 filas:
#         date    ANFCI  BAA10Y  BAMLH0A0HYM2  CPIAUCSL  DCOILWTICO  DFII10  \
# 0 2025-01-01 -0.49691    1.42          2.92   317.603       72.44    2.24
# 1 2025-01-02 -0.49691    1.45          2.88   317.603       73.79    2.23
# 2 2025-01-03 -0.49995    1.44          2.81   317.603       74.64    2.26
# 3 2025-01-04 -0.49995    1.44          2.81   317.603       74.64    2.26
# 4 2025-01-05 -0.49995    1.44          2.81   317.603       74.64    2.26
#
#    DGS10  DGS2  DTWEXBGS  FEDFUNDS        GDP   HOUST      ICSA    INDPRO  \
# 0   4.58  4.25  129.4880      4.48  29962.047  1514.0  209000.0  103.0447
# 1   4.57  4.25  129.6666      4.48  29962.047  1514.0  209000.0  103.0447
# 2   4.60  4.28  129.6721      4.48  29962.047  1514.0  209000.0  103.0447
# 3   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
# 4   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
#
#       M2SL     NFCI    PAYEMS  PERMIT  STLFSI2  T10Y2Y  T10Y3M  T5YIE  \
# 0  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.33    0.21   2.38
# 1  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.32    0.21   2.41
# 2  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 3  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 4  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
#
#    TEDRATE  THREEFYTP10  UMCSENT  UNRATE  VIXCLS      WALCL          DJIA  \
# 0     0.09       0.6872     74.0     4.1   17.35  6852491.0  42544.218750
# 1     0.09       0.6851     74.0     4.1   17.93  6852491.0  42392.269531
# 2     0.09       0.7016     74.0     4.1   16.13  6852491.0  42732.128906
# 3     0.09       0.7016     74.0     4.1   16.13  6852491.0  42732.128906
# 4     0.09       0.7016     74.0     4.1   16.13  6852491.0  42732.128906
#
#    DJIA_ret     djia_lag1     djia_lag5    djia_sma20    djia_sma50  \
# 0  0.000000  42544.218750  42992.210938  43065.353125  43797.163906
# 1 -0.003572  42544.218750  42992.210938  42993.563672  43765.845469
# 2  0.008017  42392.269531  42992.210938  42938.767188  43745.470859
# 3  0.000000  42732.128906  42573.730469  42883.970703  43731.213672
# 4  0.000000  42732.128906  42544.218750  42834.703125  43716.956484
#
#    djia_vol20  djia_rsi14  djia_std20  djia_bollinger_upper  \
# 0    0.007473   56.103517  488.807992          44042.969109
# 1    0.007486   51.304872  476.167772          43945.899216
# 2    0.007786   46.926176  436.486719          43811.740625
# 3    0.007786   46.926176  384.687128          43653.344959
# 4    0.007785   46.926176  331.779180          43498.261484
#
#    djia_bollinger_lower  y_djia_ret_5d  y_djia_ret_20d  y_djia_ret_180d  year
# 0          42087.737141       0.003816        0.034825         0.036446  2025
# 1          42041.228128       0.003210        0.041622         0.049600  2025
# 2          42065.793750      -0.002268        0.042894         0.041006  2025
# 3          42114.596447      -0.002268        0.039598         0.049059  2025
# 4          42171.144766      -0.018573        0.039598         0.049059  2025
# ===== NASDAQ: 34 archivos encontrados =====
#  • market/gold/features/NASDAQ/year=1992/NASDAQ_1992.parquet
#  • market/gold/features/NASDAQ/year=1993/NASDAQ_1993.parquet
#  • market/gold/features/NASDAQ/year=1994/NASDAQ_1994.parquet
#  • market/gold/features/NASDAQ/year=1995/NASDAQ_1995.parquet
#  • market/gold/features/NASDAQ/year=1996/NASDAQ_1996.parquet
#
# Columnas y tipos:
# date                      datetime64[ns]
# ANFCI                            float64
# BAA10Y                           float64
# BAMLH0A0HYM2                     float64
# CPIAUCSL                         float64
# DCOILWTICO                       float64
# DFII10                           float64
# DGS10                            float64
# DGS2                             float64
# DTWEXBGS                         float64
# FEDFUNDS                         float64
# GDP                              float64
# HOUST                            float64
# ICSA                             float64
# INDPRO                           float64
# M2SL                             float64
# NFCI                             float64
# PAYEMS                           float64
# PERMIT                           float64
# STLFSI2                          float64
# T10Y2Y                           float64
# T10Y3M                           float64
# T5YIE                            float64
# TEDRATE                          float64
# THREEFYTP10                      float64
# UMCSENT                          float64
# UNRATE                           float64
# VIXCLS                           float64
# WALCL                            float64
# NASDAQ                           float64
# NASDAQ_ret                       float64
# nasdaq_lag1                      float64
# nasdaq_lag5                      float64
# nasdaq_sma20                     float64
# nasdaq_sma50                     float64
# nasdaq_vol20                     float64
# nasdaq_rsi14                     float64
# nasdaq_std20                     float64
# nasdaq_bollinger_upper           float64
# nasdaq_bollinger_lower           float64
# y_nasdaq_ret_5d                  float64
# y_nasdaq_ret_20d                 float64
# y_nasdaq_ret_180d                float64
# year                               int32
# dtype: object
#
# Primeras 5 filas:
#         date    ANFCI  BAA10Y  BAMLH0A0HYM2  CPIAUCSL  DCOILWTICO  DFII10  \
# 0 2025-01-01 -0.49691    1.42          2.92   317.603       72.44    2.24
# 1 2025-01-02 -0.49691    1.45          2.88   317.603       73.79    2.23
# 2 2025-01-03 -0.49995    1.44          2.81   317.603       74.64    2.26
# 3 2025-01-04 -0.49995    1.44          2.81   317.603       74.64    2.26
# 4 2025-01-05 -0.49995    1.44          2.81   317.603       74.64    2.26
#
#    DGS10  DGS2  DTWEXBGS  FEDFUNDS        GDP   HOUST      ICSA    INDPRO  \
# 0   4.58  4.25  129.4880      4.48  29962.047  1514.0  209000.0  103.0447
# 1   4.57  4.25  129.6666      4.48  29962.047  1514.0  209000.0  103.0447
# 2   4.60  4.28  129.6721      4.48  29962.047  1514.0  209000.0  103.0447
# 3   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
# 4   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
#
#       M2SL     NFCI    PAYEMS  PERMIT  STLFSI2  T10Y2Y  T10Y3M  T5YIE  \
# 0  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.33    0.21   2.38
# 1  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.32    0.21   2.41
# 2  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 3  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 4  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
#
#    TEDRATE  THREEFYTP10  UMCSENT  UNRATE  VIXCLS      WALCL        NASDAQ  \
# 0     0.09       0.6872     74.0     4.1   17.35  6852491.0  19310.789062
# 1     0.09       0.6851     74.0     4.1   17.93  6852491.0  19280.789062
# 2     0.09       0.7016     74.0     4.1   16.13  6852491.0  19621.679688
# 3     0.09       0.7016     74.0     4.1   16.13  6852491.0  19621.679688
# 4     0.09       0.7016     74.0     4.1   16.13  6852491.0  19621.679688
#
#    NASDAQ_ret   nasdaq_lag1   nasdaq_lag5  nasdaq_sma20  nasdaq_sma50  \
# 0    0.000000  19310.789062  19722.029297  19733.416406  19460.833359
# 1   -0.001554  19310.789062  19722.029297  19701.119824  19461.834727
# 2    0.017680  19280.789062  19722.029297  19685.867773  19472.115312
# 3    0.000000  19621.679688  19486.789062  19670.615723  19490.946523
# 4    0.000000  19621.679688  19310.789062  19643.005176  19509.777734
#
#    nasdaq_vol20  nasdaq_rsi14  nasdaq_std20  nasdaq_bollinger_upper  \
# 0      0.010923     47.072106    276.253957            20285.924319
# 1      0.010905     46.735278    289.886756            20280.893337
# 2      0.011718     51.583470    285.381995            20256.631763
# 3      0.011718     51.583470    279.931594            20230.478911
# 4      0.011310     51.583470    253.681785            20150.368746
#
#    nasdaq_bollinger_lower  y_nasdaq_ret_5d  y_nasdaq_ret_20d  \
# 0            19180.908493         0.028699          0.023095
# 1            19121.346311         0.010834          0.037786
# 2            19115.103784        -0.007278          0.022016
# 3            19110.752534        -0.007278          0.016952
# 4            19135.641605        -0.023446          0.016952
#
#    y_nasdaq_ret_180d  year
# 0           0.054837  2025
# 1           0.047825  2025
# 2           0.039316  2025
# 3           0.049915  2025
# 4           0.049915  2025
# ===== RUSSELL2000: 34 archivos encontrados =====
#  • market/gold/features/RUSSELL2000/year=1992/RUSSELL2000_1992.parquet
#  • market/gold/features/RUSSELL2000/year=1993/RUSSELL2000_1993.parquet
#  • market/gold/features/RUSSELL2000/year=1994/RUSSELL2000_1994.parquet
#  • market/gold/features/RUSSELL2000/year=1995/RUSSELL2000_1995.parquet
#  • market/gold/features/RUSSELL2000/year=1996/RUSSELL2000_1996.parquet
#
# Columnas y tipos:
# date                           datetime64[ns]
# ANFCI                                 float64
# BAA10Y                                float64
# BAMLH0A0HYM2                          float64
# CPIAUCSL                              float64
# DCOILWTICO                            float64
# DFII10                                float64
# DGS10                                 float64
# DGS2                                  float64
# DTWEXBGS                              float64
# FEDFUNDS                              float64
# GDP                                   float64
# HOUST                                 float64
# ICSA                                  float64
# INDPRO                                float64
# M2SL                                  float64
# NFCI                                  float64
# PAYEMS                                float64
# PERMIT                                float64
# STLFSI2                               float64
# T10Y2Y                                float64
# T10Y3M                                float64
# T5YIE                                 float64
# TEDRATE                               float64
# THREEFYTP10                           float64
# UMCSENT                               float64
# UNRATE                                float64
# VIXCLS                                float64
# WALCL                                 float64
# RUSSELL2000                           float64
# RUSSELL2000_ret                       float64
# russell2000_lag1                      float64
# russell2000_lag5                      float64
# russell2000_sma20                     float64
# russell2000_sma50                     float64
# russell2000_vol20                     float64
# russell2000_rsi14                     float64
# russell2000_std20                     float64
# russell2000_bollinger_upper           float64
# russell2000_bollinger_lower           float64
# y_russell2000_ret_5d                  float64
# y_russell2000_ret_20d                 float64
# y_russell2000_ret_180d                float64
# year                                    int32
# dtype: object
#
# Primeras 5 filas:
#         date    ANFCI  BAA10Y  BAMLH0A0HYM2  CPIAUCSL  DCOILWTICO  DFII10  \
# 0 2025-01-01 -0.49691    1.42          2.92   317.603       72.44    2.24
# 1 2025-01-02 -0.49691    1.45          2.88   317.603       73.79    2.23
# 2 2025-01-03 -0.49995    1.44          2.81   317.603       74.64    2.26
# 3 2025-01-04 -0.49995    1.44          2.81   317.603       74.64    2.26
# 4 2025-01-05 -0.49995    1.44          2.81   317.603       74.64    2.26
#
#    DGS10  DGS2  DTWEXBGS  FEDFUNDS        GDP   HOUST      ICSA    INDPRO  \
# 0   4.58  4.25  129.4880      4.48  29962.047  1514.0  209000.0  103.0447
# 1   4.57  4.25  129.6666      4.48  29962.047  1514.0  209000.0  103.0447
# 2   4.60  4.28  129.6721      4.48  29962.047  1514.0  209000.0  103.0447
# 3   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
# 4   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
#
#       M2SL     NFCI    PAYEMS  PERMIT  STLFSI2  T10Y2Y  T10Y3M  T5YIE  \
# 0  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.33    0.21   2.38
# 1  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.32    0.21   2.41
# 2  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 3  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 4  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
#
#    TEDRATE  THREEFYTP10  UMCSENT  UNRATE  VIXCLS      WALCL  RUSSELL2000  \
# 0     0.09       0.6872     74.0     4.1   17.35  6852491.0  2230.159912
# 1     0.09       0.6851     74.0     4.1   17.93  6852491.0  2231.669922
# 2     0.09       0.7016     74.0     4.1   16.13  6852491.0  2268.469971
# 3     0.09       0.7016     74.0     4.1   16.13  6852491.0  2268.469971
# 4     0.09       0.7016     74.0     4.1   16.13  6852491.0  2268.469971
#
#    RUSSELL2000_ret  russell2000_lag1  russell2000_lag5  russell2000_sma20  \
# 0         0.000000       2230.159912       2244.590088        2268.804517
# 1         0.000677       2230.159912       2244.590088        2263.043018
# 2         0.016490       2231.669922       2244.590088        2259.121521
# 3         0.000000       2268.469971       2227.780029        2255.200024
# 4         0.000000       2268.469971       2230.159912        2250.524023
#
#    russell2000_sma50  russell2000_vol20  russell2000_rsi14  russell2000_std20  \
# 0        2339.772012           0.011861          49.493777          48.486890
# 1        2337.018008           0.011861          54.072853          45.471092
# 2        2335.648608           0.012585          59.269729          41.022905
# 3        2334.941206           0.012585          59.269729          35.577552
# 4        2334.233804           0.012449          59.269729          25.530350
#
#    russell2000_bollinger_upper  russell2000_bollinger_lower  \
# 0                  2365.778297                  2171.830736
# 1                  2353.985201                  2172.100834
# 2                  2341.167330                  2177.075712
# 3                  2326.355129                  2184.044920
# 4                  2301.584724                  2199.463323
#
#    y_russell2000_ret_5d  y_russell2000_ret_20d  y_russell2000_ret_180d  year
# 0              0.016362               0.039374               -0.024716  2025
# 1              0.008124               0.032285               -0.015293  2025
# 2             -0.013009               0.020335               -0.018554  2025
# 3             -0.013009               0.017311               -0.008565  2025
# 4             -0.034931               0.017311               -0.008565  2025
# ===== WILSHIRE5000: 34 archivos encontrados =====
#  • market/gold/features/WILSHIRE5000/year=1992/WILSHIRE5000_1992.parquet
#  • market/gold/features/WILSHIRE5000/year=1993/WILSHIRE5000_1993.parquet
#  • market/gold/features/WILSHIRE5000/year=1994/WILSHIRE5000_1994.parquet
#  • market/gold/features/WILSHIRE5000/year=1995/WILSHIRE5000_1995.parquet
#  • market/gold/features/WILSHIRE5000/year=1996/WILSHIRE5000_1996.parquet
#
# Columnas y tipos:
# date                            datetime64[ns]
# ANFCI                                  float64
# BAA10Y                                 float64
# BAMLH0A0HYM2                           float64
# CPIAUCSL                               float64
# DCOILWTICO                             float64
# DFII10                                 float64
# DGS10                                  float64
# DGS2                                   float64
# DTWEXBGS                               float64
# FEDFUNDS                               float64
# GDP                                    float64
# HOUST                                  float64
# ICSA                                   float64
# INDPRO                                 float64
# M2SL                                   float64
# NFCI                                   float64
# PAYEMS                                 float64
# PERMIT                                 float64
# STLFSI2                                float64
# T10Y2Y                                 float64
# T10Y3M                                 float64
# T5YIE                                  float64
# TEDRATE                                float64
# THREEFYTP10                            float64
# UMCSENT                                float64
# UNRATE                                 float64
# VIXCLS                                 float64
# WALCL                                  float64
# WILSHIRE5000                           float64
# WILSHIRE5000_ret                       float64
# wilshire5000_lag1                      float64
# wilshire5000_lag5                      float64
# wilshire5000_sma20                     float64
# wilshire5000_sma50                     float64
# wilshire5000_vol20                     float64
# wilshire5000_rsi14                     float64
# wilshire5000_std20                     float64
# wilshire5000_bollinger_upper           float64
# wilshire5000_bollinger_lower           float64
# y_wilshire5000_ret_5d                  float64
# y_wilshire5000_ret_20d                 float64
# y_wilshire5000_ret_180d                float64
# year                                     int32
# dtype: object
#
# Primeras 5 filas:
#         date    ANFCI  BAA10Y  BAMLH0A0HYM2  CPIAUCSL  DCOILWTICO  DFII10  \
# 0 2025-01-01 -0.49691    1.42          2.92   317.603       72.44    2.24
# 1 2025-01-02 -0.49691    1.45          2.88   317.603       73.79    2.23
# 2 2025-01-03 -0.49995    1.44          2.81   317.603       74.64    2.26
# 3 2025-01-04 -0.49995    1.44          2.81   317.603       74.64    2.26
# 4 2025-01-05 -0.49995    1.44          2.81   317.603       74.64    2.26
#
#    DGS10  DGS2  DTWEXBGS  FEDFUNDS        GDP   HOUST      ICSA    INDPRO  \
# 0   4.58  4.25  129.4880      4.48  29962.047  1514.0  209000.0  103.0447
# 1   4.57  4.25  129.6666      4.48  29962.047  1514.0  209000.0  103.0447
# 2   4.60  4.28  129.6721      4.48  29962.047  1514.0  209000.0  103.0447
# 3   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
# 4   4.60  4.28  129.6721      4.48  29962.047  1514.0  205000.0  103.0447
#
#       M2SL     NFCI    PAYEMS  PERMIT  STLFSI2  T10Y2Y  T10Y3M  T5YIE  \
# 0  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.33    0.21   2.38
# 1  21441.8 -0.48658  158942.0  1480.0  -0.8509    0.32    0.21   2.41
# 2  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 3  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
# 4  21441.8 -0.49156  158942.0  1480.0  -0.8509    0.32    0.26   2.40
#
#    TEDRATE  THREEFYTP10  UMCSENT  UNRATE  VIXCLS      WALCL  WILSHIRE5000  \
# 0     0.09       0.6872     74.0     4.1   17.35  6852491.0  58970.019531
# 1     0.09       0.6851     74.0     4.1   17.93  6852491.0  58879.191406
# 2     0.09       0.7016     74.0     4.1   16.13  6852491.0  59659.671875
# 3     0.09       0.7016     74.0     4.1   16.13  6852491.0  59659.671875
# 4     0.09       0.7016     74.0     4.1   16.13  6852491.0  59659.671875
#
#    WILSHIRE5000_ret  wilshire5000_lag1  wilshire5000_lag5  wilshire5000_sma20  \
# 0          0.000000       58970.019531       59833.500000        59942.236328
# 1         -0.001540       58970.019531       59833.500000        59842.321484
# 2          0.013256       58879.191406       59833.500000        59781.430664
# 3          0.000000       59659.671875       59204.589844        59720.539844
# 4          0.000000       59659.671875       58970.019531        59647.380859
#
#    wilshire5000_sma50  wilshire5000_vol20  wilshire5000_rsi14  \
# 0        60258.355859            0.009015           50.910195
# 1        60231.731719            0.009012           50.568606
# 2        60229.095156            0.009602           52.404594
# 3        60242.271562            0.009602           52.404594
# 4        60255.447969            0.009533           52.404594
#
#    wilshire5000_std20  wilshire5000_bollinger_upper  \
# 0          765.071084                  61472.378497
# 1          766.984879                  61376.291243
# 2          727.818913                  61237.068490
# 3          680.712324                  61081.964492
# 4          595.341481                  60838.063822
#
#    wilshire5000_bollinger_lower  y_wilshire5000_ret_5d  \
# 0                  58412.094159               0.017076
# 1                  58308.351726               0.007439
# 2                  58325.792838              -0.004561
# 3                  58359.115195              -0.004561
# 4                  58456.697897              -0.019927
#
#    y_wilshire5000_ret_20d  y_wilshire5000_ret_180d  year
# 0                0.032476                 0.050374  2025
# 1                0.039094                 0.051513  2025
# 2                0.030732                 0.043513  2025
# 3                0.028062                 0.052285  2025
# 4                0.028062                 0.052285  2025

# %% [markdown]
# | **Columna**             | **Descripción**                                                                                         |
# | ----------------------- | ------------------------------------------------------------------------------------------------------- |
# | `date`                  | Fecha de la observación (formato día/mes/año).                                                          |
# | `CPIAUCSL`              | Índice de Precios al Consumidor en EE.UU., mide la inflación.                                           |
# | `FEDFUNDS`              | Tasa de fondos federales establecida por la Reserva Federal.                                            |
# | `GDP`                   | Producto Interno Bruto (PIB) nominal de EE.UU.                                                          |
# | `GS10`                  | Tasa de rendimiento de bonos del Tesoro a 10 años.                                                      |
# | `STLFSI2`               | Índice de estrés financiero de St. Louis.                                                               |
# | `UNRATE`                | Tasa de desempleo en EE.UU.                                                                             |
# | `TICKER`                | Valor del activo financiero (dependiendo cual se filtre).                                               |
# | `TICKER_ret`            | Retorno diario del activo financiero . Calculado como el cambio porcentual.                             |
# | `TICKER_lag1`           | Precio del activo en el día anterior.                                                                   |
# | `TICKER_lag5`           | Precio promedio o cierre del activo 5 días antes. Útil para capturar memoria del mercado.               |
# | `TICKER_sma20`          | Media móvil simple de 20 días del activo. Ayuda a suavizar la tendencia a corto plazo.                  |
# | `TICKER_sma50`          | Media móvil simple de 50 días. Detecta tendencias más largas.                                           |
# | `TICKER_vol20`          | Volatilidad promedio de 20 días, mide la variación reciente del precio.                                 |
# | `TICKER_rsi14`          | Índice de Fuerza Relativa (RSI) de 14 días. Oscilador que indica condiciones de sobrecompra/sobreventa. |
# | `TICKER_std20`          | Desviación estándar de los precios en los últimos 20 días, mide la dispersión o volatilidad.            |
# | `TICKER_bollinger_upper`| Banda superior de las Bandas de Bollinger (basadas en `sma20` + 2 desviaciones estándar).               |
# | `TICKER_bollinger_lower`| Banda inferior de las Bandas de Bollinger (basadas en `sma20` - 2 desviaciones estándar).               |
# | `y_TICKER_ret_5d`       | Retorno futuro del activo en 5 días. Etiqueta usada en modelos de predicción a corto plazo.             |
# | `y_TICKER_ret_20d`      | Retorno futuro en 20 días. Objetivo para predicción a mediano plazo.                                    |
# | `y_TICKER_ret_180d`     | Retorno futuro en 180 días. Utilizado para predicciones a largo plazo.                                  |
# | `year`                  | Año de la observación (extraído de la columna `date`).                                                  |

# %%
import pandas as pd
import numpy as np
import pyarrow.parquet as pq   # lectura de metadata rápida

def quick_stats(paths):
    """
    Devuelve filas totales, columnas totales, % nulos, kurtosis media y % outliers
    usando solo metadata + una muestra (último año) para la parte estadística.
    """
    if not paths:
        return dict(n_rows=0, n_cols=0,
                    pct_nan=np.nan, kurtosis=np.nan, pct_outliers=np.nan)

    # --------- 1. nº de filas y columnas solo con metadata ----------
    total_rows = 0
    n_cols = None
    for f in paths:
        meta = pq.ParquetFile(fs.open(f, "rb")).metadata
        total_rows += meta.num_rows
        if n_cols is None:
            n_cols = meta.num_columns  # basta con leerlo una vez

    # --------- 2. estadística básica con un único archivo ------------
    df_sample = pd.read_parquet(fs.open(paths[-1], "rb"))
    num = df_sample.select_dtypes("number")
    ret_cols = [c for c in num.columns if c.endswith("_ret")]

    z = (num - num.mean()) / num.std(ddof=0)
    pct_out = 100 * (np.abs(z) > 5).sum().sum() / (len(df_sample) * len(num.columns))

    pct_nan = 100 * df_sample.isna().sum().sum() / (len(df_sample) * n_cols)

    return dict(n_rows=total_rows,
                n_cols=n_cols,
                pct_nan=round(pct_nan, 2),
                pct_outliers=round(pct_out, 3))


rows = []
for idx in tickers:                            
    paths = fs.glob(f"{CONTAINER}/{GOLD_PREFIX}/{idx}/year=*/*.parquet")
    stats = quick_stats(paths)
    stats["index"] = idx
    rows.append(stats)

df_summary = (pd.DataFrame(rows)
                .set_index("index")
                .sort_index())

display(df_summary)
# Out:
#               n_rows  n_cols  pct_nan  pct_outliers
# index
# DJIA           12259      44     2.26         0.034
# NASDAQ         12259      44     2.26         0.023
# RUSSELL2000    12259      44     2.26         0.023
# SP500          12259      44     2.26         0.034
# WILSHIRE5000   12259      44     2.26         0.023

# %%
# ================================================================
# 3.3 Resumen gráfico y tablas comparativas para los cinco índices
# ================================================================
import os, numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox

os.makedirs("eda_outputs", exist_ok=True)

TICKERS = ["SP500", "DJIA", "NASDAQ", "RUSSELL2000", "WILSHIRE5000"]
summary, bars_q, adf_rows = [], [], []

for tk in TICKERS:
    # ---------------------------------------------------------------------
    # Cargar TODA la historia del índice (1992-2025)
    # ---------------------------------------------------------------------
    paths = fs.glob(f"{CONTAINER}/{GOLD_PREFIX}/{tk}/year=*/*.parquet")
    df = pd.concat(pd.read_parquet(fs.open(p, "rb")) for p in paths).set_index("date")

    # ---------- 1) Calidad de datos --------------------------------------
    pct_nan = df.isna().mean().mean() * 100
    z = (df.select_dtypes("number") - df.mean()) / df.std(ddof=0)
    pct_out = (np.abs(z) > 5).mean().mean() * 100
    bars_q.append([pct_nan, pct_out])

    # ---------- 2) Estadísticos para la tabla de calidad -----------------
    r1d = df[f"{tk}_ret"].dropna()
    kurtosis = r1d.kurtosis()
    p_lb20 = acorr_ljungbox(r1d, lags=[20], return_df=True)["lb_pvalue"].iloc[0]
    p_ret1d = adfuller(r1d, autolag="AIC")[1]
    summary.append([tk, len(df), df.shape[1], kurtosis, p_ret1d, pct_nan, pct_out, p_lb20])

    # ---------- 3) p-ADF de precio y de los 4 retornos -------------------
    p_price   = adfuller(np.log(df[tk]).dropna(), autolag="AIC")[1]
    p_ret5d   = adfuller(df[f"y_{tk.lower()}_ret_5d"  ].dropna(), autolag="AIC")[1]
    p_ret20d  = adfuller(df[f"y_{tk.lower()}_ret_20d" ].dropna(), autolag="AIC")[1]
    p_ret180d = adfuller(df[f"y_{tk.lower()}_ret_180d"].dropna(), autolag="AIC")[1]
    adf_rows.append([tk, p_price, p_ret1d, p_ret5d, p_ret20d, p_ret180d])

# -----------------------------------------------------------------
# 4) Guardar CSV de calidad
# -----------------------------------------------------------------
cols_metrics = ["Index","Rows","Cols","Kurtosis","p_ADF_ret1d",
                "%NaN","%Outliers","p_LB20"]
pd.DataFrame(summary, columns=cols_metrics).set_index("Index") \
  .to_csv("eda_outputs/metrics_summary.csv", float_format="%.4g")

# -----------------------------------------------------------------
# 5) Guardar CSV de p-ADF (precio + 4 retornos)
# -----------------------------------------------------------------
cols_adf = ["Index","p_ADF_price","p_ADF_ret1d",
            "p_ADF_ret5d","p_ADF_ret20d","p_ADF_ret180d"]
pd.DataFrame(adf_rows, columns=cols_adf).set_index("Index") \
  .to_csv("eda_outputs/adf_pvalues.csv", float_format="%.4g")

# -----------------------------------------------------------------
# 6) Barra apilada %NaN + %Outliers
# -----------------------------------------------------------------
bars_q = np.array(bars_q)
fig, ax = plt.subplots(figsize=(6,3))
ax.bar(TICKERS, bars_q[:,0], label="% NaN")
ax.bar(TICKERS, bars_q[:,1], bottom=bars_q[:,0], label="% Outliers")
ax.set_ylabel("Porcentaje"); ax.set_title("Calidad de datos por índice"); ax.legend()
plt.tight_layout(); fig.savefig("eda_outputs/quality_bar.png", dpi=300); plt.close()

# -----------------------------------------------------------------
# 7) Histogramas comparados (1×5) – retornos 1 d
# -----------------------------------------------------------------
fig, axes = plt.subplots(1,5, figsize=(15,3), sharey=True)
for i, tk in enumerate(TICKERS):
    r1d_recent = pd.read_parquet(fs.open(
        fs.glob(f"{CONTAINER}/{GOLD_PREFIX}/{tk}/year=*/*.parquet")[-1], "rb")
    )[f"{tk}_ret"].dropna()
    sns.histplot(r1d_recent, bins=80, kde=True, ax=axes[i])
    axes[i].set_title(tk); axes[i].set_xlabel("")
fig.suptitle("Distribución de retornos diarios (1992-2025)")
plt.tight_layout(); fig.savefig("eda_outputs/hist_grid.png", dpi=300); plt.close()

# -----------------------------------------------------------------
# 8) ACF/PACF grid (2×5) – retornos 1 d
# -----------------------------------------------------------------
fig, axes = plt.subplots(2,5, figsize=(15,6), sharex=True)
for i, tk in enumerate(TICKERS):
    r1d_recent = pd.read_parquet(fs.open(
        fs.glob(f"{CONTAINER}/{GOLD_PREFIX}/{tk}/year=*/*.parquet")[-1], "rb")
    )[f"{tk}_ret"].dropna()
    plot_acf (r1d_recent, lags=30, ax=axes[0,i]); axes[0,i].set_title(tk)
    plot_pacf(r1d_recent, lags=30, ax=axes[1,i])
fig.suptitle("ACF y PACF de retornos diarios")
plt.tight_layout(); fig.savefig("eda_outputs/acf_pacf_grid.png", dpi=300); plt.close()

print("Figuras y tablas EDA actualizadas en 'eda_outputs/'")
# Out:
# Figuras y tablas EDA actualizadas en 'eda_outputs/'
