# %% [markdown]
# # Ingesta histórica + incremental de series macroeconómicas FRED hacia Azure Data Lake

# %% [markdown]
# **Descripcion:**<br>
# Este script en Python consume la API de la Reserva Federal (fredapi) para descargar observaciones mensuales/diarias de seis indicadores clave (FEDFUNDS, CPI, desempleo, PIB real, Treasury 10 años y Financial Stress Index) desde 1992 hasta hoy.<br>
# Los datos se normalizan, validan y se guardan en formato Parquet local (zona RAW) para después replicarse y particionarse por año en Azure Data Lake Storage Gen2 (zona Bronze). Incluye controles básicos de calidad, bitácora de ingesta y lógica incremental para futuras actualizaciones.<br>
#
# **Objetivos**:<br>
# -Automatizar la extracción de series macroeconómicas desde la API de FRED.<br>
# -Estandarizar el esquema.<br>
# -Persistir en formato eficiente (Parquet) tanto localmente como en ADLS, habilitando compresión y lectura columnar.<br>
# -Garantizar la calidad inicial mediante chequeos de cobertura, nulos y duplicados.<br>
# -Implementar carga incremental idempotente, particionando por year=YYYY.<br>
# -Registrar la actividad (log de ingesta y tamaños de archivo).

# %% [markdown]
# ## 1. Configuración básica y librerías y Parámetros globales del pipeline

# %%
# ================================================================
# 1.1  Librerías estándar y de terceros, así como funciones propias
# ================================================================
import os, io, pathlib, logging, datetime as dt
from datetime import date

import pandas as pd
from fredapi import Fred                                     # cliente oficial de la API FRED
from dotenv import load_dotenv                               # Leer variables de entorno

# Funciones auxiliares para Azure Data Lake Storage (ya desarrolladas)
from utils_adls import upload_bytes, _client, CONTAINER      # funciones ya creadas

load_dotenv()                 # lee .env  (FRED_API_KEY, AZ_STORAGE_ACCOUNT)

# --- parámetros generales ---------------------------------------
FRED_KEY = os.getenv("FRED_API_KEY")
fred = Fred(api_key=FRED_KEY)         # instancia del cliente FRED

# Diccionario {código FRED: descripción legible}
SERIES = {
    # Base (mantienes las tuyas; sugiero usar DGS10 en lugar de GS10 por ser diaria)
    "FEDFUNDS":  "Effective Fed Funds Rate",
    "CPIAUCSL":  "CPI (SA)",
    "UNRATE":    "Unemployment Rate",
    "GDP":       "Real GDP",
    "DGS10":     "10-Year Treasury Constant Maturity (Daily)",  # reemplaza a GS10
    "STLFSI2":   "St. Louis Fed Financial Stress Index (v2)",

    # Curva/expectativas
    "DGS2":      "2-Year Treasury Constant Maturity",
    "T10Y3M":    "10Y Minus 3M Treasury Spread",
    "T10Y2Y":    "10Y Minus 2Y Treasury Spread",
    "DFII10":    "10-Year TIPS Yield (Real)",
    "T5YIE":     "5-Year Breakeven Inflation",
    "THREEFYTP10": "Kim-Wright 10Y Zero-Coupon Term Premium",  # en lugar de ACMTP10

    # Crédito / estrés
    "BAMLH0A0HYM2": "ICE BofA US High Yield Index Option-Adjusted Spread",  # en lugar de ...OAS
    "BAA10Y":       "Moody's BAA Corporate - 10Y Treasury Spread",
    "NFCI":         "Chicago Fed National Financial Conditions Index",
    "ANFCI":        "Adjusted NFCI",
    "TEDRATE":      "TED Spread",

    # Volatilidad y risk-on/off
    "VIXCLS":    "CBOE VIX Close",

    # Dólar y commodities
    "DTWEXBGS":  "Trade-Weighted U.S. Dollar Index: Broad",
    "DCOILWTICO":"Crude Oil WTI Spot Price",

    # Actividad / empleo / sentimiento
    "INDPRO":    "Industrial Production Index",
    "ICSA":      "Initial Claims, Unemployment Insurance (Weekly)",
    "PAYEMS":    "All Employees: Total Nonfarm",
    "UMCSENT":   "University of Michigan: Sentiment",

    # Vivienda
    "HOUST":     "Housing Starts: Total",
    "PERMIT":    "Building Permits: Total",

    # Liquidez / balance Fed
    "M2SL":      "M2 Money Stock",
    "WALCL":     "Total Assets, Federal Reserve"
}


START_DATE = "1992-01-01"         # fecha inicial para todas las series
END_DATE   = date.today().isoformat()  # fecha final dinámica (hoy)

# Rutas locales y prefijos en ADLS ---------------------------
RAW_DIR       = "data/raw/macros";  os.makedirs(RAW_DIR, exist_ok=True)
BRONZE_PREFIX = "bronze/macros"

# %% [markdown]
# ## 2. Descarga histórica, subida a ADLS y Chequeos rapido

# %%
# ================================================================
# 2.1  descarga histórica y subida a ADLS
# ================================================================

# -------------------------------------------------------------------------------
# - Descarga cada serie completa usando fredapi.
# - Guarda un Parquet en la carpeta RAW local.
# - Sube la misma copia a ADLS bajo raw/macros/.
# -------------------------------------------------------------------------------
def download_series(code: str) -> pd.DataFrame:
    ser = fred.get_series(code, observation_start=START_DATE, observation_end=END_DATE)
    df  = ser.to_frame("value").reset_index().rename(columns={"index": "date"})
    df["series"] = code
    return df

for code in SERIES:
    print("⏬", code)
    df = download_series(code)

    # 1a) guarda RAW local
    local_raw = f"{RAW_DIR}/{code}.parquet"
    df.to_parquet(local_raw, index=False)

    # 1b) sube RAW a ADLS
    with open(local_raw, "rb") as f:
        upload_bytes(f"raw/macros/{code}.parquet", f.read())
# Out:
# ⏬ FEDFUNDS
# ⏬ CPIAUCSL
# ⏬ UNRATE
# ⏬ GDP
# ⏬ DGS10
# ⏬ STLFSI2
# ⏬ DGS2
# ⏬ T10Y3M
# ⏬ T10Y2Y
# ⏬ DFII10
# ⏬ T5YIE
# ⏬ THREEFYTP10
# ⏬ BAMLH0A0HYM2
# ⏬ BAA10Y
# ⏬ NFCI
# ⏬ ANFCI
# ⏬ TEDRATE
# ⏬ VIXCLS
# ⏬ DTWEXBGS
# ⏬ DCOILWTICO
# ⏬ INDPRO
# ⏬ ICSA
# ⏬ PAYEMS
# ⏬ UMCSENT
# ⏬ HOUST
# ⏬ PERMIT
# ⏬ M2SL
# ⏬ WALCL

# %%
# ================================================================
# 2.2  Chequeos rapidos (EDA)
# ================================================================

# ----------------------------------------------------------------
# Combina todos los Parquet RAW y realiza:
#   - Cobertura temporal por serie (fecha mín, máx y nº observaciones).
#   - Porcentaje de valores nulos.
#   - Tamaño físico de cada archivo.
# Estos chequeos se imprimen / muestran en el notebook para validación inmediata.
# -----------------------------------------------------------------

dfs = [pd.read_parquet(f"{RAW_DIR}/{c}.parquet") for c in SERIES]
macro_df = pd.concat(dfs)

#  Cobertura temporal ---------------------------------------------
coverage = (
    macro_df.groupby("series")["date"]
            .agg(fecha_min=("min"), fecha_max=("max"), num_obs=("count"))
)
display(coverage)

# Valores nulos ---------------------------------------------------
nulls_pct = (macro_df.isna().mean() * 100).round(2)
print("NaNs (%):\n", nulls_pct)

# Tamaño de archivos ----------------------------------------------
sizes = {p.name: round(p.stat().st_size / 1_048_576, 2)
         for p in pathlib.Path(RAW_DIR).glob("*.parquet")}
print("Tamaños (MB):", sizes)
# Out:
#               fecha_min  fecha_max  num_obs
# series
# ANFCI        1992-01-03 2025-07-18     1751
# BAA10Y       1992-01-01 2025-07-24     8757
# BAMLH0A0HYM2 1996-12-31 2025-07-24     7549
# CPIAUCSL     1992-01-01 2025-06-01      402
# DCOILWTICO   1992-01-01 2025-07-21     8754
# DFII10       2003-01-02 2025-07-24     5886
# DGS10        1992-01-01 2025-07-24     8757
# DGS2         1992-01-01 2025-07-24     8757
# DTWEXBGS     2006-01-02 2025-07-18     5100
# FEDFUNDS     1992-01-01 2025-06-01      402
# GDP          1992-01-01 2025-01-01      133
# HOUST        1992-01-01 2025-06-01      402
# ICSA         1992-01-04 2025-07-19     1751
# INDPRO       1992-01-01 2025-06-01      402
# M2SL         1992-01-01 2025-06-01      402
# NFCI         1992-01-03 2025-07-18     1751
# PAYEMS       1992-01-01 2025-06-01      402
# PERMIT       1992-01-01 2025-06-01      402
# STLFSI2      1993-12-31 2022-01-07     1463
# T10Y2Y       1992-01-01 2025-07-25     8758
# T10Y3M       1992-01-01 2025-07-25     8758
# T5YIE        2003-01-02 2025-07-25     5887
# TEDRATE      1992-01-01 2022-01-21     7843
# THREEFYTP10  1992-01-01 2025-07-18     8753
# UMCSENT      1992-01-01 2025-05-01      401
# UNRATE       1992-01-01 2025-06-01      402
# VIXCLS       1992-01-01 2025-07-24     8757
# WALCL        2002-12-18 2025-07-23     1180
# NaNs (%):
#  date      0.00
# value     3.55
# series    0.00
# dtype: float64
# Tamaños (MB): {'ANFCI.parquet': 0.03, 'BAA10Y.parquet': 0.09, 'BAMLH0A0HYM2.parquet': 0.08, 'CPIAUCSL.parquet': 0.01, 'DCOILWTICO.parquet': 0.11, 'DFII10.parquet': 0.06, 'DGS10.parquet': 0.09, 'DGS2.parquet': 0.09, 'DTWEXBGS.parquet': 0.08, 'FEDFUNDS.parquet': 0.01, 'GDP.parquet': 0.0, 'HOUST.parquet': 0.01, 'ICSA.parquet': 0.02, 'INDPRO.parquet': 0.01, 'M2SL.parquet': 0.01, 'NFCI.parquet': 0.03, 'PAYEMS.parquet': 0.01, 'PERMIT.parquet': 0.01, 'STLFSI2.parquet': 0.03, 'T10Y2Y.parquet': 0.09, 'T10Y3M.parquet': 0.09, 'T5YIE.parquet': 0.06, 'TEDRATE.parquet': 0.08, 'THREEFYTP10.parquet': 0.13, 'UMCSENT.parquet': 0.01, 'UNRATE.parquet': 0.01, 'VIXCLS.parquet': 0.1, 'WALCL.parquet': 0.02}

# %% [markdown]
# # Etapa Bronze

# %% [markdown]
# ## 3. Ingesta inicial (histórico completo) -> Azure Data Lake Storage y registro en Logs

# %%
# ================================================================
# 3.1 Ingesta inicial en Bronze, solo se debe ejecutar una vez como carga inicial
# ================================================================

# ----------------------------------------------------------------
# Convierte el histórico descargado en la *capa Bronze*:
#   • Añade columnas de metadatos (`year`, `ingest_ts`, `source`).
#   • Particiona por año (year=YYYY) y sube cada partición a ADLS.
#   • Este bloque debe correrse una sola vez para poblar todo el histórico.
# ---------------------------------------------------------------

for code in SERIES:
    df = pd.read_parquet(f"{RAW_DIR}/{code}.parquet")
    
    # Agrega columnas de metadatos ------------------------------
    df["year"] = pd.to_datetime(df["date"]).dt.year
    df["ingest_ts"] = pd.Timestamp.utcnow().isoformat()
    df["source"]    = "FRED"

     # Sube cada año como Parquet independiente -----------------
    for yr, sub in df.groupby("year"):
        buf = io.BytesIO(); sub.to_parquet(buf, index=False); buf.seek(0)
        remote = f"{BRONZE_PREFIX}/{code}/year={yr}/{code}_{yr}.parquet"
        upload_bytes(remote, buf.read())                 # overwrite=True
        print(f"▲ {code} {yr} -> {remote}  ({len(sub)} filas)")
# Out:
# ▲ FEDFUNDS 1992 -> bronze/macros/FEDFUNDS/year=1992/FEDFUNDS_1992.parquet  (12 filas)
# ▲ FEDFUNDS 1993 -> bronze/macros/FEDFUNDS/year=1993/FEDFUNDS_1993.parquet  (12 filas)
# ▲ FEDFUNDS 1994 -> bronze/macros/FEDFUNDS/year=1994/FEDFUNDS_1994.parquet  (12 filas)
# ▲ FEDFUNDS 1995 -> bronze/macros/FEDFUNDS/year=1995/FEDFUNDS_1995.parquet  (12 filas)
# ▲ FEDFUNDS 1996 -> bronze/macros/FEDFUNDS/year=1996/FEDFUNDS_1996.parquet  (12 filas)
# ▲ FEDFUNDS 1997 -> bronze/macros/FEDFUNDS/year=1997/FEDFUNDS_1997.parquet  (12 filas)
# ▲ FEDFUNDS 1998 -> bronze/macros/FEDFUNDS/year=1998/FEDFUNDS_1998.parquet  (12 filas)
# ▲ FEDFUNDS 1999 -> bronze/macros/FEDFUNDS/year=1999/FEDFUNDS_1999.parquet  (12 filas)
# ▲ FEDFUNDS 2000 -> bronze/macros/FEDFUNDS/year=2000/FEDFUNDS_2000.parquet  (12 filas)
# ▲ FEDFUNDS 2001 -> bronze/macros/FEDFUNDS/year=2001/FEDFUNDS_2001.parquet  (12 filas)
# ▲ FEDFUNDS 2002 -> bronze/macros/FEDFUNDS/year=2002/FEDFUNDS_2002.parquet  (12 filas)
# ▲ FEDFUNDS 2003 -> bronze/macros/FEDFUNDS/year=2003/FEDFUNDS_2003.parquet  (12 filas)
# ▲ FEDFUNDS 2004 -> bronze/macros/FEDFUNDS/year=2004/FEDFUNDS_2004.parquet  (12 filas)
# ▲ FEDFUNDS 2005 -> bronze/macros/FEDFUNDS/year=2005/FEDFUNDS_2005.parquet  (12 filas)
# ▲ FEDFUNDS 2006 -> bronze/macros/FEDFUNDS/year=2006/FEDFUNDS_2006.parquet  (12 filas)
# ▲ FEDFUNDS 2007 -> bronze/macros/FEDFUNDS/year=2007/FEDFUNDS_2007.parquet  (12 filas)
# ▲ FEDFUNDS 2008 -> bronze/macros/FEDFUNDS/year=2008/FEDFUNDS_2008.parquet  (12 filas)
# ▲ FEDFUNDS 2009 -> bronze/macros/FEDFUNDS/year=2009/FEDFUNDS_2009.parquet  (12 filas)
# ▲ FEDFUNDS 2010 -> bronze/macros/FEDFUNDS/year=2010/FEDFUNDS_2010.parquet  (12 filas)
# ▲ FEDFUNDS 2011 -> bronze/macros/FEDFUNDS/year=2011/FEDFUNDS_2011.parquet  (12 filas)
# ▲ FEDFUNDS 2012 -> bronze/macros/FEDFUNDS/year=2012/FEDFUNDS_2012.parquet  (12 filas)
# ▲ FEDFUNDS 2013 -> bronze/macros/FEDFUNDS/year=2013/FEDFUNDS_2013.parquet  (12 filas)
# ▲ FEDFUNDS 2014 -> bronze/macros/FEDFUNDS/year=2014/FEDFUNDS_2014.parquet  (12 filas)
# ▲ FEDFUNDS 2015 -> bronze/macros/FEDFUNDS/year=2015/FEDFUNDS_2015.parquet  (12 filas)
# ▲ FEDFUNDS 2016 -> bronze/macros/FEDFUNDS/year=2016/FEDFUNDS_2016.parquet  (12 filas)
# ▲ FEDFUNDS 2017 -> bronze/macros/FEDFUNDS/year=2017/FEDFUNDS_2017.parquet  (12 filas)
# ▲ FEDFUNDS 2018 -> bronze/macros/FEDFUNDS/year=2018/FEDFUNDS_2018.parquet  (12 filas)
# ▲ FEDFUNDS 2019 -> bronze/macros/FEDFUNDS/year=2019/FEDFUNDS_2019.parquet  (12 filas)
# ▲ FEDFUNDS 2020 -> bronze/macros/FEDFUNDS/year=2020/FEDFUNDS_2020.parquet  (12 filas)
# ▲ FEDFUNDS 2021 -> bronze/macros/FEDFUNDS/year=2021/FEDFUNDS_2021.parquet  (12 filas)
# ▲ FEDFUNDS 2022 -> bronze/macros/FEDFUNDS/year=2022/FEDFUNDS_2022.parquet  (12 filas)
# ▲ FEDFUNDS 2023 -> bronze/macros/FEDFUNDS/year=2023/FEDFUNDS_2023.parquet  (12 filas)
# ▲ FEDFUNDS 2024 -> bronze/macros/FEDFUNDS/year=2024/FEDFUNDS_2024.parquet  (12 filas)
# ▲ FEDFUNDS 2025 -> bronze/macros/FEDFUNDS/year=2025/FEDFUNDS_2025.parquet  (6 filas)
# ▲ CPIAUCSL 1992 -> bronze/macros/CPIAUCSL/year=1992/CPIAUCSL_1992.parquet  (12 filas)
# ▲ CPIAUCSL 1993 -> bronze/macros/CPIAUCSL/year=1993/CPIAUCSL_1993.parquet  (12 filas)
# ▲ CPIAUCSL 1994 -> bronze/macros/CPIAUCSL/year=1994/CPIAUCSL_1994.parquet  (12 filas)
# ▲ CPIAUCSL 1995 -> bronze/macros/CPIAUCSL/year=1995/CPIAUCSL_1995.parquet  (12 filas)
# ▲ CPIAUCSL 1996 -> bronze/macros/CPIAUCSL/year=1996/CPIAUCSL_1996.parquet  (12 filas)
# ▲ CPIAUCSL 1997 -> bronze/macros/CPIAUCSL/year=1997/CPIAUCSL_1997.parquet  (12 filas)
# ▲ CPIAUCSL 1998 -> bronze/macros/CPIAUCSL/year=1998/CPIAUCSL_1998.parquet  (12 filas)
# ▲ CPIAUCSL 1999 -> bronze/macros/CPIAUCSL/year=1999/CPIAUCSL_1999.parquet  (12 filas)
# ▲ CPIAUCSL 2000 -> bronze/macros/CPIAUCSL/year=2000/CPIAUCSL_2000.parquet  (12 filas)
# ▲ CPIAUCSL 2001 -> bronze/macros/CPIAUCSL/year=2001/CPIAUCSL_2001.parquet  (12 filas)
# ▲ CPIAUCSL 2002 -> bronze/macros/CPIAUCSL/year=2002/CPIAUCSL_2002.parquet  (12 filas)
# ▲ CPIAUCSL 2003 -> bronze/macros/CPIAUCSL/year=2003/CPIAUCSL_2003.parquet  (12 filas)
# ▲ CPIAUCSL 2004 -> bronze/macros/CPIAUCSL/year=2004/CPIAUCSL_2004.parquet  (12 filas)
# ▲ CPIAUCSL 2005 -> bronze/macros/CPIAUCSL/year=2005/CPIAUCSL_2005.parquet  (12 filas)
# ▲ CPIAUCSL 2006 -> bronze/macros/CPIAUCSL/year=2006/CPIAUCSL_2006.parquet  (12 filas)
# ▲ CPIAUCSL 2007 -> bronze/macros/CPIAUCSL/year=2007/CPIAUCSL_2007.parquet  (12 filas)
# ▲ CPIAUCSL 2008 -> bronze/macros/CPIAUCSL/year=2008/CPIAUCSL_2008.parquet  (12 filas)
# ▲ CPIAUCSL 2009 -> bronze/macros/CPIAUCSL/year=2009/CPIAUCSL_2009.parquet  (12 filas)
# ▲ CPIAUCSL 2010 -> bronze/macros/CPIAUCSL/year=2010/CPIAUCSL_2010.parquet  (12 filas)
# ▲ CPIAUCSL 2011 -> bronze/macros/CPIAUCSL/year=2011/CPIAUCSL_2011.parquet  (12 filas)
# ▲ CPIAUCSL 2012 -> bronze/macros/CPIAUCSL/year=2012/CPIAUCSL_2012.parquet  (12 filas)
# ▲ CPIAUCSL 2013 -> bronze/macros/CPIAUCSL/year=2013/CPIAUCSL_2013.parquet  (12 filas)
# ▲ CPIAUCSL 2014 -> bronze/macros/CPIAUCSL/year=2014/CPIAUCSL_2014.parquet  (12 filas)
# ▲ CPIAUCSL 2015 -> bronze/macros/CPIAUCSL/year=2015/CPIAUCSL_2015.parquet  (12 filas)
# ▲ CPIAUCSL 2016 -> bronze/macros/CPIAUCSL/year=2016/CPIAUCSL_2016.parquet  (12 filas)
# ▲ CPIAUCSL 2017 -> bronze/macros/CPIAUCSL/year=2017/CPIAUCSL_2017.parquet  (12 filas)
# ▲ CPIAUCSL 2018 -> bronze/macros/CPIAUCSL/year=2018/CPIAUCSL_2018.parquet  (12 filas)
# ▲ CPIAUCSL 2019 -> bronze/macros/CPIAUCSL/year=2019/CPIAUCSL_2019.parquet  (12 filas)
# ▲ CPIAUCSL 2020 -> bronze/macros/CPIAUCSL/year=2020/CPIAUCSL_2020.parquet  (12 filas)
# ▲ CPIAUCSL 2021 -> bronze/macros/CPIAUCSL/year=2021/CPIAUCSL_2021.parquet  (12 filas)
# ▲ CPIAUCSL 2022 -> bronze/macros/CPIAUCSL/year=2022/CPIAUCSL_2022.parquet  (12 filas)
# ▲ CPIAUCSL 2023 -> bronze/macros/CPIAUCSL/year=2023/CPIAUCSL_2023.parquet  (12 filas)
# ▲ CPIAUCSL 2024 -> bronze/macros/CPIAUCSL/year=2024/CPIAUCSL_2024.parquet  (12 filas)
# ▲ CPIAUCSL 2025 -> bronze/macros/CPIAUCSL/year=2025/CPIAUCSL_2025.parquet  (6 filas)
# ▲ UNRATE 1992 -> bronze/macros/UNRATE/year=1992/UNRATE_1992.parquet  (12 filas)
# ▲ UNRATE 1993 -> bronze/macros/UNRATE/year=1993/UNRATE_1993.parquet  (12 filas)
# ▲ UNRATE 1994 -> bronze/macros/UNRATE/year=1994/UNRATE_1994.parquet  (12 filas)
# ▲ UNRATE 1995 -> bronze/macros/UNRATE/year=1995/UNRATE_1995.parquet  (12 filas)
# ▲ UNRATE 1996 -> bronze/macros/UNRATE/year=1996/UNRATE_1996.parquet  (12 filas)
# ▲ UNRATE 1997 -> bronze/macros/UNRATE/year=1997/UNRATE_1997.parquet  (12 filas)
# ▲ UNRATE 1998 -> bronze/macros/UNRATE/year=1998/UNRATE_1998.parquet  (12 filas)
# ▲ UNRATE 1999 -> bronze/macros/UNRATE/year=1999/UNRATE_1999.parquet  (12 filas)
# ▲ UNRATE 2000 -> bronze/macros/UNRATE/year=2000/UNRATE_2000.parquet  (12 filas)
# ▲ UNRATE 2001 -> bronze/macros/UNRATE/year=2001/UNRATE_2001.parquet  (12 filas)
# ▲ UNRATE 2002 -> bronze/macros/UNRATE/year=2002/UNRATE_2002.parquet  (12 filas)
# ▲ UNRATE 2003 -> bronze/macros/UNRATE/year=2003/UNRATE_2003.parquet  (12 filas)
# ▲ UNRATE 2004 -> bronze/macros/UNRATE/year=2004/UNRATE_2004.parquet  (12 filas)
# ▲ UNRATE 2005 -> bronze/macros/UNRATE/year=2005/UNRATE_2005.parquet  (12 filas)
# ▲ UNRATE 2006 -> bronze/macros/UNRATE/year=2006/UNRATE_2006.parquet  (12 filas)
# ▲ UNRATE 2007 -> bronze/macros/UNRATE/year=2007/UNRATE_2007.parquet  (12 filas)
# ▲ UNRATE 2008 -> bronze/macros/UNRATE/year=2008/UNRATE_2008.parquet  (12 filas)
# ▲ UNRATE 2009 -> bronze/macros/UNRATE/year=2009/UNRATE_2009.parquet  (12 filas)
# ▲ UNRATE 2010 -> bronze/macros/UNRATE/year=2010/UNRATE_2010.parquet  (12 filas)
# ▲ UNRATE 2011 -> bronze/macros/UNRATE/year=2011/UNRATE_2011.parquet  (12 filas)
# ▲ UNRATE 2012 -> bronze/macros/UNRATE/year=2012/UNRATE_2012.parquet  (12 filas)
# ▲ UNRATE 2013 -> bronze/macros/UNRATE/year=2013/UNRATE_2013.parquet  (12 filas)
# ▲ UNRATE 2014 -> bronze/macros/UNRATE/year=2014/UNRATE_2014.parquet  (12 filas)
# ▲ UNRATE 2015 -> bronze/macros/UNRATE/year=2015/UNRATE_2015.parquet  (12 filas)
# ▲ UNRATE 2016 -> bronze/macros/UNRATE/year=2016/UNRATE_2016.parquet  (12 filas)
# ▲ UNRATE 2017 -> bronze/macros/UNRATE/year=2017/UNRATE_2017.parquet  (12 filas)
# ▲ UNRATE 2018 -> bronze/macros/UNRATE/year=2018/UNRATE_2018.parquet  (12 filas)
# ▲ UNRATE 2019 -> bronze/macros/UNRATE/year=2019/UNRATE_2019.parquet  (12 filas)
# ▲ UNRATE 2020 -> bronze/macros/UNRATE/year=2020/UNRATE_2020.parquet  (12 filas)
# ▲ UNRATE 2021 -> bronze/macros/UNRATE/year=2021/UNRATE_2021.parquet  (12 filas)
# ▲ UNRATE 2022 -> bronze/macros/UNRATE/year=2022/UNRATE_2022.parquet  (12 filas)
# ▲ UNRATE 2023 -> bronze/macros/UNRATE/year=2023/UNRATE_2023.parquet  (12 filas)
# ▲ UNRATE 2024 -> bronze/macros/UNRATE/year=2024/UNRATE_2024.parquet  (12 filas)
# ▲ UNRATE 2025 -> bronze/macros/UNRATE/year=2025/UNRATE_2025.parquet  (6 filas)
# ▲ GDP 1992 -> bronze/macros/GDP/year=1992/GDP_1992.parquet  (4 filas)
# ▲ GDP 1993 -> bronze/macros/GDP/year=1993/GDP_1993.parquet  (4 filas)
# ▲ GDP 1994 -> bronze/macros/GDP/year=1994/GDP_1994.parquet  (4 filas)
# ▲ GDP 1995 -> bronze/macros/GDP/year=1995/GDP_1995.parquet  (4 filas)
# ▲ GDP 1996 -> bronze/macros/GDP/year=1996/GDP_1996.parquet  (4 filas)
# ▲ GDP 1997 -> bronze/macros/GDP/year=1997/GDP_1997.parquet  (4 filas)
# ▲ GDP 1998 -> bronze/macros/GDP/year=1998/GDP_1998.parquet  (4 filas)
# ▲ GDP 1999 -> bronze/macros/GDP/year=1999/GDP_1999.parquet  (4 filas)
# ▲ GDP 2000 -> bronze/macros/GDP/year=2000/GDP_2000.parquet  (4 filas)
# ▲ GDP 2001 -> bronze/macros/GDP/year=2001/GDP_2001.parquet  (4 filas)
# ▲ GDP 2002 -> bronze/macros/GDP/year=2002/GDP_2002.parquet  (4 filas)
# ▲ GDP 2003 -> bronze/macros/GDP/year=2003/GDP_2003.parquet  (4 filas)
# ▲ GDP 2004 -> bronze/macros/GDP/year=2004/GDP_2004.parquet  (4 filas)
# ▲ GDP 2005 -> bronze/macros/GDP/year=2005/GDP_2005.parquet  (4 filas)
# ▲ GDP 2006 -> bronze/macros/GDP/year=2006/GDP_2006.parquet  (4 filas)
# ▲ GDP 2007 -> bronze/macros/GDP/year=2007/GDP_2007.parquet  (4 filas)
# ▲ GDP 2008 -> bronze/macros/GDP/year=2008/GDP_2008.parquet  (4 filas)
# ▲ GDP 2009 -> bronze/macros/GDP/year=2009/GDP_2009.parquet  (4 filas)
# ▲ GDP 2010 -> bronze/macros/GDP/year=2010/GDP_2010.parquet  (4 filas)
# ▲ GDP 2011 -> bronze/macros/GDP/year=2011/GDP_2011.parquet  (4 filas)
# ▲ GDP 2012 -> bronze/macros/GDP/year=2012/GDP_2012.parquet  (4 filas)
# ▲ GDP 2013 -> bronze/macros/GDP/year=2013/GDP_2013.parquet  (4 filas)
# ▲ GDP 2014 -> bronze/macros/GDP/year=2014/GDP_2014.parquet  (4 filas)
# ▲ GDP 2015 -> bronze/macros/GDP/year=2015/GDP_2015.parquet  (4 filas)
# ▲ GDP 2016 -> bronze/macros/GDP/year=2016/GDP_2016.parquet  (4 filas)
# ▲ GDP 2017 -> bronze/macros/GDP/year=2017/GDP_2017.parquet  (4 filas)
# ▲ GDP 2018 -> bronze/macros/GDP/year=2018/GDP_2018.parquet  (4 filas)
# ▲ GDP 2019 -> bronze/macros/GDP/year=2019/GDP_2019.parquet  (4 filas)
# ▲ GDP 2020 -> bronze/macros/GDP/year=2020/GDP_2020.parquet  (4 filas)
# ▲ GDP 2021 -> bronze/macros/GDP/year=2021/GDP_2021.parquet  (4 filas)
# ▲ GDP 2022 -> bronze/macros/GDP/year=2022/GDP_2022.parquet  (4 filas)
# ▲ GDP 2023 -> bronze/macros/GDP/year=2023/GDP_2023.parquet  (4 filas)
# ▲ GDP 2024 -> bronze/macros/GDP/year=2024/GDP_2024.parquet  (4 filas)
# ▲ GDP 2025 -> bronze/macros/GDP/year=2025/GDP_2025.parquet  (1 filas)
# ▲ DGS10 1992 -> bronze/macros/DGS10/year=1992/DGS10_1992.parquet  (262 filas)
# ▲ DGS10 1993 -> bronze/macros/DGS10/year=1993/DGS10_1993.parquet  (261 filas)
# ▲ DGS10 1994 -> bronze/macros/DGS10/year=1994/DGS10_1994.parquet  (260 filas)
# ▲ DGS10 1995 -> bronze/macros/DGS10/year=1995/DGS10_1995.parquet  (260 filas)
# ▲ DGS10 1996 -> bronze/macros/DGS10/year=1996/DGS10_1996.parquet  (262 filas)
# ▲ DGS10 1997 -> bronze/macros/DGS10/year=1997/DGS10_1997.parquet  (261 filas)
# ▲ DGS10 1998 -> bronze/macros/DGS10/year=1998/DGS10_1998.parquet  (261 filas)
# ▲ DGS10 1999 -> bronze/macros/DGS10/year=1999/DGS10_1999.parquet  (261 filas)
# ▲ DGS10 2000 -> bronze/macros/DGS10/year=2000/DGS10_2000.parquet  (260 filas)
# ▲ DGS10 2001 -> bronze/macros/DGS10/year=2001/DGS10_2001.parquet  (261 filas)
# ▲ DGS10 2002 -> bronze/macros/DGS10/year=2002/DGS10_2002.parquet  (261 filas)
# ▲ DGS10 2003 -> bronze/macros/DGS10/year=2003/DGS10_2003.parquet  (261 filas)
# ▲ DGS10 2004 -> bronze/macros/DGS10/year=2004/DGS10_2004.parquet  (262 filas)
# ▲ DGS10 2005 -> bronze/macros/DGS10/year=2005/DGS10_2005.parquet  (260 filas)
# ▲ DGS10 2006 -> bronze/macros/DGS10/year=2006/DGS10_2006.parquet  (260 filas)
# ▲ DGS10 2007 -> bronze/macros/DGS10/year=2007/DGS10_2007.parquet  (261 filas)
# ▲ DGS10 2008 -> bronze/macros/DGS10/year=2008/DGS10_2008.parquet  (262 filas)
# ▲ DGS10 2009 -> bronze/macros/DGS10/year=2009/DGS10_2009.parquet  (261 filas)
# ▲ DGS10 2010 -> bronze/macros/DGS10/year=2010/DGS10_2010.parquet  (261 filas)
# ▲ DGS10 2011 -> bronze/macros/DGS10/year=2011/DGS10_2011.parquet  (260 filas)
# ▲ DGS10 2012 -> bronze/macros/DGS10/year=2012/DGS10_2012.parquet  (261 filas)
# ▲ DGS10 2013 -> bronze/macros/DGS10/year=2013/DGS10_2013.parquet  (261 filas)
# ▲ DGS10 2014 -> bronze/macros/DGS10/year=2014/DGS10_2014.parquet  (261 filas)
# ▲ DGS10 2015 -> bronze/macros/DGS10/year=2015/DGS10_2015.parquet  (261 filas)
# ▲ DGS10 2016 -> bronze/macros/DGS10/year=2016/DGS10_2016.parquet  (261 filas)
# ▲ DGS10 2017 -> bronze/macros/DGS10/year=2017/DGS10_2017.parquet  (260 filas)
# ▲ DGS10 2018 -> bronze/macros/DGS10/year=2018/DGS10_2018.parquet  (261 filas)
# ▲ DGS10 2019 -> bronze/macros/DGS10/year=2019/DGS10_2019.parquet  (261 filas)
# ▲ DGS10 2020 -> bronze/macros/DGS10/year=2020/DGS10_2020.parquet  (262 filas)
# ▲ DGS10 2021 -> bronze/macros/DGS10/year=2021/DGS10_2021.parquet  (261 filas)
# ▲ DGS10 2022 -> bronze/macros/DGS10/year=2022/DGS10_2022.parquet  (260 filas)
# ▲ DGS10 2023 -> bronze/macros/DGS10/year=2023/DGS10_2023.parquet  (260 filas)
# ▲ DGS10 2024 -> bronze/macros/DGS10/year=2024/DGS10_2024.parquet  (262 filas)
# ▲ DGS10 2025 -> bronze/macros/DGS10/year=2025/DGS10_2025.parquet  (147 filas)
# ▲ STLFSI2 1993 -> bronze/macros/STLFSI2/year=1993/STLFSI2_1993.parquet  (1 filas)
# ▲ STLFSI2 1994 -> bronze/macros/STLFSI2/year=1994/STLFSI2_1994.parquet  (52 filas)
# ▲ STLFSI2 1995 -> bronze/macros/STLFSI2/year=1995/STLFSI2_1995.parquet  (52 filas)
# ▲ STLFSI2 1996 -> bronze/macros/STLFSI2/year=1996/STLFSI2_1996.parquet  (52 filas)
# ▲ STLFSI2 1997 -> bronze/macros/STLFSI2/year=1997/STLFSI2_1997.parquet  (52 filas)
# ▲ STLFSI2 1998 -> bronze/macros/STLFSI2/year=1998/STLFSI2_1998.parquet  (52 filas)
# ▲ STLFSI2 1999 -> bronze/macros/STLFSI2/year=1999/STLFSI2_1999.parquet  (53 filas)
# ▲ STLFSI2 2000 -> bronze/macros/STLFSI2/year=2000/STLFSI2_2000.parquet  (52 filas)
# ▲ STLFSI2 2001 -> bronze/macros/STLFSI2/year=2001/STLFSI2_2001.parquet  (52 filas)
# ▲ STLFSI2 2002 -> bronze/macros/STLFSI2/year=2002/STLFSI2_2002.parquet  (52 filas)
# ▲ STLFSI2 2003 -> bronze/macros/STLFSI2/year=2003/STLFSI2_2003.parquet  (52 filas)
# ▲ STLFSI2 2004 -> bronze/macros/STLFSI2/year=2004/STLFSI2_2004.parquet  (53 filas)
# ▲ STLFSI2 2005 -> bronze/macros/STLFSI2/year=2005/STLFSI2_2005.parquet  (52 filas)
# ▲ STLFSI2 2006 -> bronze/macros/STLFSI2/year=2006/STLFSI2_2006.parquet  (52 filas)
# ▲ STLFSI2 2007 -> bronze/macros/STLFSI2/year=2007/STLFSI2_2007.parquet  (52 filas)
# ▲ STLFSI2 2008 -> bronze/macros/STLFSI2/year=2008/STLFSI2_2008.parquet  (52 filas)
# ▲ STLFSI2 2009 -> bronze/macros/STLFSI2/year=2009/STLFSI2_2009.parquet  (52 filas)
# ▲ STLFSI2 2010 -> bronze/macros/STLFSI2/year=2010/STLFSI2_2010.parquet  (53 filas)
# ▲ STLFSI2 2011 -> bronze/macros/STLFSI2/year=2011/STLFSI2_2011.parquet  (52 filas)
# ▲ STLFSI2 2012 -> bronze/macros/STLFSI2/year=2012/STLFSI2_2012.parquet  (52 filas)
# ▲ STLFSI2 2013 -> bronze/macros/STLFSI2/year=2013/STLFSI2_2013.parquet  (52 filas)
# ▲ STLFSI2 2014 -> bronze/macros/STLFSI2/year=2014/STLFSI2_2014.parquet  (52 filas)
# ▲ STLFSI2 2015 -> bronze/macros/STLFSI2/year=2015/STLFSI2_2015.parquet  (52 filas)
# ▲ STLFSI2 2016 -> bronze/macros/STLFSI2/year=2016/STLFSI2_2016.parquet  (53 filas)
# ▲ STLFSI2 2017 -> bronze/macros/STLFSI2/year=2017/STLFSI2_2017.parquet  (52 filas)
# ▲ STLFSI2 2018 -> bronze/macros/STLFSI2/year=2018/STLFSI2_2018.parquet  (52 filas)
# ▲ STLFSI2 2019 -> bronze/macros/STLFSI2/year=2019/STLFSI2_2019.parquet  (52 filas)
# ▲ STLFSI2 2020 -> bronze/macros/STLFSI2/year=2020/STLFSI2_2020.parquet  (52 filas)
# ▲ STLFSI2 2021 -> bronze/macros/STLFSI2/year=2021/STLFSI2_2021.parquet  (53 filas)
# ▲ STLFSI2 2022 -> bronze/macros/STLFSI2/year=2022/STLFSI2_2022.parquet  (1 filas)
# ▲ DGS2 1992 -> bronze/macros/DGS2/year=1992/DGS2_1992.parquet  (262 filas)
# ▲ DGS2 1993 -> bronze/macros/DGS2/year=1993/DGS2_1993.parquet  (261 filas)
# ▲ DGS2 1994 -> bronze/macros/DGS2/year=1994/DGS2_1994.parquet  (260 filas)
# ▲ DGS2 1995 -> bronze/macros/DGS2/year=1995/DGS2_1995.parquet  (260 filas)
# ▲ DGS2 1996 -> bronze/macros/DGS2/year=1996/DGS2_1996.parquet  (262 filas)
# ▲ DGS2 1997 -> bronze/macros/DGS2/year=1997/DGS2_1997.parquet  (261 filas)
# ▲ DGS2 1998 -> bronze/macros/DGS2/year=1998/DGS2_1998.parquet  (261 filas)
# ▲ DGS2 1999 -> bronze/macros/DGS2/year=1999/DGS2_1999.parquet  (261 filas)
# ▲ DGS2 2000 -> bronze/macros/DGS2/year=2000/DGS2_2000.parquet  (260 filas)
# ▲ DGS2 2001 -> bronze/macros/DGS2/year=2001/DGS2_2001.parquet  (261 filas)
# ▲ DGS2 2002 -> bronze/macros/DGS2/year=2002/DGS2_2002.parquet  (261 filas)
# ▲ DGS2 2003 -> bronze/macros/DGS2/year=2003/DGS2_2003.parquet  (261 filas)
# ▲ DGS2 2004 -> bronze/macros/DGS2/year=2004/DGS2_2004.parquet  (262 filas)
# ▲ DGS2 2005 -> bronze/macros/DGS2/year=2005/DGS2_2005.parquet  (260 filas)
# ▲ DGS2 2006 -> bronze/macros/DGS2/year=2006/DGS2_2006.parquet  (260 filas)
# ▲ DGS2 2007 -> bronze/macros/DGS2/year=2007/DGS2_2007.parquet  (261 filas)
# ▲ DGS2 2008 -> bronze/macros/DGS2/year=2008/DGS2_2008.parquet  (262 filas)
# ▲ DGS2 2009 -> bronze/macros/DGS2/year=2009/DGS2_2009.parquet  (261 filas)
# ▲ DGS2 2010 -> bronze/macros/DGS2/year=2010/DGS2_2010.parquet  (261 filas)
# ▲ DGS2 2011 -> bronze/macros/DGS2/year=2011/DGS2_2011.parquet  (260 filas)
# ▲ DGS2 2012 -> bronze/macros/DGS2/year=2012/DGS2_2012.parquet  (261 filas)
# ▲ DGS2 2013 -> bronze/macros/DGS2/year=2013/DGS2_2013.parquet  (261 filas)
# ▲ DGS2 2014 -> bronze/macros/DGS2/year=2014/DGS2_2014.parquet  (261 filas)
# ▲ DGS2 2015 -> bronze/macros/DGS2/year=2015/DGS2_2015.parquet  (261 filas)
# ▲ DGS2 2016 -> bronze/macros/DGS2/year=2016/DGS2_2016.parquet  (261 filas)
# ▲ DGS2 2017 -> bronze/macros/DGS2/year=2017/DGS2_2017.parquet  (260 filas)
# ▲ DGS2 2018 -> bronze/macros/DGS2/year=2018/DGS2_2018.parquet  (261 filas)
# ▲ DGS2 2019 -> bronze/macros/DGS2/year=2019/DGS2_2019.parquet  (261 filas)
# ▲ DGS2 2020 -> bronze/macros/DGS2/year=2020/DGS2_2020.parquet  (262 filas)
# ▲ DGS2 2021 -> bronze/macros/DGS2/year=2021/DGS2_2021.parquet  (261 filas)
# ▲ DGS2 2022 -> bronze/macros/DGS2/year=2022/DGS2_2022.parquet  (260 filas)
# ▲ DGS2 2023 -> bronze/macros/DGS2/year=2023/DGS2_2023.parquet  (260 filas)
# ▲ DGS2 2024 -> bronze/macros/DGS2/year=2024/DGS2_2024.parquet  (262 filas)
# ▲ DGS2 2025 -> bronze/macros/DGS2/year=2025/DGS2_2025.parquet  (147 filas)
# ▲ T10Y3M 1992 -> bronze/macros/T10Y3M/year=1992/T10Y3M_1992.parquet  (262 filas)
# ▲ T10Y3M 1993 -> bronze/macros/T10Y3M/year=1993/T10Y3M_1993.parquet  (261 filas)
# ▲ T10Y3M 1994 -> bronze/macros/T10Y3M/year=1994/T10Y3M_1994.parquet  (260 filas)
# ▲ T10Y3M 1995 -> bronze/macros/T10Y3M/year=1995/T10Y3M_1995.parquet  (260 filas)
# ▲ T10Y3M 1996 -> bronze/macros/T10Y3M/year=1996/T10Y3M_1996.parquet  (262 filas)
# ▲ T10Y3M 1997 -> bronze/macros/T10Y3M/year=1997/T10Y3M_1997.parquet  (261 filas)
# ▲ T10Y3M 1998 -> bronze/macros/T10Y3M/year=1998/T10Y3M_1998.parquet  (261 filas)
# ▲ T10Y3M 1999 -> bronze/macros/T10Y3M/year=1999/T10Y3M_1999.parquet  (261 filas)
# ▲ T10Y3M 2000 -> bronze/macros/T10Y3M/year=2000/T10Y3M_2000.parquet  (260 filas)
# ▲ T10Y3M 2001 -> bronze/macros/T10Y3M/year=2001/T10Y3M_2001.parquet  (261 filas)
# ▲ T10Y3M 2002 -> bronze/macros/T10Y3M/year=2002/T10Y3M_2002.parquet  (261 filas)
# ▲ T10Y3M 2003 -> bronze/macros/T10Y3M/year=2003/T10Y3M_2003.parquet  (261 filas)
# ▲ T10Y3M 2004 -> bronze/macros/T10Y3M/year=2004/T10Y3M_2004.parquet  (262 filas)
# ▲ T10Y3M 2005 -> bronze/macros/T10Y3M/year=2005/T10Y3M_2005.parquet  (260 filas)
# ▲ T10Y3M 2006 -> bronze/macros/T10Y3M/year=2006/T10Y3M_2006.parquet  (260 filas)
# ▲ T10Y3M 2007 -> bronze/macros/T10Y3M/year=2007/T10Y3M_2007.parquet  (261 filas)
# ▲ T10Y3M 2008 -> bronze/macros/T10Y3M/year=2008/T10Y3M_2008.parquet  (262 filas)
# ▲ T10Y3M 2009 -> bronze/macros/T10Y3M/year=2009/T10Y3M_2009.parquet  (261 filas)
# ▲ T10Y3M 2010 -> bronze/macros/T10Y3M/year=2010/T10Y3M_2010.parquet  (261 filas)
# ▲ T10Y3M 2011 -> bronze/macros/T10Y3M/year=2011/T10Y3M_2011.parquet  (260 filas)
# ▲ T10Y3M 2012 -> bronze/macros/T10Y3M/year=2012/T10Y3M_2012.parquet  (261 filas)
# ▲ T10Y3M 2013 -> bronze/macros/T10Y3M/year=2013/T10Y3M_2013.parquet  (261 filas)
# ▲ T10Y3M 2014 -> bronze/macros/T10Y3M/year=2014/T10Y3M_2014.parquet  (261 filas)
# ▲ T10Y3M 2015 -> bronze/macros/T10Y3M/year=2015/T10Y3M_2015.parquet  (261 filas)
# ▲ T10Y3M 2016 -> bronze/macros/T10Y3M/year=2016/T10Y3M_2016.parquet  (261 filas)
# ▲ T10Y3M 2017 -> bronze/macros/T10Y3M/year=2017/T10Y3M_2017.parquet  (260 filas)
# ▲ T10Y3M 2018 -> bronze/macros/T10Y3M/year=2018/T10Y3M_2018.parquet  (261 filas)
# ▲ T10Y3M 2019 -> bronze/macros/T10Y3M/year=2019/T10Y3M_2019.parquet  (261 filas)
# ▲ T10Y3M 2020 -> bronze/macros/T10Y3M/year=2020/T10Y3M_2020.parquet  (262 filas)
# ▲ T10Y3M 2021 -> bronze/macros/T10Y3M/year=2021/T10Y3M_2021.parquet  (261 filas)
# ▲ T10Y3M 2022 -> bronze/macros/T10Y3M/year=2022/T10Y3M_2022.parquet  (260 filas)
# ▲ T10Y3M 2023 -> bronze/macros/T10Y3M/year=2023/T10Y3M_2023.parquet  (260 filas)
# ▲ T10Y3M 2024 -> bronze/macros/T10Y3M/year=2024/T10Y3M_2024.parquet  (262 filas)
# ▲ T10Y3M 2025 -> bronze/macros/T10Y3M/year=2025/T10Y3M_2025.parquet  (148 filas)
# ▲ T10Y2Y 1992 -> bronze/macros/T10Y2Y/year=1992/T10Y2Y_1992.parquet  (262 filas)
# ▲ T10Y2Y 1993 -> bronze/macros/T10Y2Y/year=1993/T10Y2Y_1993.parquet  (261 filas)
# ▲ T10Y2Y 1994 -> bronze/macros/T10Y2Y/year=1994/T10Y2Y_1994.parquet  (260 filas)
# ▲ T10Y2Y 1995 -> bronze/macros/T10Y2Y/year=1995/T10Y2Y_1995.parquet  (260 filas)
# ▲ T10Y2Y 1996 -> bronze/macros/T10Y2Y/year=1996/T10Y2Y_1996.parquet  (262 filas)
# ▲ T10Y2Y 1997 -> bronze/macros/T10Y2Y/year=1997/T10Y2Y_1997.parquet  (261 filas)
# ▲ T10Y2Y 1998 -> bronze/macros/T10Y2Y/year=1998/T10Y2Y_1998.parquet  (261 filas)
# ▲ T10Y2Y 1999 -> bronze/macros/T10Y2Y/year=1999/T10Y2Y_1999.parquet  (261 filas)
# ▲ T10Y2Y 2000 -> bronze/macros/T10Y2Y/year=2000/T10Y2Y_2000.parquet  (260 filas)
# ▲ T10Y2Y 2001 -> bronze/macros/T10Y2Y/year=2001/T10Y2Y_2001.parquet  (261 filas)
# ▲ T10Y2Y 2002 -> bronze/macros/T10Y2Y/year=2002/T10Y2Y_2002.parquet  (261 filas)
# ▲ T10Y2Y 2003 -> bronze/macros/T10Y2Y/year=2003/T10Y2Y_2003.parquet  (261 filas)
# ▲ T10Y2Y 2004 -> bronze/macros/T10Y2Y/year=2004/T10Y2Y_2004.parquet  (262 filas)
# ▲ T10Y2Y 2005 -> bronze/macros/T10Y2Y/year=2005/T10Y2Y_2005.parquet  (260 filas)
# ▲ T10Y2Y 2006 -> bronze/macros/T10Y2Y/year=2006/T10Y2Y_2006.parquet  (260 filas)
# ▲ T10Y2Y 2007 -> bronze/macros/T10Y2Y/year=2007/T10Y2Y_2007.parquet  (261 filas)
# ▲ T10Y2Y 2008 -> bronze/macros/T10Y2Y/year=2008/T10Y2Y_2008.parquet  (262 filas)
# ▲ T10Y2Y 2009 -> bronze/macros/T10Y2Y/year=2009/T10Y2Y_2009.parquet  (261 filas)
# ▲ T10Y2Y 2010 -> bronze/macros/T10Y2Y/year=2010/T10Y2Y_2010.parquet  (261 filas)
# ▲ T10Y2Y 2011 -> bronze/macros/T10Y2Y/year=2011/T10Y2Y_2011.parquet  (260 filas)
# ▲ T10Y2Y 2012 -> bronze/macros/T10Y2Y/year=2012/T10Y2Y_2012.parquet  (261 filas)
# ▲ T10Y2Y 2013 -> bronze/macros/T10Y2Y/year=2013/T10Y2Y_2013.parquet  (261 filas)
# ▲ T10Y2Y 2014 -> bronze/macros/T10Y2Y/year=2014/T10Y2Y_2014.parquet  (261 filas)
# ▲ T10Y2Y 2015 -> bronze/macros/T10Y2Y/year=2015/T10Y2Y_2015.parquet  (261 filas)
# ▲ T10Y2Y 2016 -> bronze/macros/T10Y2Y/year=2016/T10Y2Y_2016.parquet  (261 filas)
# ▲ T10Y2Y 2017 -> bronze/macros/T10Y2Y/year=2017/T10Y2Y_2017.parquet  (260 filas)
# ▲ T10Y2Y 2018 -> bronze/macros/T10Y2Y/year=2018/T10Y2Y_2018.parquet  (261 filas)
# ▲ T10Y2Y 2019 -> bronze/macros/T10Y2Y/year=2019/T10Y2Y_2019.parquet  (261 filas)
# ▲ T10Y2Y 2020 -> bronze/macros/T10Y2Y/year=2020/T10Y2Y_2020.parquet  (262 filas)
# ▲ T10Y2Y 2021 -> bronze/macros/T10Y2Y/year=2021/T10Y2Y_2021.parquet  (261 filas)
# ▲ T10Y2Y 2022 -> bronze/macros/T10Y2Y/year=2022/T10Y2Y_2022.parquet  (260 filas)
# ▲ T10Y2Y 2023 -> bronze/macros/T10Y2Y/year=2023/T10Y2Y_2023.parquet  (260 filas)
# ▲ T10Y2Y 2024 -> bronze/macros/T10Y2Y/year=2024/T10Y2Y_2024.parquet  (262 filas)
# ▲ T10Y2Y 2025 -> bronze/macros/T10Y2Y/year=2025/T10Y2Y_2025.parquet  (148 filas)
# ▲ DFII10 2003 -> bronze/macros/DFII10/year=2003/DFII10_2003.parquet  (260 filas)
# ▲ DFII10 2004 -> bronze/macros/DFII10/year=2004/DFII10_2004.parquet  (262 filas)
# ▲ DFII10 2005 -> bronze/macros/DFII10/year=2005/DFII10_2005.parquet  (260 filas)
# ▲ DFII10 2006 -> bronze/macros/DFII10/year=2006/DFII10_2006.parquet  (260 filas)
# ▲ DFII10 2007 -> bronze/macros/DFII10/year=2007/DFII10_2007.parquet  (261 filas)
# ▲ DFII10 2008 -> bronze/macros/DFII10/year=2008/DFII10_2008.parquet  (262 filas)
# ▲ DFII10 2009 -> bronze/macros/DFII10/year=2009/DFII10_2009.parquet  (261 filas)
# ▲ DFII10 2010 -> bronze/macros/DFII10/year=2010/DFII10_2010.parquet  (261 filas)
# ▲ DFII10 2011 -> bronze/macros/DFII10/year=2011/DFII10_2011.parquet  (260 filas)
# ▲ DFII10 2012 -> bronze/macros/DFII10/year=2012/DFII10_2012.parquet  (261 filas)
# ▲ DFII10 2013 -> bronze/macros/DFII10/year=2013/DFII10_2013.parquet  (261 filas)
# ▲ DFII10 2014 -> bronze/macros/DFII10/year=2014/DFII10_2014.parquet  (261 filas)
# ▲ DFII10 2015 -> bronze/macros/DFII10/year=2015/DFII10_2015.parquet  (261 filas)
# ▲ DFII10 2016 -> bronze/macros/DFII10/year=2016/DFII10_2016.parquet  (261 filas)
# ▲ DFII10 2017 -> bronze/macros/DFII10/year=2017/DFII10_2017.parquet  (260 filas)
# ▲ DFII10 2018 -> bronze/macros/DFII10/year=2018/DFII10_2018.parquet  (261 filas)
# ▲ DFII10 2019 -> bronze/macros/DFII10/year=2019/DFII10_2019.parquet  (261 filas)
# ▲ DFII10 2020 -> bronze/macros/DFII10/year=2020/DFII10_2020.parquet  (262 filas)
# ▲ DFII10 2021 -> bronze/macros/DFII10/year=2021/DFII10_2021.parquet  (261 filas)
# ▲ DFII10 2022 -> bronze/macros/DFII10/year=2022/DFII10_2022.parquet  (260 filas)
# ▲ DFII10 2023 -> bronze/macros/DFII10/year=2023/DFII10_2023.parquet  (260 filas)
# ▲ DFII10 2024 -> bronze/macros/DFII10/year=2024/DFII10_2024.parquet  (262 filas)
# ▲ DFII10 2025 -> bronze/macros/DFII10/year=2025/DFII10_2025.parquet  (147 filas)
# ▲ T5YIE 2003 -> bronze/macros/T5YIE/year=2003/T5YIE_2003.parquet  (260 filas)
# ▲ T5YIE 2004 -> bronze/macros/T5YIE/year=2004/T5YIE_2004.parquet  (262 filas)
# ▲ T5YIE 2005 -> bronze/macros/T5YIE/year=2005/T5YIE_2005.parquet  (260 filas)
# ▲ T5YIE 2006 -> bronze/macros/T5YIE/year=2006/T5YIE_2006.parquet  (260 filas)
# ▲ T5YIE 2007 -> bronze/macros/T5YIE/year=2007/T5YIE_2007.parquet  (261 filas)
# ▲ T5YIE 2008 -> bronze/macros/T5YIE/year=2008/T5YIE_2008.parquet  (262 filas)
# ▲ T5YIE 2009 -> bronze/macros/T5YIE/year=2009/T5YIE_2009.parquet  (261 filas)
# ▲ T5YIE 2010 -> bronze/macros/T5YIE/year=2010/T5YIE_2010.parquet  (261 filas)
# ▲ T5YIE 2011 -> bronze/macros/T5YIE/year=2011/T5YIE_2011.parquet  (260 filas)
# ▲ T5YIE 2012 -> bronze/macros/T5YIE/year=2012/T5YIE_2012.parquet  (261 filas)
# ▲ T5YIE 2013 -> bronze/macros/T5YIE/year=2013/T5YIE_2013.parquet  (261 filas)
# ▲ T5YIE 2014 -> bronze/macros/T5YIE/year=2014/T5YIE_2014.parquet  (261 filas)
# ▲ T5YIE 2015 -> bronze/macros/T5YIE/year=2015/T5YIE_2015.parquet  (261 filas)
# ▲ T5YIE 2016 -> bronze/macros/T5YIE/year=2016/T5YIE_2016.parquet  (261 filas)
# ▲ T5YIE 2017 -> bronze/macros/T5YIE/year=2017/T5YIE_2017.parquet  (260 filas)
# ▲ T5YIE 2018 -> bronze/macros/T5YIE/year=2018/T5YIE_2018.parquet  (261 filas)
# ▲ T5YIE 2019 -> bronze/macros/T5YIE/year=2019/T5YIE_2019.parquet  (261 filas)
# ▲ T5YIE 2020 -> bronze/macros/T5YIE/year=2020/T5YIE_2020.parquet  (262 filas)
# ▲ T5YIE 2021 -> bronze/macros/T5YIE/year=2021/T5YIE_2021.parquet  (261 filas)
# ▲ T5YIE 2022 -> bronze/macros/T5YIE/year=2022/T5YIE_2022.parquet  (260 filas)
# ▲ T5YIE 2023 -> bronze/macros/T5YIE/year=2023/T5YIE_2023.parquet  (260 filas)
# ▲ T5YIE 2024 -> bronze/macros/T5YIE/year=2024/T5YIE_2024.parquet  (262 filas)
# ▲ T5YIE 2025 -> bronze/macros/T5YIE/year=2025/T5YIE_2025.parquet  (148 filas)
# ▲ THREEFYTP10 1992 -> bronze/macros/THREEFYTP10/year=1992/THREEFYTP10_1992.parquet  (262 filas)
# ▲ THREEFYTP10 1993 -> bronze/macros/THREEFYTP10/year=1993/THREEFYTP10_1993.parquet  (261 filas)
# ▲ THREEFYTP10 1994 -> bronze/macros/THREEFYTP10/year=1994/THREEFYTP10_1994.parquet  (260 filas)
# ▲ THREEFYTP10 1995 -> bronze/macros/THREEFYTP10/year=1995/THREEFYTP10_1995.parquet  (260 filas)
# ▲ THREEFYTP10 1996 -> bronze/macros/THREEFYTP10/year=1996/THREEFYTP10_1996.parquet  (262 filas)
# ▲ THREEFYTP10 1997 -> bronze/macros/THREEFYTP10/year=1997/THREEFYTP10_1997.parquet  (261 filas)
# ▲ THREEFYTP10 1998 -> bronze/macros/THREEFYTP10/year=1998/THREEFYTP10_1998.parquet  (261 filas)
# ▲ THREEFYTP10 1999 -> bronze/macros/THREEFYTP10/year=1999/THREEFYTP10_1999.parquet  (261 filas)
# ▲ THREEFYTP10 2000 -> bronze/macros/THREEFYTP10/year=2000/THREEFYTP10_2000.parquet  (260 filas)
# ▲ THREEFYTP10 2001 -> bronze/macros/THREEFYTP10/year=2001/THREEFYTP10_2001.parquet  (261 filas)
# ▲ THREEFYTP10 2002 -> bronze/macros/THREEFYTP10/year=2002/THREEFYTP10_2002.parquet  (261 filas)
# ▲ THREEFYTP10 2003 -> bronze/macros/THREEFYTP10/year=2003/THREEFYTP10_2003.parquet  (261 filas)
# ▲ THREEFYTP10 2004 -> bronze/macros/THREEFYTP10/year=2004/THREEFYTP10_2004.parquet  (262 filas)
# ▲ THREEFYTP10 2005 -> bronze/macros/THREEFYTP10/year=2005/THREEFYTP10_2005.parquet  (260 filas)
# ▲ THREEFYTP10 2006 -> bronze/macros/THREEFYTP10/year=2006/THREEFYTP10_2006.parquet  (260 filas)
# ▲ THREEFYTP10 2007 -> bronze/macros/THREEFYTP10/year=2007/THREEFYTP10_2007.parquet  (261 filas)
# ▲ THREEFYTP10 2008 -> bronze/macros/THREEFYTP10/year=2008/THREEFYTP10_2008.parquet  (262 filas)
# ▲ THREEFYTP10 2009 -> bronze/macros/THREEFYTP10/year=2009/THREEFYTP10_2009.parquet  (261 filas)
# ▲ THREEFYTP10 2010 -> bronze/macros/THREEFYTP10/year=2010/THREEFYTP10_2010.parquet  (261 filas)
# ▲ THREEFYTP10 2011 -> bronze/macros/THREEFYTP10/year=2011/THREEFYTP10_2011.parquet  (260 filas)
# ▲ THREEFYTP10 2012 -> bronze/macros/THREEFYTP10/year=2012/THREEFYTP10_2012.parquet  (261 filas)
# ▲ THREEFYTP10 2013 -> bronze/macros/THREEFYTP10/year=2013/THREEFYTP10_2013.parquet  (261 filas)
# ▲ THREEFYTP10 2014 -> bronze/macros/THREEFYTP10/year=2014/THREEFYTP10_2014.parquet  (261 filas)
# ▲ THREEFYTP10 2015 -> bronze/macros/THREEFYTP10/year=2015/THREEFYTP10_2015.parquet  (261 filas)
# ▲ THREEFYTP10 2016 -> bronze/macros/THREEFYTP10/year=2016/THREEFYTP10_2016.parquet  (261 filas)
# ▲ THREEFYTP10 2017 -> bronze/macros/THREEFYTP10/year=2017/THREEFYTP10_2017.parquet  (260 filas)
# ▲ THREEFYTP10 2018 -> bronze/macros/THREEFYTP10/year=2018/THREEFYTP10_2018.parquet  (261 filas)
# ▲ THREEFYTP10 2019 -> bronze/macros/THREEFYTP10/year=2019/THREEFYTP10_2019.parquet  (261 filas)
# ▲ THREEFYTP10 2020 -> bronze/macros/THREEFYTP10/year=2020/THREEFYTP10_2020.parquet  (262 filas)
# ▲ THREEFYTP10 2021 -> bronze/macros/THREEFYTP10/year=2021/THREEFYTP10_2021.parquet  (261 filas)
# ▲ THREEFYTP10 2022 -> bronze/macros/THREEFYTP10/year=2022/THREEFYTP10_2022.parquet  (260 filas)
# ▲ THREEFYTP10 2023 -> bronze/macros/THREEFYTP10/year=2023/THREEFYTP10_2023.parquet  (260 filas)
# ▲ THREEFYTP10 2024 -> bronze/macros/THREEFYTP10/year=2024/THREEFYTP10_2024.parquet  (262 filas)
# ▲ THREEFYTP10 2025 -> bronze/macros/THREEFYTP10/year=2025/THREEFYTP10_2025.parquet  (143 filas)
# ▲ BAMLH0A0HYM2 1996 -> bronze/macros/BAMLH0A0HYM2/year=1996/BAMLH0A0HYM2_1996.parquet  (1 filas)
# ▲ BAMLH0A0HYM2 1997 -> bronze/macros/BAMLH0A0HYM2/year=1997/BAMLH0A0HYM2_1997.parquet  (264 filas)
# ▲ BAMLH0A0HYM2 1998 -> bronze/macros/BAMLH0A0HYM2/year=1998/BAMLH0A0HYM2_1998.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 1999 -> bronze/macros/BAMLH0A0HYM2/year=1999/BAMLH0A0HYM2_1999.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2000 -> bronze/macros/BAMLH0A0HYM2/year=2000/BAMLH0A0HYM2_2000.parquet  (263 filas)
# ▲ BAMLH0A0HYM2 2001 -> bronze/macros/BAMLH0A0HYM2/year=2001/BAMLH0A0HYM2_2001.parquet  (264 filas)
# ▲ BAMLH0A0HYM2 2002 -> bronze/macros/BAMLH0A0HYM2/year=2002/BAMLH0A0HYM2_2002.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2003 -> bronze/macros/BAMLH0A0HYM2/year=2003/BAMLH0A0HYM2_2003.parquet  (264 filas)
# ▲ BAMLH0A0HYM2 2004 -> bronze/macros/BAMLH0A0HYM2/year=2004/BAMLH0A0HYM2_2004.parquet  (266 filas)
# ▲ BAMLH0A0HYM2 2005 -> bronze/macros/BAMLH0A0HYM2/year=2005/BAMLH0A0HYM2_2005.parquet  (263 filas)
# ▲ BAMLH0A0HYM2 2006 -> bronze/macros/BAMLH0A0HYM2/year=2006/BAMLH0A0HYM2_2006.parquet  (263 filas)
# ▲ BAMLH0A0HYM2 2007 -> bronze/macros/BAMLH0A0HYM2/year=2007/BAMLH0A0HYM2_2007.parquet  (264 filas)
# ▲ BAMLH0A0HYM2 2008 -> bronze/macros/BAMLH0A0HYM2/year=2008/BAMLH0A0HYM2_2008.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2009 -> bronze/macros/BAMLH0A0HYM2/year=2009/BAMLH0A0HYM2_2009.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2010 -> bronze/macros/BAMLH0A0HYM2/year=2010/BAMLH0A0HYM2_2010.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2011 -> bronze/macros/BAMLH0A0HYM2/year=2011/BAMLH0A0HYM2_2011.parquet  (263 filas)
# ▲ BAMLH0A0HYM2 2012 -> bronze/macros/BAMLH0A0HYM2/year=2012/BAMLH0A0HYM2_2012.parquet  (264 filas)
# ▲ BAMLH0A0HYM2 2013 -> bronze/macros/BAMLH0A0HYM2/year=2013/BAMLH0A0HYM2_2013.parquet  (264 filas)
# ▲ BAMLH0A0HYM2 2014 -> bronze/macros/BAMLH0A0HYM2/year=2014/BAMLH0A0HYM2_2014.parquet  (264 filas)
# ▲ BAMLH0A0HYM2 2015 -> bronze/macros/BAMLH0A0HYM2/year=2015/BAMLH0A0HYM2_2015.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2016 -> bronze/macros/BAMLH0A0HYM2/year=2016/BAMLH0A0HYM2_2016.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2017 -> bronze/macros/BAMLH0A0HYM2/year=2017/BAMLH0A0HYM2_2017.parquet  (263 filas)
# ▲ BAMLH0A0HYM2 2018 -> bronze/macros/BAMLH0A0HYM2/year=2018/BAMLH0A0HYM2_2018.parquet  (264 filas)
# ▲ BAMLH0A0HYM2 2019 -> bronze/macros/BAMLH0A0HYM2/year=2019/BAMLH0A0HYM2_2019.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2020 -> bronze/macros/BAMLH0A0HYM2/year=2020/BAMLH0A0HYM2_2020.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2021 -> bronze/macros/BAMLH0A0HYM2/year=2021/BAMLH0A0HYM2_2021.parquet  (265 filas)
# ▲ BAMLH0A0HYM2 2022 -> bronze/macros/BAMLH0A0HYM2/year=2022/BAMLH0A0HYM2_2022.parquet  (263 filas)
# ▲ BAMLH0A0HYM2 2023 -> bronze/macros/BAMLH0A0HYM2/year=2023/BAMLH0A0HYM2_2023.parquet  (263 filas)
# ▲ BAMLH0A0HYM2 2024 -> bronze/macros/BAMLH0A0HYM2/year=2024/BAMLH0A0HYM2_2024.parquet  (266 filas)
# ▲ BAMLH0A0HYM2 2025 -> bronze/macros/BAMLH0A0HYM2/year=2025/BAMLH0A0HYM2_2025.parquet  (148 filas)
# ▲ BAA10Y 1992 -> bronze/macros/BAA10Y/year=1992/BAA10Y_1992.parquet  (262 filas)
# ▲ BAA10Y 1993 -> bronze/macros/BAA10Y/year=1993/BAA10Y_1993.parquet  (261 filas)
# ▲ BAA10Y 1994 -> bronze/macros/BAA10Y/year=1994/BAA10Y_1994.parquet  (260 filas)
# ▲ BAA10Y 1995 -> bronze/macros/BAA10Y/year=1995/BAA10Y_1995.parquet  (260 filas)
# ▲ BAA10Y 1996 -> bronze/macros/BAA10Y/year=1996/BAA10Y_1996.parquet  (262 filas)
# ▲ BAA10Y 1997 -> bronze/macros/BAA10Y/year=1997/BAA10Y_1997.parquet  (261 filas)
# ▲ BAA10Y 1998 -> bronze/macros/BAA10Y/year=1998/BAA10Y_1998.parquet  (261 filas)
# ▲ BAA10Y 1999 -> bronze/macros/BAA10Y/year=1999/BAA10Y_1999.parquet  (261 filas)
# ▲ BAA10Y 2000 -> bronze/macros/BAA10Y/year=2000/BAA10Y_2000.parquet  (260 filas)
# ▲ BAA10Y 2001 -> bronze/macros/BAA10Y/year=2001/BAA10Y_2001.parquet  (261 filas)
# ▲ BAA10Y 2002 -> bronze/macros/BAA10Y/year=2002/BAA10Y_2002.parquet  (261 filas)
# ▲ BAA10Y 2003 -> bronze/macros/BAA10Y/year=2003/BAA10Y_2003.parquet  (261 filas)
# ▲ BAA10Y 2004 -> bronze/macros/BAA10Y/year=2004/BAA10Y_2004.parquet  (262 filas)
# ▲ BAA10Y 2005 -> bronze/macros/BAA10Y/year=2005/BAA10Y_2005.parquet  (260 filas)
# ▲ BAA10Y 2006 -> bronze/macros/BAA10Y/year=2006/BAA10Y_2006.parquet  (260 filas)
# ▲ BAA10Y 2007 -> bronze/macros/BAA10Y/year=2007/BAA10Y_2007.parquet  (261 filas)
# ▲ BAA10Y 2008 -> bronze/macros/BAA10Y/year=2008/BAA10Y_2008.parquet  (262 filas)
# ▲ BAA10Y 2009 -> bronze/macros/BAA10Y/year=2009/BAA10Y_2009.parquet  (261 filas)
# ▲ BAA10Y 2010 -> bronze/macros/BAA10Y/year=2010/BAA10Y_2010.parquet  (261 filas)
# ▲ BAA10Y 2011 -> bronze/macros/BAA10Y/year=2011/BAA10Y_2011.parquet  (260 filas)
# ▲ BAA10Y 2012 -> bronze/macros/BAA10Y/year=2012/BAA10Y_2012.parquet  (261 filas)
# ▲ BAA10Y 2013 -> bronze/macros/BAA10Y/year=2013/BAA10Y_2013.parquet  (261 filas)
# ▲ BAA10Y 2014 -> bronze/macros/BAA10Y/year=2014/BAA10Y_2014.parquet  (261 filas)
# ▲ BAA10Y 2015 -> bronze/macros/BAA10Y/year=2015/BAA10Y_2015.parquet  (261 filas)
# ▲ BAA10Y 2016 -> bronze/macros/BAA10Y/year=2016/BAA10Y_2016.parquet  (261 filas)
# ▲ BAA10Y 2017 -> bronze/macros/BAA10Y/year=2017/BAA10Y_2017.parquet  (260 filas)
# ▲ BAA10Y 2018 -> bronze/macros/BAA10Y/year=2018/BAA10Y_2018.parquet  (261 filas)
# ▲ BAA10Y 2019 -> bronze/macros/BAA10Y/year=2019/BAA10Y_2019.parquet  (261 filas)
# ▲ BAA10Y 2020 -> bronze/macros/BAA10Y/year=2020/BAA10Y_2020.parquet  (262 filas)
# ▲ BAA10Y 2021 -> bronze/macros/BAA10Y/year=2021/BAA10Y_2021.parquet  (261 filas)
# ▲ BAA10Y 2022 -> bronze/macros/BAA10Y/year=2022/BAA10Y_2022.parquet  (260 filas)
# ▲ BAA10Y 2023 -> bronze/macros/BAA10Y/year=2023/BAA10Y_2023.parquet  (260 filas)
# ▲ BAA10Y 2024 -> bronze/macros/BAA10Y/year=2024/BAA10Y_2024.parquet  (262 filas)
# ▲ BAA10Y 2025 -> bronze/macros/BAA10Y/year=2025/BAA10Y_2025.parquet  (147 filas)
# ▲ NFCI 1992 -> bronze/macros/NFCI/year=1992/NFCI_1992.parquet  (52 filas)
# ▲ NFCI 1993 -> bronze/macros/NFCI/year=1993/NFCI_1993.parquet  (53 filas)
# ▲ NFCI 1994 -> bronze/macros/NFCI/year=1994/NFCI_1994.parquet  (52 filas)
# ▲ NFCI 1995 -> bronze/macros/NFCI/year=1995/NFCI_1995.parquet  (52 filas)
# ▲ NFCI 1996 -> bronze/macros/NFCI/year=1996/NFCI_1996.parquet  (52 filas)
# ▲ NFCI 1997 -> bronze/macros/NFCI/year=1997/NFCI_1997.parquet  (52 filas)
# ▲ NFCI 1998 -> bronze/macros/NFCI/year=1998/NFCI_1998.parquet  (52 filas)
# ▲ NFCI 1999 -> bronze/macros/NFCI/year=1999/NFCI_1999.parquet  (53 filas)
# ▲ NFCI 2000 -> bronze/macros/NFCI/year=2000/NFCI_2000.parquet  (52 filas)
# ▲ NFCI 2001 -> bronze/macros/NFCI/year=2001/NFCI_2001.parquet  (52 filas)
# ▲ NFCI 2002 -> bronze/macros/NFCI/year=2002/NFCI_2002.parquet  (52 filas)
# ▲ NFCI 2003 -> bronze/macros/NFCI/year=2003/NFCI_2003.parquet  (52 filas)
# ▲ NFCI 2004 -> bronze/macros/NFCI/year=2004/NFCI_2004.parquet  (53 filas)
# ▲ NFCI 2005 -> bronze/macros/NFCI/year=2005/NFCI_2005.parquet  (52 filas)
# ▲ NFCI 2006 -> bronze/macros/NFCI/year=2006/NFCI_2006.parquet  (52 filas)
# ▲ NFCI 2007 -> bronze/macros/NFCI/year=2007/NFCI_2007.parquet  (52 filas)
# ▲ NFCI 2008 -> bronze/macros/NFCI/year=2008/NFCI_2008.parquet  (52 filas)
# ▲ NFCI 2009 -> bronze/macros/NFCI/year=2009/NFCI_2009.parquet  (52 filas)
# ▲ NFCI 2010 -> bronze/macros/NFCI/year=2010/NFCI_2010.parquet  (53 filas)
# ▲ NFCI 2011 -> bronze/macros/NFCI/year=2011/NFCI_2011.parquet  (52 filas)
# ▲ NFCI 2012 -> bronze/macros/NFCI/year=2012/NFCI_2012.parquet  (52 filas)
# ▲ NFCI 2013 -> bronze/macros/NFCI/year=2013/NFCI_2013.parquet  (52 filas)
# ▲ NFCI 2014 -> bronze/macros/NFCI/year=2014/NFCI_2014.parquet  (52 filas)
# ▲ NFCI 2015 -> bronze/macros/NFCI/year=2015/NFCI_2015.parquet  (52 filas)
# ▲ NFCI 2016 -> bronze/macros/NFCI/year=2016/NFCI_2016.parquet  (53 filas)
# ▲ NFCI 2017 -> bronze/macros/NFCI/year=2017/NFCI_2017.parquet  (52 filas)
# ▲ NFCI 2018 -> bronze/macros/NFCI/year=2018/NFCI_2018.parquet  (52 filas)
# ▲ NFCI 2019 -> bronze/macros/NFCI/year=2019/NFCI_2019.parquet  (52 filas)
# ▲ NFCI 2020 -> bronze/macros/NFCI/year=2020/NFCI_2020.parquet  (52 filas)
# ▲ NFCI 2021 -> bronze/macros/NFCI/year=2021/NFCI_2021.parquet  (53 filas)
# ▲ NFCI 2022 -> bronze/macros/NFCI/year=2022/NFCI_2022.parquet  (52 filas)
# ▲ NFCI 2023 -> bronze/macros/NFCI/year=2023/NFCI_2023.parquet  (52 filas)
# ▲ NFCI 2024 -> bronze/macros/NFCI/year=2024/NFCI_2024.parquet  (52 filas)
# ▲ NFCI 2025 -> bronze/macros/NFCI/year=2025/NFCI_2025.parquet  (29 filas)
# ▲ ANFCI 1992 -> bronze/macros/ANFCI/year=1992/ANFCI_1992.parquet  (52 filas)
# ▲ ANFCI 1993 -> bronze/macros/ANFCI/year=1993/ANFCI_1993.parquet  (53 filas)
# ▲ ANFCI 1994 -> bronze/macros/ANFCI/year=1994/ANFCI_1994.parquet  (52 filas)
# ▲ ANFCI 1995 -> bronze/macros/ANFCI/year=1995/ANFCI_1995.parquet  (52 filas)
# ▲ ANFCI 1996 -> bronze/macros/ANFCI/year=1996/ANFCI_1996.parquet  (52 filas)
# ▲ ANFCI 1997 -> bronze/macros/ANFCI/year=1997/ANFCI_1997.parquet  (52 filas)
# ▲ ANFCI 1998 -> bronze/macros/ANFCI/year=1998/ANFCI_1998.parquet  (52 filas)
# ▲ ANFCI 1999 -> bronze/macros/ANFCI/year=1999/ANFCI_1999.parquet  (53 filas)
# ▲ ANFCI 2000 -> bronze/macros/ANFCI/year=2000/ANFCI_2000.parquet  (52 filas)
# ▲ ANFCI 2001 -> bronze/macros/ANFCI/year=2001/ANFCI_2001.parquet  (52 filas)
# ▲ ANFCI 2002 -> bronze/macros/ANFCI/year=2002/ANFCI_2002.parquet  (52 filas)
# ▲ ANFCI 2003 -> bronze/macros/ANFCI/year=2003/ANFCI_2003.parquet  (52 filas)
# ▲ ANFCI 2004 -> bronze/macros/ANFCI/year=2004/ANFCI_2004.parquet  (53 filas)
# ▲ ANFCI 2005 -> bronze/macros/ANFCI/year=2005/ANFCI_2005.parquet  (52 filas)
# ▲ ANFCI 2006 -> bronze/macros/ANFCI/year=2006/ANFCI_2006.parquet  (52 filas)
# ▲ ANFCI 2007 -> bronze/macros/ANFCI/year=2007/ANFCI_2007.parquet  (52 filas)
# ▲ ANFCI 2008 -> bronze/macros/ANFCI/year=2008/ANFCI_2008.parquet  (52 filas)
# ▲ ANFCI 2009 -> bronze/macros/ANFCI/year=2009/ANFCI_2009.parquet  (52 filas)
# ▲ ANFCI 2010 -> bronze/macros/ANFCI/year=2010/ANFCI_2010.parquet  (53 filas)
# ▲ ANFCI 2011 -> bronze/macros/ANFCI/year=2011/ANFCI_2011.parquet  (52 filas)
# ▲ ANFCI 2012 -> bronze/macros/ANFCI/year=2012/ANFCI_2012.parquet  (52 filas)
# ▲ ANFCI 2013 -> bronze/macros/ANFCI/year=2013/ANFCI_2013.parquet  (52 filas)
# ▲ ANFCI 2014 -> bronze/macros/ANFCI/year=2014/ANFCI_2014.parquet  (52 filas)
# ▲ ANFCI 2015 -> bronze/macros/ANFCI/year=2015/ANFCI_2015.parquet  (52 filas)
# ▲ ANFCI 2016 -> bronze/macros/ANFCI/year=2016/ANFCI_2016.parquet  (53 filas)
# ▲ ANFCI 2017 -> bronze/macros/ANFCI/year=2017/ANFCI_2017.parquet  (52 filas)
# ▲ ANFCI 2018 -> bronze/macros/ANFCI/year=2018/ANFCI_2018.parquet  (52 filas)
# ▲ ANFCI 2019 -> bronze/macros/ANFCI/year=2019/ANFCI_2019.parquet  (52 filas)
# ▲ ANFCI 2020 -> bronze/macros/ANFCI/year=2020/ANFCI_2020.parquet  (52 filas)
# ▲ ANFCI 2021 -> bronze/macros/ANFCI/year=2021/ANFCI_2021.parquet  (53 filas)
# ▲ ANFCI 2022 -> bronze/macros/ANFCI/year=2022/ANFCI_2022.parquet  (52 filas)
# ▲ ANFCI 2023 -> bronze/macros/ANFCI/year=2023/ANFCI_2023.parquet  (52 filas)
# ▲ ANFCI 2024 -> bronze/macros/ANFCI/year=2024/ANFCI_2024.parquet  (52 filas)
# ▲ ANFCI 2025 -> bronze/macros/ANFCI/year=2025/ANFCI_2025.parquet  (29 filas)
# ▲ TEDRATE 1992 -> bronze/macros/TEDRATE/year=1992/TEDRATE_1992.parquet  (262 filas)
# ▲ TEDRATE 1993 -> bronze/macros/TEDRATE/year=1993/TEDRATE_1993.parquet  (261 filas)
# ▲ TEDRATE 1994 -> bronze/macros/TEDRATE/year=1994/TEDRATE_1994.parquet  (260 filas)
# ▲ TEDRATE 1995 -> bronze/macros/TEDRATE/year=1995/TEDRATE_1995.parquet  (260 filas)
# ▲ TEDRATE 1996 -> bronze/macros/TEDRATE/year=1996/TEDRATE_1996.parquet  (262 filas)
# ▲ TEDRATE 1997 -> bronze/macros/TEDRATE/year=1997/TEDRATE_1997.parquet  (261 filas)
# ▲ TEDRATE 1998 -> bronze/macros/TEDRATE/year=1998/TEDRATE_1998.parquet  (261 filas)
# ▲ TEDRATE 1999 -> bronze/macros/TEDRATE/year=1999/TEDRATE_1999.parquet  (261 filas)
# ▲ TEDRATE 2000 -> bronze/macros/TEDRATE/year=2000/TEDRATE_2000.parquet  (260 filas)
# ▲ TEDRATE 2001 -> bronze/macros/TEDRATE/year=2001/TEDRATE_2001.parquet  (261 filas)
# ▲ TEDRATE 2002 -> bronze/macros/TEDRATE/year=2002/TEDRATE_2002.parquet  (261 filas)
# ▲ TEDRATE 2003 -> bronze/macros/TEDRATE/year=2003/TEDRATE_2003.parquet  (261 filas)
# ▲ TEDRATE 2004 -> bronze/macros/TEDRATE/year=2004/TEDRATE_2004.parquet  (262 filas)
# ▲ TEDRATE 2005 -> bronze/macros/TEDRATE/year=2005/TEDRATE_2005.parquet  (260 filas)
# ▲ TEDRATE 2006 -> bronze/macros/TEDRATE/year=2006/TEDRATE_2006.parquet  (260 filas)
# ▲ TEDRATE 2007 -> bronze/macros/TEDRATE/year=2007/TEDRATE_2007.parquet  (261 filas)
# ▲ TEDRATE 2008 -> bronze/macros/TEDRATE/year=2008/TEDRATE_2008.parquet  (262 filas)
# ▲ TEDRATE 2009 -> bronze/macros/TEDRATE/year=2009/TEDRATE_2009.parquet  (261 filas)
# ▲ TEDRATE 2010 -> bronze/macros/TEDRATE/year=2010/TEDRATE_2010.parquet  (261 filas)
# ▲ TEDRATE 2011 -> bronze/macros/TEDRATE/year=2011/TEDRATE_2011.parquet  (260 filas)
# ▲ TEDRATE 2012 -> bronze/macros/TEDRATE/year=2012/TEDRATE_2012.parquet  (261 filas)
# ▲ TEDRATE 2013 -> bronze/macros/TEDRATE/year=2013/TEDRATE_2013.parquet  (261 filas)
# ▲ TEDRATE 2014 -> bronze/macros/TEDRATE/year=2014/TEDRATE_2014.parquet  (261 filas)
# ▲ TEDRATE 2015 -> bronze/macros/TEDRATE/year=2015/TEDRATE_2015.parquet  (261 filas)
# ▲ TEDRATE 2016 -> bronze/macros/TEDRATE/year=2016/TEDRATE_2016.parquet  (261 filas)
# ▲ TEDRATE 2017 -> bronze/macros/TEDRATE/year=2017/TEDRATE_2017.parquet  (260 filas)
# ▲ TEDRATE 2018 -> bronze/macros/TEDRATE/year=2018/TEDRATE_2018.parquet  (261 filas)
# ▲ TEDRATE 2019 -> bronze/macros/TEDRATE/year=2019/TEDRATE_2019.parquet  (261 filas)
# ▲ TEDRATE 2020 -> bronze/macros/TEDRATE/year=2020/TEDRATE_2020.parquet  (262 filas)
# ▲ TEDRATE 2021 -> bronze/macros/TEDRATE/year=2021/TEDRATE_2021.parquet  (261 filas)
# ▲ TEDRATE 2022 -> bronze/macros/TEDRATE/year=2022/TEDRATE_2022.parquet  (15 filas)
# ▲ VIXCLS 1992 -> bronze/macros/VIXCLS/year=1992/VIXCLS_1992.parquet  (262 filas)
# ▲ VIXCLS 1993 -> bronze/macros/VIXCLS/year=1993/VIXCLS_1993.parquet  (261 filas)
# ▲ VIXCLS 1994 -> bronze/macros/VIXCLS/year=1994/VIXCLS_1994.parquet  (260 filas)
# ▲ VIXCLS 1995 -> bronze/macros/VIXCLS/year=1995/VIXCLS_1995.parquet  (260 filas)
# ▲ VIXCLS 1996 -> bronze/macros/VIXCLS/year=1996/VIXCLS_1996.parquet  (262 filas)
# ▲ VIXCLS 1997 -> bronze/macros/VIXCLS/year=1997/VIXCLS_1997.parquet  (261 filas)
# ▲ VIXCLS 1998 -> bronze/macros/VIXCLS/year=1998/VIXCLS_1998.parquet  (261 filas)
# ▲ VIXCLS 1999 -> bronze/macros/VIXCLS/year=1999/VIXCLS_1999.parquet  (261 filas)
# ▲ VIXCLS 2000 -> bronze/macros/VIXCLS/year=2000/VIXCLS_2000.parquet  (260 filas)
# ▲ VIXCLS 2001 -> bronze/macros/VIXCLS/year=2001/VIXCLS_2001.parquet  (261 filas)
# ▲ VIXCLS 2002 -> bronze/macros/VIXCLS/year=2002/VIXCLS_2002.parquet  (261 filas)
# ▲ VIXCLS 2003 -> bronze/macros/VIXCLS/year=2003/VIXCLS_2003.parquet  (261 filas)
# ▲ VIXCLS 2004 -> bronze/macros/VIXCLS/year=2004/VIXCLS_2004.parquet  (262 filas)
# ▲ VIXCLS 2005 -> bronze/macros/VIXCLS/year=2005/VIXCLS_2005.parquet  (260 filas)
# ▲ VIXCLS 2006 -> bronze/macros/VIXCLS/year=2006/VIXCLS_2006.parquet  (260 filas)
# ▲ VIXCLS 2007 -> bronze/macros/VIXCLS/year=2007/VIXCLS_2007.parquet  (261 filas)
# ▲ VIXCLS 2008 -> bronze/macros/VIXCLS/year=2008/VIXCLS_2008.parquet  (262 filas)
# ▲ VIXCLS 2009 -> bronze/macros/VIXCLS/year=2009/VIXCLS_2009.parquet  (261 filas)
# ▲ VIXCLS 2010 -> bronze/macros/VIXCLS/year=2010/VIXCLS_2010.parquet  (261 filas)
# ▲ VIXCLS 2011 -> bronze/macros/VIXCLS/year=2011/VIXCLS_2011.parquet  (260 filas)
# ▲ VIXCLS 2012 -> bronze/macros/VIXCLS/year=2012/VIXCLS_2012.parquet  (261 filas)
# ▲ VIXCLS 2013 -> bronze/macros/VIXCLS/year=2013/VIXCLS_2013.parquet  (261 filas)
# ▲ VIXCLS 2014 -> bronze/macros/VIXCLS/year=2014/VIXCLS_2014.parquet  (261 filas)
# ▲ VIXCLS 2015 -> bronze/macros/VIXCLS/year=2015/VIXCLS_2015.parquet  (261 filas)
# ▲ VIXCLS 2016 -> bronze/macros/VIXCLS/year=2016/VIXCLS_2016.parquet  (261 filas)
# ▲ VIXCLS 2017 -> bronze/macros/VIXCLS/year=2017/VIXCLS_2017.parquet  (260 filas)
# ▲ VIXCLS 2018 -> bronze/macros/VIXCLS/year=2018/VIXCLS_2018.parquet  (261 filas)
# ▲ VIXCLS 2019 -> bronze/macros/VIXCLS/year=2019/VIXCLS_2019.parquet  (261 filas)
# ▲ VIXCLS 2020 -> bronze/macros/VIXCLS/year=2020/VIXCLS_2020.parquet  (262 filas)
# ▲ VIXCLS 2021 -> bronze/macros/VIXCLS/year=2021/VIXCLS_2021.parquet  (261 filas)
# ▲ VIXCLS 2022 -> bronze/macros/VIXCLS/year=2022/VIXCLS_2022.parquet  (260 filas)
# ▲ VIXCLS 2023 -> bronze/macros/VIXCLS/year=2023/VIXCLS_2023.parquet  (260 filas)
# ▲ VIXCLS 2024 -> bronze/macros/VIXCLS/year=2024/VIXCLS_2024.parquet  (262 filas)
# ▲ VIXCLS 2025 -> bronze/macros/VIXCLS/year=2025/VIXCLS_2025.parquet  (147 filas)
# ▲ DTWEXBGS 2006 -> bronze/macros/DTWEXBGS/year=2006/DTWEXBGS_2006.parquet  (260 filas)
# ▲ DTWEXBGS 2007 -> bronze/macros/DTWEXBGS/year=2007/DTWEXBGS_2007.parquet  (261 filas)
# ▲ DTWEXBGS 2008 -> bronze/macros/DTWEXBGS/year=2008/DTWEXBGS_2008.parquet  (262 filas)
# ▲ DTWEXBGS 2009 -> bronze/macros/DTWEXBGS/year=2009/DTWEXBGS_2009.parquet  (261 filas)
# ▲ DTWEXBGS 2010 -> bronze/macros/DTWEXBGS/year=2010/DTWEXBGS_2010.parquet  (261 filas)
# ▲ DTWEXBGS 2011 -> bronze/macros/DTWEXBGS/year=2011/DTWEXBGS_2011.parquet  (260 filas)
# ▲ DTWEXBGS 2012 -> bronze/macros/DTWEXBGS/year=2012/DTWEXBGS_2012.parquet  (261 filas)
# ▲ DTWEXBGS 2013 -> bronze/macros/DTWEXBGS/year=2013/DTWEXBGS_2013.parquet  (261 filas)
# ...
# ▲ ICSA 2016 -> bronze/macros/ICSA/year=2016/ICSA_2016.parquet  (53 filas)
# ▲ ICSA 2017 -> bronze/macros/ICSA/year=2017/ICSA_2017.parquet  (52 filas)
# ▲ ICSA 2018 -> bronze/macros/ICSA/year=2018/ICSA_2018.parquet  (52 filas)
# ▲ ICSA 2019 -> bronze/macros/ICSA/year=2019/ICSA_2019.parquet  (52 filas)
# ▲ ICSA 2020 -> bronze/macros/ICSA/year=2020/ICSA_2020.parquet  (52 filas)
# ▲ ICSA 2021 -> bronze/macros/ICSA/year=2021/ICSA_2021.parquet  (52 filas)
# ▲ ICSA 2022 -> bronze/macros/ICSA/year=2022/ICSA_2022.parquet  (53 filas)
# ▲ ICSA 2023 -> bronze/macros/ICSA/year=2023/ICSA_2023.parquet  (52 filas)
# ▲ ICSA 2024 -> bronze/macros/ICSA/year=2024/ICSA_2024.parquet  (52 filas)
# ▲ ICSA 2025 -> bronze/macros/ICSA/year=2025/ICSA_2025.parquet  (29 filas)
# ▲ PAYEMS 1992 -> bronze/macros/PAYEMS/year=1992/PAYEMS_1992.parquet  (12 filas)
# ▲ PAYEMS 1993 -> bronze/macros/PAYEMS/year=1993/PAYEMS_1993.parquet  (12 filas)
# ▲ PAYEMS 1994 -> bronze/macros/PAYEMS/year=1994/PAYEMS_1994.parquet  (12 filas)
# ▲ PAYEMS 1995 -> bronze/macros/PAYEMS/year=1995/PAYEMS_1995.parquet  (12 filas)
# ▲ PAYEMS 1996 -> bronze/macros/PAYEMS/year=1996/PAYEMS_1996.parquet  (12 filas)
# ▲ PAYEMS 1997 -> bronze/macros/PAYEMS/year=1997/PAYEMS_1997.parquet  (12 filas)
# ▲ PAYEMS 1998 -> bronze/macros/PAYEMS/year=1998/PAYEMS_1998.parquet  (12 filas)
# ▲ PAYEMS 1999 -> bronze/macros/PAYEMS/year=1999/PAYEMS_1999.parquet  (12 filas)
# ▲ PAYEMS 2000 -> bronze/macros/PAYEMS/year=2000/PAYEMS_2000.parquet  (12 filas)
# ▲ PAYEMS 2001 -> bronze/macros/PAYEMS/year=2001/PAYEMS_2001.parquet  (12 filas)
# ▲ PAYEMS 2002 -> bronze/macros/PAYEMS/year=2002/PAYEMS_2002.parquet  (12 filas)
# ▲ PAYEMS 2003 -> bronze/macros/PAYEMS/year=2003/PAYEMS_2003.parquet  (12 filas)
# ▲ PAYEMS 2004 -> bronze/macros/PAYEMS/year=2004/PAYEMS_2004.parquet  (12 filas)
# ▲ PAYEMS 2005 -> bronze/macros/PAYEMS/year=2005/PAYEMS_2005.parquet  (12 filas)
# ▲ PAYEMS 2006 -> bronze/macros/PAYEMS/year=2006/PAYEMS_2006.parquet  (12 filas)
# ▲ PAYEMS 2007 -> bronze/macros/PAYEMS/year=2007/PAYEMS_2007.parquet  (12 filas)
# ▲ PAYEMS 2008 -> bronze/macros/PAYEMS/year=2008/PAYEMS_2008.parquet  (12 filas)
# ▲ PAYEMS 2009 -> bronze/macros/PAYEMS/year=2009/PAYEMS_2009.parquet  (12 filas)
# ▲ PAYEMS 2010 -> bronze/macros/PAYEMS/year=2010/PAYEMS_2010.parquet  (12 filas)
# ▲ PAYEMS 2011 -> bronze/macros/PAYEMS/year=2011/PAYEMS_2011.parquet  (12 filas)
# ▲ PAYEMS 2012 -> bronze/macros/PAYEMS/year=2012/PAYEMS_2012.parquet  (12 filas)
# ▲ PAYEMS 2013 -> bronze/macros/PAYEMS/year=2013/PAYEMS_2013.parquet  (12 filas)
# ▲ PAYEMS 2014 -> bronze/macros/PAYEMS/year=2014/PAYEMS_2014.parquet  (12 filas)
# ▲ PAYEMS 2015 -> bronze/macros/PAYEMS/year=2015/PAYEMS_2015.parquet  (12 filas)
# ▲ PAYEMS 2016 -> bronze/macros/PAYEMS/year=2016/PAYEMS_2016.parquet  (12 filas)
# ▲ PAYEMS 2017 -> bronze/macros/PAYEMS/year=2017/PAYEMS_2017.parquet  (12 filas)
# ▲ PAYEMS 2018 -> bronze/macros/PAYEMS/year=2018/PAYEMS_2018.parquet  (12 filas)
# ▲ PAYEMS 2019 -> bronze/macros/PAYEMS/year=2019/PAYEMS_2019.parquet  (12 filas)
# ▲ PAYEMS 2020 -> bronze/macros/PAYEMS/year=2020/PAYEMS_2020.parquet  (12 filas)
# ▲ PAYEMS 2021 -> bronze/macros/PAYEMS/year=2021/PAYEMS_2021.parquet  (12 filas)
# ▲ PAYEMS 2022 -> bronze/macros/PAYEMS/year=2022/PAYEMS_2022.parquet  (12 filas)
# ▲ PAYEMS 2023 -> bronze/macros/PAYEMS/year=2023/PAYEMS_2023.parquet  (12 filas)
# ▲ PAYEMS 2024 -> bronze/macros/PAYEMS/year=2024/PAYEMS_2024.parquet  (12 filas)
# ▲ PAYEMS 2025 -> bronze/macros/PAYEMS/year=2025/PAYEMS_2025.parquet  (6 filas)
# ▲ UMCSENT 1992 -> bronze/macros/UMCSENT/year=1992/UMCSENT_1992.parquet  (12 filas)
# ▲ UMCSENT 1993 -> bronze/macros/UMCSENT/year=1993/UMCSENT_1993.parquet  (12 filas)
# ▲ UMCSENT 1994 -> bronze/macros/UMCSENT/year=1994/UMCSENT_1994.parquet  (12 filas)
# ▲ UMCSENT 1995 -> bronze/macros/UMCSENT/year=1995/UMCSENT_1995.parquet  (12 filas)
# ▲ UMCSENT 1996 -> bronze/macros/UMCSENT/year=1996/UMCSENT_1996.parquet  (12 filas)
# ▲ UMCSENT 1997 -> bronze/macros/UMCSENT/year=1997/UMCSENT_1997.parquet  (12 filas)
# ▲ UMCSENT 1998 -> bronze/macros/UMCSENT/year=1998/UMCSENT_1998.parquet  (12 filas)
# ▲ UMCSENT 1999 -> bronze/macros/UMCSENT/year=1999/UMCSENT_1999.parquet  (12 filas)
# ▲ UMCSENT 2000 -> bronze/macros/UMCSENT/year=2000/UMCSENT_2000.parquet  (12 filas)
# ▲ UMCSENT 2001 -> bronze/macros/UMCSENT/year=2001/UMCSENT_2001.parquet  (12 filas)
# ▲ UMCSENT 2002 -> bronze/macros/UMCSENT/year=2002/UMCSENT_2002.parquet  (12 filas)
# ▲ UMCSENT 2003 -> bronze/macros/UMCSENT/year=2003/UMCSENT_2003.parquet  (12 filas)
# ▲ UMCSENT 2004 -> bronze/macros/UMCSENT/year=2004/UMCSENT_2004.parquet  (12 filas)
# ▲ UMCSENT 2005 -> bronze/macros/UMCSENT/year=2005/UMCSENT_2005.parquet  (12 filas)
# ▲ UMCSENT 2006 -> bronze/macros/UMCSENT/year=2006/UMCSENT_2006.parquet  (12 filas)
# ▲ UMCSENT 2007 -> bronze/macros/UMCSENT/year=2007/UMCSENT_2007.parquet  (12 filas)
# ▲ UMCSENT 2008 -> bronze/macros/UMCSENT/year=2008/UMCSENT_2008.parquet  (12 filas)
# ▲ UMCSENT 2009 -> bronze/macros/UMCSENT/year=2009/UMCSENT_2009.parquet  (12 filas)
# ▲ UMCSENT 2010 -> bronze/macros/UMCSENT/year=2010/UMCSENT_2010.parquet  (12 filas)
# ▲ UMCSENT 2011 -> bronze/macros/UMCSENT/year=2011/UMCSENT_2011.parquet  (12 filas)
# ▲ UMCSENT 2012 -> bronze/macros/UMCSENT/year=2012/UMCSENT_2012.parquet  (12 filas)
# ▲ UMCSENT 2013 -> bronze/macros/UMCSENT/year=2013/UMCSENT_2013.parquet  (12 filas)
# ▲ UMCSENT 2014 -> bronze/macros/UMCSENT/year=2014/UMCSENT_2014.parquet  (12 filas)
# ▲ UMCSENT 2015 -> bronze/macros/UMCSENT/year=2015/UMCSENT_2015.parquet  (12 filas)
# ▲ UMCSENT 2016 -> bronze/macros/UMCSENT/year=2016/UMCSENT_2016.parquet  (12 filas)
# ▲ UMCSENT 2017 -> bronze/macros/UMCSENT/year=2017/UMCSENT_2017.parquet  (12 filas)
# ▲ UMCSENT 2018 -> bronze/macros/UMCSENT/year=2018/UMCSENT_2018.parquet  (12 filas)
# ▲ UMCSENT 2019 -> bronze/macros/UMCSENT/year=2019/UMCSENT_2019.parquet  (12 filas)
# ▲ UMCSENT 2020 -> bronze/macros/UMCSENT/year=2020/UMCSENT_2020.parquet  (12 filas)
# ▲ UMCSENT 2021 -> bronze/macros/UMCSENT/year=2021/UMCSENT_2021.parquet  (12 filas)
# ▲ UMCSENT 2022 -> bronze/macros/UMCSENT/year=2022/UMCSENT_2022.parquet  (12 filas)
# ▲ UMCSENT 2023 -> bronze/macros/UMCSENT/year=2023/UMCSENT_2023.parquet  (12 filas)
# ▲ UMCSENT 2024 -> bronze/macros/UMCSENT/year=2024/UMCSENT_2024.parquet  (12 filas)
# ▲ UMCSENT 2025 -> bronze/macros/UMCSENT/year=2025/UMCSENT_2025.parquet  (5 filas)
# ▲ HOUST 1992 -> bronze/macros/HOUST/year=1992/HOUST_1992.parquet  (12 filas)
# ▲ HOUST 1993 -> bronze/macros/HOUST/year=1993/HOUST_1993.parquet  (12 filas)
# ▲ HOUST 1994 -> bronze/macros/HOUST/year=1994/HOUST_1994.parquet  (12 filas)
# ▲ HOUST 1995 -> bronze/macros/HOUST/year=1995/HOUST_1995.parquet  (12 filas)
# ▲ HOUST 1996 -> bronze/macros/HOUST/year=1996/HOUST_1996.parquet  (12 filas)
# ▲ HOUST 1997 -> bronze/macros/HOUST/year=1997/HOUST_1997.parquet  (12 filas)
# ▲ HOUST 1998 -> bronze/macros/HOUST/year=1998/HOUST_1998.parquet  (12 filas)
# ▲ HOUST 1999 -> bronze/macros/HOUST/year=1999/HOUST_1999.parquet  (12 filas)
# ▲ HOUST 2000 -> bronze/macros/HOUST/year=2000/HOUST_2000.parquet  (12 filas)
# ▲ HOUST 2001 -> bronze/macros/HOUST/year=2001/HOUST_2001.parquet  (12 filas)
# ▲ HOUST 2002 -> bronze/macros/HOUST/year=2002/HOUST_2002.parquet  (12 filas)
# ▲ HOUST 2003 -> bronze/macros/HOUST/year=2003/HOUST_2003.parquet  (12 filas)
# ▲ HOUST 2004 -> bronze/macros/HOUST/year=2004/HOUST_2004.parquet  (12 filas)
# ▲ HOUST 2005 -> bronze/macros/HOUST/year=2005/HOUST_2005.parquet  (12 filas)
# ▲ HOUST 2006 -> bronze/macros/HOUST/year=2006/HOUST_2006.parquet  (12 filas)
# ▲ HOUST 2007 -> bronze/macros/HOUST/year=2007/HOUST_2007.parquet  (12 filas)
# ▲ HOUST 2008 -> bronze/macros/HOUST/year=2008/HOUST_2008.parquet  (12 filas)
# ▲ HOUST 2009 -> bronze/macros/HOUST/year=2009/HOUST_2009.parquet  (12 filas)
# ▲ HOUST 2010 -> bronze/macros/HOUST/year=2010/HOUST_2010.parquet  (12 filas)
# ▲ HOUST 2011 -> bronze/macros/HOUST/year=2011/HOUST_2011.parquet  (12 filas)
# ▲ HOUST 2012 -> bronze/macros/HOUST/year=2012/HOUST_2012.parquet  (12 filas)
# ▲ HOUST 2013 -> bronze/macros/HOUST/year=2013/HOUST_2013.parquet  (12 filas)
# ▲ HOUST 2014 -> bronze/macros/HOUST/year=2014/HOUST_2014.parquet  (12 filas)
# ▲ HOUST 2015 -> bronze/macros/HOUST/year=2015/HOUST_2015.parquet  (12 filas)
# ▲ HOUST 2016 -> bronze/macros/HOUST/year=2016/HOUST_2016.parquet  (12 filas)
# ▲ HOUST 2017 -> bronze/macros/HOUST/year=2017/HOUST_2017.parquet  (12 filas)
# ▲ HOUST 2018 -> bronze/macros/HOUST/year=2018/HOUST_2018.parquet  (12 filas)
# ▲ HOUST 2019 -> bronze/macros/HOUST/year=2019/HOUST_2019.parquet  (12 filas)
# ▲ HOUST 2020 -> bronze/macros/HOUST/year=2020/HOUST_2020.parquet  (12 filas)
# ▲ HOUST 2021 -> bronze/macros/HOUST/year=2021/HOUST_2021.parquet  (12 filas)
# ▲ HOUST 2022 -> bronze/macros/HOUST/year=2022/HOUST_2022.parquet  (12 filas)
# ▲ HOUST 2023 -> bronze/macros/HOUST/year=2023/HOUST_2023.parquet  (12 filas)
# ▲ HOUST 2024 -> bronze/macros/HOUST/year=2024/HOUST_2024.parquet  (12 filas)
# ▲ HOUST 2025 -> bronze/macros/HOUST/year=2025/HOUST_2025.parquet  (6 filas)
# ▲ PERMIT 1992 -> bronze/macros/PERMIT/year=1992/PERMIT_1992.parquet  (12 filas)
# ▲ PERMIT 1993 -> bronze/macros/PERMIT/year=1993/PERMIT_1993.parquet  (12 filas)
# ▲ PERMIT 1994 -> bronze/macros/PERMIT/year=1994/PERMIT_1994.parquet  (12 filas)
# ▲ PERMIT 1995 -> bronze/macros/PERMIT/year=1995/PERMIT_1995.parquet  (12 filas)
# ▲ PERMIT 1996 -> bronze/macros/PERMIT/year=1996/PERMIT_1996.parquet  (12 filas)
# ▲ PERMIT 1997 -> bronze/macros/PERMIT/year=1997/PERMIT_1997.parquet  (12 filas)
# ▲ PERMIT 1998 -> bronze/macros/PERMIT/year=1998/PERMIT_1998.parquet  (12 filas)
# ▲ PERMIT 1999 -> bronze/macros/PERMIT/year=1999/PERMIT_1999.parquet  (12 filas)
# ▲ PERMIT 2000 -> bronze/macros/PERMIT/year=2000/PERMIT_2000.parquet  (12 filas)
# ▲ PERMIT 2001 -> bronze/macros/PERMIT/year=2001/PERMIT_2001.parquet  (12 filas)
# ▲ PERMIT 2002 -> bronze/macros/PERMIT/year=2002/PERMIT_2002.parquet  (12 filas)
# ▲ PERMIT 2003 -> bronze/macros/PERMIT/year=2003/PERMIT_2003.parquet  (12 filas)
# ▲ PERMIT 2004 -> bronze/macros/PERMIT/year=2004/PERMIT_2004.parquet  (12 filas)
# ▲ PERMIT 2005 -> bronze/macros/PERMIT/year=2005/PERMIT_2005.parquet  (12 filas)
# ▲ PERMIT 2006 -> bronze/macros/PERMIT/year=2006/PERMIT_2006.parquet  (12 filas)
# ▲ PERMIT 2007 -> bronze/macros/PERMIT/year=2007/PERMIT_2007.parquet  (12 filas)
# ▲ PERMIT 2008 -> bronze/macros/PERMIT/year=2008/PERMIT_2008.parquet  (12 filas)
# ▲ PERMIT 2009 -> bronze/macros/PERMIT/year=2009/PERMIT_2009.parquet  (12 filas)
# ▲ PERMIT 2010 -> bronze/macros/PERMIT/year=2010/PERMIT_2010.parquet  (12 filas)
# ▲ PERMIT 2011 -> bronze/macros/PERMIT/year=2011/PERMIT_2011.parquet  (12 filas)
# ▲ PERMIT 2012 -> bronze/macros/PERMIT/year=2012/PERMIT_2012.parquet  (12 filas)
# ▲ PERMIT 2013 -> bronze/macros/PERMIT/year=2013/PERMIT_2013.parquet  (12 filas)
# ▲ PERMIT 2014 -> bronze/macros/PERMIT/year=2014/PERMIT_2014.parquet  (12 filas)
# ▲ PERMIT 2015 -> bronze/macros/PERMIT/year=2015/PERMIT_2015.parquet  (12 filas)
# ▲ PERMIT 2016 -> bronze/macros/PERMIT/year=2016/PERMIT_2016.parquet  (12 filas)
# ▲ PERMIT 2017 -> bronze/macros/PERMIT/year=2017/PERMIT_2017.parquet  (12 filas)
# ▲ PERMIT 2018 -> bronze/macros/PERMIT/year=2018/PERMIT_2018.parquet  (12 filas)
# ▲ PERMIT 2019 -> bronze/macros/PERMIT/year=2019/PERMIT_2019.parquet  (12 filas)
# ▲ PERMIT 2020 -> bronze/macros/PERMIT/year=2020/PERMIT_2020.parquet  (12 filas)
# ▲ PERMIT 2021 -> bronze/macros/PERMIT/year=2021/PERMIT_2021.parquet  (12 filas)
# ▲ PERMIT 2022 -> bronze/macros/PERMIT/year=2022/PERMIT_2022.parquet  (12 filas)
# ▲ PERMIT 2023 -> bronze/macros/PERMIT/year=2023/PERMIT_2023.parquet  (12 filas)
# ▲ PERMIT 2024 -> bronze/macros/PERMIT/year=2024/PERMIT_2024.parquet  (12 filas)
# ▲ PERMIT 2025 -> bronze/macros/PERMIT/year=2025/PERMIT_2025.parquet  (6 filas)
# ▲ M2SL 1992 -> bronze/macros/M2SL/year=1992/M2SL_1992.parquet  (12 filas)
# ▲ M2SL 1993 -> bronze/macros/M2SL/year=1993/M2SL_1993.parquet  (12 filas)
# ▲ M2SL 1994 -> bronze/macros/M2SL/year=1994/M2SL_1994.parquet  (12 filas)
# ▲ M2SL 1995 -> bronze/macros/M2SL/year=1995/M2SL_1995.parquet  (12 filas)
# ▲ M2SL 1996 -> bronze/macros/M2SL/year=1996/M2SL_1996.parquet  (12 filas)
# ▲ M2SL 1997 -> bronze/macros/M2SL/year=1997/M2SL_1997.parquet  (12 filas)
# ▲ M2SL 1998 -> bronze/macros/M2SL/year=1998/M2SL_1998.parquet  (12 filas)
# ▲ M2SL 1999 -> bronze/macros/M2SL/year=1999/M2SL_1999.parquet  (12 filas)
# ▲ M2SL 2000 -> bronze/macros/M2SL/year=2000/M2SL_2000.parquet  (12 filas)
# ▲ M2SL 2001 -> bronze/macros/M2SL/year=2001/M2SL_2001.parquet  (12 filas)
# ▲ M2SL 2002 -> bronze/macros/M2SL/year=2002/M2SL_2002.parquet  (12 filas)
# ▲ M2SL 2003 -> bronze/macros/M2SL/year=2003/M2SL_2003.parquet  (12 filas)
# ▲ M2SL 2004 -> bronze/macros/M2SL/year=2004/M2SL_2004.parquet  (12 filas)
# ▲ M2SL 2005 -> bronze/macros/M2SL/year=2005/M2SL_2005.parquet  (12 filas)
# ▲ M2SL 2006 -> bronze/macros/M2SL/year=2006/M2SL_2006.parquet  (12 filas)
# ▲ M2SL 2007 -> bronze/macros/M2SL/year=2007/M2SL_2007.parquet  (12 filas)
# ▲ M2SL 2008 -> bronze/macros/M2SL/year=2008/M2SL_2008.parquet  (12 filas)
# ▲ M2SL 2009 -> bronze/macros/M2SL/year=2009/M2SL_2009.parquet  (12 filas)
# ▲ M2SL 2010 -> bronze/macros/M2SL/year=2010/M2SL_2010.parquet  (12 filas)
# ▲ M2SL 2011 -> bronze/macros/M2SL/year=2011/M2SL_2011.parquet  (12 filas)
# ▲ M2SL 2012 -> bronze/macros/M2SL/year=2012/M2SL_2012.parquet  (12 filas)
# ▲ M2SL 2013 -> bronze/macros/M2SL/year=2013/M2SL_2013.parquet  (12 filas)
# ▲ M2SL 2014 -> bronze/macros/M2SL/year=2014/M2SL_2014.parquet  (12 filas)
# ▲ M2SL 2015 -> bronze/macros/M2SL/year=2015/M2SL_2015.parquet  (12 filas)
# ▲ M2SL 2016 -> bronze/macros/M2SL/year=2016/M2SL_2016.parquet  (12 filas)
# ▲ M2SL 2017 -> bronze/macros/M2SL/year=2017/M2SL_2017.parquet  (12 filas)
# ▲ M2SL 2018 -> bronze/macros/M2SL/year=2018/M2SL_2018.parquet  (12 filas)
# ▲ M2SL 2019 -> bronze/macros/M2SL/year=2019/M2SL_2019.parquet  (12 filas)
# ▲ M2SL 2020 -> bronze/macros/M2SL/year=2020/M2SL_2020.parquet  (12 filas)
# ▲ M2SL 2021 -> bronze/macros/M2SL/year=2021/M2SL_2021.parquet  (12 filas)
# ▲ M2SL 2022 -> bronze/macros/M2SL/year=2022/M2SL_2022.parquet  (12 filas)
# ▲ M2SL 2023 -> bronze/macros/M2SL/year=2023/M2SL_2023.parquet  (12 filas)
# ▲ M2SL 2024 -> bronze/macros/M2SL/year=2024/M2SL_2024.parquet  (12 filas)
# ▲ M2SL 2025 -> bronze/macros/M2SL/year=2025/M2SL_2025.parquet  (6 filas)
# ▲ WALCL 2002 -> bronze/macros/WALCL/year=2002/WALCL_2002.parquet  (2 filas)
# ▲ WALCL 2003 -> bronze/macros/WALCL/year=2003/WALCL_2003.parquet  (53 filas)
# ▲ WALCL 2004 -> bronze/macros/WALCL/year=2004/WALCL_2004.parquet  (52 filas)
# ▲ WALCL 2005 -> bronze/macros/WALCL/year=2005/WALCL_2005.parquet  (52 filas)
# ▲ WALCL 2006 -> bronze/macros/WALCL/year=2006/WALCL_2006.parquet  (52 filas)
# ▲ WALCL 2007 -> bronze/macros/WALCL/year=2007/WALCL_2007.parquet  (52 filas)
# ▲ WALCL 2008 -> bronze/macros/WALCL/year=2008/WALCL_2008.parquet  (53 filas)
# ▲ WALCL 2009 -> bronze/macros/WALCL/year=2009/WALCL_2009.parquet  (52 filas)
# ▲ WALCL 2010 -> bronze/macros/WALCL/year=2010/WALCL_2010.parquet  (52 filas)
# ▲ WALCL 2011 -> bronze/macros/WALCL/year=2011/WALCL_2011.parquet  (52 filas)
# ▲ WALCL 2012 -> bronze/macros/WALCL/year=2012/WALCL_2012.parquet  (52 filas)
# ▲ WALCL 2013 -> bronze/macros/WALCL/year=2013/WALCL_2013.parquet  (52 filas)
# ▲ WALCL 2014 -> bronze/macros/WALCL/year=2014/WALCL_2014.parquet  (53 filas)
# ▲ WALCL 2015 -> bronze/macros/WALCL/year=2015/WALCL_2015.parquet  (52 filas)
# ▲ WALCL 2016 -> bronze/macros/WALCL/year=2016/WALCL_2016.parquet  (52 filas)
# ▲ WALCL 2017 -> bronze/macros/WALCL/year=2017/WALCL_2017.parquet  (52 filas)
# ▲ WALCL 2018 -> bronze/macros/WALCL/year=2018/WALCL_2018.parquet  (52 filas)
# ▲ WALCL 2019 -> bronze/macros/WALCL/year=2019/WALCL_2019.parquet  (52 filas)
# ▲ WALCL 2020 -> bronze/macros/WALCL/year=2020/WALCL_2020.parquet  (53 filas)
# ▲ WALCL 2021 -> bronze/macros/WALCL/year=2021/WALCL_2021.parquet  (52 filas)
# ▲ WALCL 2022 -> bronze/macros/WALCL/year=2022/WALCL_2022.parquet  (52 filas)
# ▲ WALCL 2023 -> bronze/macros/WALCL/year=2023/WALCL_2023.parquet  (52 filas)
# ▲ WALCL 2024 -> bronze/macros/WALCL/year=2024/WALCL_2024.parquet  (52 filas)
# ▲ WALCL 2025 -> bronze/macros/WALCL/year=2025/WALCL_2025.parquet  (30 filas)

# %%
# ================================================================
# 3.1 Log de Ingesta
# ================================================================
LOG_DIR = "logs"; os.makedirs(LOG_DIR, exist_ok=True)
logging.basicConfig(
    filename=f"{LOG_DIR}/ingest_macros_{dt.date.today()}.log",
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
)
for name, mb in sizes.items():
    logging.info(f"{name}: {mb} MB guardado en RAW")
logging.info("Cobertura: %s", coverage.to_dict())

# %% [markdown]
# ## 4. Carga incremental de último año cargado

# %%
# ================================================================
# 4.1 Carga Incremental (Para ejecuciones programadas)
# ================================================================

# ----------------------------------------------------------------
# Detecta la última fecha cargada en Bronze y descarga sólo las observaciones
# nuevas desde esa fecha +1 hasta hoy.  Idempotente: si no hay datos nuevos,
# la serie se salta.
# ----------------------------------------------------------------
svc = _client()

"""Devuelve la última fecha disponible en Bronze para la serie dada."""
def last_date(series: str):
    d = svc.get_directory_client(CONTAINER, f"{BRONZE_PREFIX}/{series}")
    years = sorted(int(p.name.split('=')[1]) for p in d.get_paths() if p.is_directory)
    if not years: return None
    latest_year = years[-1]
    latest_file = next(p.name for p in d.get_paths()
                       if (not p.is_directory) and f"year={latest_year}/" in p.name)
    raw = svc.get_file_client(CONTAINER, latest_file).download_file().readall()
    return pd.read_parquet(io.BytesIO(raw), columns=["date"])["date"].max().date()

# ► Descarga incremental por serie -------------------------------
today = dt.date.today()
for code in SERIES:
    ld = last_date(code)
    start = (ld + dt.timedelta(days=1)) if ld else pd.to_datetime(START_DATE).date()
    if start > today:
        print(code, "al día"); continue

    # Descarga desde la fecha 'start' hasta hoy ------------------
    df_new = fred.get_series(code, observation_start=start, observation_end=today).to_frame("value")
    if df_new.empty:
        continue
    
    # Normaliza y añade metadatos --------------------------------
    df_new = (df_new.reset_index()
                     .rename(columns={"index": "date"})
                     .assign(series=code,
                             year=lambda x: x["date"].dt.year,
                             ingest_ts=pd.Timestamp.utcnow().isoformat(),
                             source="FRED"))

    # Sube particiones anuales nuevas o sobrescribe existente ----
    for yr, part in df_new.groupby("year"):
        buf = io.BytesIO(); part.to_parquet(buf, index=False); buf.seek(0)
        remote = f"{BRONZE_PREFIX}/{code}/year={yr}/{code}_{yr}.parquet"
        upload_bytes(remote, buf.read())
        print(f"▲ {code} {yr} +{len(part)} obs")
print("\nProceso completado ✅")
# Out:
# ▲ FEDFUNDS 2025 +1 obs
# ▲ CPIAUCSL 2025 +1 obs
# ▲ UNRATE 2025 +1 obs
# ▲ GDP 2025 +1 obs
# ▲ INDPRO 2025 +1 obs
# ▲ PAYEMS 2025 +1 obs
# ▲ UMCSENT 2025 +1 obs
# ▲ HOUST 2025 +1 obs
# ▲ PERMIT 2025 +1 obs
# ▲ M2SL 2025 +1 obs
#
# Proceso completado ✅
