# %% [markdown]
# # Ingesta histórica + carga incremental de índices bursátiles hacia Azure Data Lake

# %% [markdown]
# **Descripcion:**<br>
# El presente script de Python descarga precios diarios de los principales índices bursátiles utilizando la librería de yfinance (1992-Actualidad), los normaliza y valida, guardando en formato Parquet local y replicándolos en Azure Data Lake Storage Gen2, incluyendo controles de calidad, logs de ingesta y lógica incremental.<br>
#
# **Objetivos**:<br>
# -Automatizar la extracción de datos desde la API de Yahoo Finance.<br>
# -Estandarizar el esquema.<br>
# -Persistir en formato eficiente (Parquet) tanto localmente como en ADLS, habilitando compresión y lectura columnar.<br>
# -Garantizar la calidad inicial mediante chequeos de cobertura, nulos y duplicados.<br>
# -Implementar carga incremental idempotente, particionando por year=YYYY.<br>
# -Registrar la actividad (log de ingesta y tamaños de archivo).

# %% [markdown]
# ## 1. Configuración básica y librerías y Parámetros globales del pipeline

# %%
# ================================================================
# 1.1 Configuración básica y librerías
# ================================================================
import os
from datetime import date

import pandas as pd
import yfinance as yf

# Mostrar todas las columnas al imprimir DataFrames
pd.set_option("display.max_columns", None)

# %%
# ================================================================
# 1.2 · Parámetros globales del pipeline
# ================================================================
TICKERS = {
    "SP500": "^GSPC",
    "DJIA": "^DJI",
    "NASDAQ": "^IXIC",
    "RUSSELL2000": "^RUT",
    "WILSHIRE5000": "^W5000",
}

START_DATE = "1992-01-01"   # Fecha inicial fija del histórico
END_DATE   = date.today().isoformat()  # Fecha final dinámica (hoy)
DATA_DIR   = "data/raw/indices"      # Carpeta local para la zona RAW
os.makedirs(DATA_DIR, exist_ok=True) # Crea la carpeta si no existe

# %% [markdown]
# ## 2. Función de descarga y normalización (RAW)

# %%
# ================================================================
# 2.1 · Descarga de precios díarios
# ================================================================
def download_index(ticker: str, name: str) -> pd.DataFrame:
    """
    Descarga precios diarios y deja columnas planas:
    open, high, low, close, adj_close, volume, ticker
    """

    # --- Descarga desde la API de Yahoo Finance ------------------
    df = yf.download(
        ticker,
        start=START_DATE,
        end=END_DATE,
        interval="1d",
        auto_adjust=True, # Ajusta historical splits/dividends en close
        progress=False    # Suprime barra de progreso
    )

    # --- 1· Aplanar encabezados ----------------------------------
    if isinstance(df.columns, pd.MultiIndex):
        # Ejemplo actual: MultiIndex( ('open','^GSPC'), … )
        df.columns = df.columns.get_level_values(0)        # → open, high, low…
    else:
        # A veces vienen tuplas sueltas: ('^GSPC', 'Open')
        df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]

    # --- 2· Normalizar nombres -----------------------------------
    df.columns = [str(c).lower().replace(" ", "_") for c in df.columns]

    # --- 3· Añadir metadatos y retornar --------------------------
    df.index.name = "date"   # índice → fecha
    df["ticker"] = name      # identificador de mercado
    return df

# %% [markdown]
# ## 3. Ingesta inicial (histórico completo) -> Azure Data Lake Storage y Chequeos rápidos de calidad

# %%
# ================================================================
# 3.1 Muestreo inicial del tipo de datos
# ================================================================
test = download_index("^GSPC", "SP500")
print(test.columns)
# Out:
# Index(['close', 'high', 'low', 'open', 'volume', 'ticker'], dtype='object')

# %%
# ================================================================
# 3.2 Ingesta inicial (histórico completo RAW → ADLS)
# ================================================================

from utils_adls import upload_bytes
frames = []  # Almacena los DataFrames en memoria para EDA posterior
for name, ticker in TICKERS.items():
    print(f"⏬ {name} ({ticker})")
    df_i = download_index(ticker, name)
    print(f"   {df_i.shape[0]} filas desde {df_i.index.min().date()}")

    # 1) Guarda archivo Parquet local (zona RAW)
    local_file = f"{DATA_DIR}/{name}.parquet"
    df_i.to_parquet(local_file)

    # 2) Replica archivo RAW en Azure Data Lake Storage Gen2
    remote_raw = f"raw/indices/{name}.parquet"
    with open(local_file, "rb") as f:
        upload_bytes(remote_raw, f.read())     # Sobrescribe si ya existe

    frames.append(df_i)
# Out:
# ⏬ SP500 (^GSPC)
#    8451 filas desde 1992-01-02
# ⏬ DJIA (^DJI)
#    8451 filas desde 1992-01-02
# ⏬ NASDAQ (^IXIC)
#    8451 filas desde 1992-01-02
# ⏬ RUSSELL2000 (^RUT)
#    8451 filas desde 1992-01-02
# ⏬ WILSHIRE5000 (^W5000)
#    8444 filas desde 1992-01-02

# %% [markdown]
# ## 4. Chequeos rápidos de calidad

# %%
# ================================================================
# 4.1 Combinar todos los Parquet para análisis (Quick EDA)
# ================================================================
parquet_paths = [f"{DATA_DIR}/{name}.parquet" for name in TICKERS]
market_df = pd.concat([pd.read_parquet(p) for p in parquet_paths])
market_df.tail()
# Out:
#                    close          high           low          open  volume  \
# date
# 2025-07-21  62981.320312  63327.730469  62947.539062  62947.539062       0
# 2025-07-22  63076.570312  63149.789062  62757.300781  62981.320312       0
# 2025-07-23  63586.968750  63594.929688  63076.570312  63076.570312       0
# 2025-07-24  63560.398438  63745.820312  63559.718750  63586.968750       0
# 2025-07-25  63834.250000  63898.480469  63560.398438  63560.398438       0
#
#                   ticker
# date
# 2025-07-21  WILSHIRE5000
# 2025-07-22  WILSHIRE5000
# 2025-07-23  WILSHIRE5000
# 2025-07-24  WILSHIRE5000
# 2025-07-25  WILSHIRE5000

# %%
# ================================================================
# 4.2 Cobertura temporal
# ================================================================
coverage = (
    market_df.reset_index()
             .groupby("ticker")["date"]
             .agg(["min", "max", "count"])
             .rename(columns={"min": "fecha_min", "max": "fecha_max", "count": "num_dias"})
)
print("\nCobertura temporal por índice:\n", coverage)
# Out:
# Cobertura temporal por índice:
#                fecha_min  fecha_max  num_dias
# ticker
# DJIA         1992-01-02 2025-07-25      8451
# NASDAQ       1992-01-02 2025-07-25      8451
# RUSSELL2000  1992-01-02 2025-07-25      8451
# SP500        1992-01-02 2025-07-25      8451
# WILSHIRE5000 1992-01-02 2025-07-25      8444

# %%
# ================================================================
# 4.3 Valores nulos
# ================================================================
nulls_pct = (market_df.isna().mean() * 100).round(3)
print("Porcentaje de NaNs por columna:\n", nulls_pct)
# Out:
# Porcentaje de NaNs por columna:
#  close     0.0
# high      0.0
# low       0.0
# open      0.0
# volume    0.0
# ticker    0.0
# dtype: float64

# %%
# ================================================================
# 4.4 Duplicados fecha‑ticker
# ================================================================
dupes = (
    market_df.reset_index()
             .duplicated(subset=["date", "ticker"])
             .sum()
)
print("Duplicados:", dupes)
assert dupes == 0, "Hay fechas duplicadas — revisa la descarga."
# Out:
# Duplicados: 0

# %% [markdown]
# ## 5. Verificación de tamaños de archivo Parquet y Logging de ingesta

# %%
# ================================================================
# 5.1 Verificación de tamaños de archivo Parquet
# ================================================================
import pathlib

filesize_mb = {
    p.name: round(p.stat().st_size / 1_048_576, 2)   # bytes → MB
    for p in pathlib.Path(DATA_DIR).glob("*.parquet")
}
print("Tamaños de archivo (MB):", filesize_mb)
# Out:
# Tamaños de archivo (MB): {'DJIA.parquet': 0.37, 'NASDAQ.parquet': 0.38, 'RUSSELL2000.parquet': 0.37, 'SP500.parquet': 0.38, 'WILSHIRE5000.parquet': 0.32}

# %%
# ================================================================
# 5.2 Logging de ingesta
# ================================================================
import logging, datetime as dt
LOG_DIR = "logs"; os.makedirs(LOG_DIR, exist_ok=True)
logging.basicConfig(
    filename=f"{LOG_DIR}/ingest_indices_{dt.date.today()}.log",
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
)

for name, path in filesize_mb.items():
    logging.info(f"{name}: {path} MB guardado en {DATA_DIR}")
logging.info("Chequeos — duplicados: %s, NaNs: %s", dupes, nulls_pct.to_dict())

# %% [markdown]
# # Etapa Bronze

# %% [markdown]
# ## 6. Prueba de escritura en Bronze

# %%
# ================================================================
# 6.1 Prueba de escritura
# ================================================================
from utils_adls import upload_bytes
upload_bytes(
    "bronze/test.txt",
    b"hola mundo",          # Contenido arbitrario
    content_type="text/plain"
)
print("✔ Archivo de prueba creado/sobrescrito sin error en Bronze")
# Out:
# ✔ Archivo de prueba creado/sobrescrito sin error en Bronze

# %% [markdown]
# ## 7. Carga incremental de último año cargado

# %%
# ================================================================
# 7.1 Obteniendo de último año cargado (para incremental)
# ================================================================
from azure.core.exceptions import ResourceNotFoundError
from utils_adls import _client, CONTAINER
BRONZE_ADLS_PREFIX = "bronze/indices"
TICKERS_LIST = list(TICKERS.keys())

svc = _client()           # cliente ADLS

ultimo_anio = {}          # {ticker: último año encontrado}

for tk in TICKERS_LIST:
    dir_path = f"{BRONZE_ADLS_PREFIX}/{tk}"
    dir_client = svc.get_directory_client(CONTAINER, dir_path)

    try:
        years = [
            int(p.name.split("=")[1])
            for p in dir_client.get_paths() if p.is_directory
        ]
        ultimo_anio[tk] = max(years) if years else None
    except ResourceNotFoundError:
        ultimo_anio[tk] = 1992

print("\nÚltimo año cargado por índice:", ultimo_anio)
# Out:
# Último año cargado por índice: {'SP500': 1992, 'DJIA': 1992, 'NASDAQ': 1992, 'RUSSELL2000': 1992, 'WILSHIRE5000': 1992}

# %%
# ================================================================
# 7.2 Carga incremental (RAW → Bronze por año)
# ================================================================
import os, pandas as pd, yfinance as yf, io, datetime as dt
from utils_adls import _client, upload_bytes, CONTAINER

def max_date_for(ticker: str):
    """Devuelve la fecha máxima almacenada para un ticker en Bronze."""
    
    dir_client = svc.get_directory_client(
        CONTAINER,
        f"{BRONZE_ADLS_PREFIX}/{ticker}"    # ← ya apunta al índice
    )

    try:
        # 1) Identifica los directorios year=YYYY
        years = sorted(
            int(p.name.split("=")[1])
            for p in dir_client.get_paths() if p.is_directory
        )
        if not years:
            return None
        latest_year = years[-1]
    
        # 2) Obtiene el primer fichero Parquet dentro del último año
        latest_file = next(
            p.name for p in dir_client.get_paths()            # ← ¡sin path extra!
            if (not p.is_directory) and f"year={latest_year}/" in p.name
        )
    
        # 3) Descarga y lee sólo la columna fecha
        file_client = svc.get_file_client(CONTAINER, latest_file)
        raw = file_client.download_file().readall()
    
        df = pd.read_parquet(io.BytesIO(raw), columns=["date"])
        return pd.to_datetime(df["date"]).max().date()
    except ResourceNotFoundError:
        return None
# ---------- Loop principal por ticker ----------------------------
today = dt.date.today()
for name, y_ticker in TICKERS.items():
    last_dt = max_date_for(name)
    start_dt = last_dt + dt.timedelta(days=1) if last_dt else dt.date(1992,1,1)

    if start_dt > today:
        print(f"{name}: ya actualizado hasta {last_dt}")
        continue

    print(f"{name}: descargando desde {start_dt} hasta {today}")
    df_new = yf.download(
        y_ticker,
        start=start_dt.isoformat(),
        end=today.isoformat(),
        interval="1d",
        auto_adjust=True,
        progress=False,
    )

    if df_new.empty:
        print(f"{name}: nada nuevo")
        continue

    # --- Normaliza columnas nuevamente ----------------------------
    if isinstance(df_new.columns, pd.MultiIndex):
        df_new.columns = df_new.columns.get_level_values(0)
    df_new.columns = [c.lower().replace(" ", "_") for c in df_new.columns]
    df_new.index.name = "date"
    df_new["ticker"] = name

     # Añade columna de partición por año y reinicia índice
    df_new = df_new.reset_index()
    df_new["year"] = pd.to_datetime(df_new["date"]).dt.year

    # --- Sube Parquet por cada año --------------------------------
    for yr, group in df_new.groupby("year"):
        buf = io.BytesIO()
        group.to_parquet(buf, index=False, engine="pyarrow")
        buf.seek(0)

        remote = f"{BRONZE_ADLS_PREFIX}/{name}/year={yr}/{name}_{yr}.parquet"
        upload_bytes(remote, buf.read())        # overwrite=True dentro de la función
        print(f"▲ {name} {yr} -> {remote}   ({len(group)} filas)")

print("\nProceso completado ✅")
# Out:
# SP500: descargando desde 1992-01-01 hasta 2025-07-28
# ▲ SP500 1992 -> bronze/indices/SP500/year=1992/SP500_1992.parquet   (254 filas)
# ▲ SP500 1993 -> bronze/indices/SP500/year=1993/SP500_1993.parquet   (253 filas)
# ▲ SP500 1994 -> bronze/indices/SP500/year=1994/SP500_1994.parquet   (252 filas)
# ▲ SP500 1995 -> bronze/indices/SP500/year=1995/SP500_1995.parquet   (252 filas)
# ▲ SP500 1996 -> bronze/indices/SP500/year=1996/SP500_1996.parquet   (254 filas)
# ▲ SP500 1997 -> bronze/indices/SP500/year=1997/SP500_1997.parquet   (253 filas)
# ▲ SP500 1998 -> bronze/indices/SP500/year=1998/SP500_1998.parquet   (252 filas)
# ▲ SP500 1999 -> bronze/indices/SP500/year=1999/SP500_1999.parquet   (252 filas)
# ▲ SP500 2000 -> bronze/indices/SP500/year=2000/SP500_2000.parquet   (252 filas)
# ▲ SP500 2001 -> bronze/indices/SP500/year=2001/SP500_2001.parquet   (248 filas)
# ▲ SP500 2002 -> bronze/indices/SP500/year=2002/SP500_2002.parquet   (252 filas)
# ▲ SP500 2003 -> bronze/indices/SP500/year=2003/SP500_2003.parquet   (252 filas)
# ▲ SP500 2004 -> bronze/indices/SP500/year=2004/SP500_2004.parquet   (252 filas)
# ▲ SP500 2005 -> bronze/indices/SP500/year=2005/SP500_2005.parquet   (252 filas)
# ▲ SP500 2006 -> bronze/indices/SP500/year=2006/SP500_2006.parquet   (251 filas)
# ▲ SP500 2007 -> bronze/indices/SP500/year=2007/SP500_2007.parquet   (251 filas)
# ▲ SP500 2008 -> bronze/indices/SP500/year=2008/SP500_2008.parquet   (253 filas)
# ▲ SP500 2009 -> bronze/indices/SP500/year=2009/SP500_2009.parquet   (252 filas)
# ▲ SP500 2010 -> bronze/indices/SP500/year=2010/SP500_2010.parquet   (252 filas)
# ▲ SP500 2011 -> bronze/indices/SP500/year=2011/SP500_2011.parquet   (252 filas)
# ▲ SP500 2012 -> bronze/indices/SP500/year=2012/SP500_2012.parquet   (250 filas)
# ▲ SP500 2013 -> bronze/indices/SP500/year=2013/SP500_2013.parquet   (252 filas)
# ▲ SP500 2014 -> bronze/indices/SP500/year=2014/SP500_2014.parquet   (252 filas)
# ▲ SP500 2015 -> bronze/indices/SP500/year=2015/SP500_2015.parquet   (252 filas)
# ▲ SP500 2016 -> bronze/indices/SP500/year=2016/SP500_2016.parquet   (252 filas)
# ▲ SP500 2017 -> bronze/indices/SP500/year=2017/SP500_2017.parquet   (251 filas)
# ▲ SP500 2018 -> bronze/indices/SP500/year=2018/SP500_2018.parquet   (251 filas)
# ▲ SP500 2019 -> bronze/indices/SP500/year=2019/SP500_2019.parquet   (252 filas)
# ▲ SP500 2020 -> bronze/indices/SP500/year=2020/SP500_2020.parquet   (253 filas)
# ▲ SP500 2021 -> bronze/indices/SP500/year=2021/SP500_2021.parquet   (252 filas)
# ▲ SP500 2022 -> bronze/indices/SP500/year=2022/SP500_2022.parquet   (251 filas)
# ▲ SP500 2023 -> bronze/indices/SP500/year=2023/SP500_2023.parquet   (250 filas)
# ▲ SP500 2024 -> bronze/indices/SP500/year=2024/SP500_2024.parquet   (252 filas)
# ▲ SP500 2025 -> bronze/indices/SP500/year=2025/SP500_2025.parquet   (140 filas)
# DJIA: descargando desde 1992-01-01 hasta 2025-07-28
# ▲ DJIA 1992 -> bronze/indices/DJIA/year=1992/DJIA_1992.parquet   (254 filas)
# ▲ DJIA 1993 -> bronze/indices/DJIA/year=1993/DJIA_1993.parquet   (253 filas)
# ▲ DJIA 1994 -> bronze/indices/DJIA/year=1994/DJIA_1994.parquet   (252 filas)
# ▲ DJIA 1995 -> bronze/indices/DJIA/year=1995/DJIA_1995.parquet   (252 filas)
# ▲ DJIA 1996 -> bronze/indices/DJIA/year=1996/DJIA_1996.parquet   (254 filas)
# ▲ DJIA 1997 -> bronze/indices/DJIA/year=1997/DJIA_1997.parquet   (253 filas)
# ▲ DJIA 1998 -> bronze/indices/DJIA/year=1998/DJIA_1998.parquet   (252 filas)
# ▲ DJIA 1999 -> bronze/indices/DJIA/year=1999/DJIA_1999.parquet   (252 filas)
# ▲ DJIA 2000 -> bronze/indices/DJIA/year=2000/DJIA_2000.parquet   (252 filas)
# ▲ DJIA 2001 -> bronze/indices/DJIA/year=2001/DJIA_2001.parquet   (248 filas)
# ▲ DJIA 2002 -> bronze/indices/DJIA/year=2002/DJIA_2002.parquet   (252 filas)
# ▲ DJIA 2003 -> bronze/indices/DJIA/year=2003/DJIA_2003.parquet   (252 filas)
# ▲ DJIA 2004 -> bronze/indices/DJIA/year=2004/DJIA_2004.parquet   (252 filas)
# ▲ DJIA 2005 -> bronze/indices/DJIA/year=2005/DJIA_2005.parquet   (252 filas)
# ▲ DJIA 2006 -> bronze/indices/DJIA/year=2006/DJIA_2006.parquet   (251 filas)
# ▲ DJIA 2007 -> bronze/indices/DJIA/year=2007/DJIA_2007.parquet   (251 filas)
# ▲ DJIA 2008 -> bronze/indices/DJIA/year=2008/DJIA_2008.parquet   (253 filas)
# ▲ DJIA 2009 -> bronze/indices/DJIA/year=2009/DJIA_2009.parquet   (252 filas)
# ▲ DJIA 2010 -> bronze/indices/DJIA/year=2010/DJIA_2010.parquet   (252 filas)
# ▲ DJIA 2011 -> bronze/indices/DJIA/year=2011/DJIA_2011.parquet   (252 filas)
# ▲ DJIA 2012 -> bronze/indices/DJIA/year=2012/DJIA_2012.parquet   (250 filas)
# ▲ DJIA 2013 -> bronze/indices/DJIA/year=2013/DJIA_2013.parquet   (252 filas)
# ▲ DJIA 2014 -> bronze/indices/DJIA/year=2014/DJIA_2014.parquet   (252 filas)
# ▲ DJIA 2015 -> bronze/indices/DJIA/year=2015/DJIA_2015.parquet   (252 filas)
# ▲ DJIA 2016 -> bronze/indices/DJIA/year=2016/DJIA_2016.parquet   (252 filas)
# ▲ DJIA 2017 -> bronze/indices/DJIA/year=2017/DJIA_2017.parquet   (251 filas)
# ▲ DJIA 2018 -> bronze/indices/DJIA/year=2018/DJIA_2018.parquet   (251 filas)
# ▲ DJIA 2019 -> bronze/indices/DJIA/year=2019/DJIA_2019.parquet   (252 filas)
# ▲ DJIA 2020 -> bronze/indices/DJIA/year=2020/DJIA_2020.parquet   (253 filas)
# ▲ DJIA 2021 -> bronze/indices/DJIA/year=2021/DJIA_2021.parquet   (252 filas)
# ▲ DJIA 2022 -> bronze/indices/DJIA/year=2022/DJIA_2022.parquet   (251 filas)
# ▲ DJIA 2023 -> bronze/indices/DJIA/year=2023/DJIA_2023.parquet   (250 filas)
# ▲ DJIA 2024 -> bronze/indices/DJIA/year=2024/DJIA_2024.parquet   (252 filas)
# ▲ DJIA 2025 -> bronze/indices/DJIA/year=2025/DJIA_2025.parquet   (140 filas)
# NASDAQ: descargando desde 1992-01-01 hasta 2025-07-28
# ▲ NASDAQ 1992 -> bronze/indices/NASDAQ/year=1992/NASDAQ_1992.parquet   (254 filas)
# ▲ NASDAQ 1993 -> bronze/indices/NASDAQ/year=1993/NASDAQ_1993.parquet   (253 filas)
# ▲ NASDAQ 1994 -> bronze/indices/NASDAQ/year=1994/NASDAQ_1994.parquet   (252 filas)
# ▲ NASDAQ 1995 -> bronze/indices/NASDAQ/year=1995/NASDAQ_1995.parquet   (252 filas)
# ▲ NASDAQ 1996 -> bronze/indices/NASDAQ/year=1996/NASDAQ_1996.parquet   (254 filas)
# ▲ NASDAQ 1997 -> bronze/indices/NASDAQ/year=1997/NASDAQ_1997.parquet   (253 filas)
# ▲ NASDAQ 1998 -> bronze/indices/NASDAQ/year=1998/NASDAQ_1998.parquet   (252 filas)
# ▲ NASDAQ 1999 -> bronze/indices/NASDAQ/year=1999/NASDAQ_1999.parquet   (252 filas)
# ▲ NASDAQ 2000 -> bronze/indices/NASDAQ/year=2000/NASDAQ_2000.parquet   (252 filas)
# ▲ NASDAQ 2001 -> bronze/indices/NASDAQ/year=2001/NASDAQ_2001.parquet   (248 filas)
# ▲ NASDAQ 2002 -> bronze/indices/NASDAQ/year=2002/NASDAQ_2002.parquet   (252 filas)
# ▲ NASDAQ 2003 -> bronze/indices/NASDAQ/year=2003/NASDAQ_2003.parquet   (252 filas)
# ▲ NASDAQ 2004 -> bronze/indices/NASDAQ/year=2004/NASDAQ_2004.parquet   (252 filas)
# ▲ NASDAQ 2005 -> bronze/indices/NASDAQ/year=2005/NASDAQ_2005.parquet   (252 filas)
# ▲ NASDAQ 2006 -> bronze/indices/NASDAQ/year=2006/NASDAQ_2006.parquet   (251 filas)
# ▲ NASDAQ 2007 -> bronze/indices/NASDAQ/year=2007/NASDAQ_2007.parquet   (251 filas)
# ▲ NASDAQ 2008 -> bronze/indices/NASDAQ/year=2008/NASDAQ_2008.parquet   (253 filas)
# ▲ NASDAQ 2009 -> bronze/indices/NASDAQ/year=2009/NASDAQ_2009.parquet   (252 filas)
# ▲ NASDAQ 2010 -> bronze/indices/NASDAQ/year=2010/NASDAQ_2010.parquet   (252 filas)
# ▲ NASDAQ 2011 -> bronze/indices/NASDAQ/year=2011/NASDAQ_2011.parquet   (252 filas)
# ▲ NASDAQ 2012 -> bronze/indices/NASDAQ/year=2012/NASDAQ_2012.parquet   (250 filas)
# ▲ NASDAQ 2013 -> bronze/indices/NASDAQ/year=2013/NASDAQ_2013.parquet   (252 filas)
# ▲ NASDAQ 2014 -> bronze/indices/NASDAQ/year=2014/NASDAQ_2014.parquet   (252 filas)
# ▲ NASDAQ 2015 -> bronze/indices/NASDAQ/year=2015/NASDAQ_2015.parquet   (252 filas)
# ▲ NASDAQ 2016 -> bronze/indices/NASDAQ/year=2016/NASDAQ_2016.parquet   (252 filas)
# ▲ NASDAQ 2017 -> bronze/indices/NASDAQ/year=2017/NASDAQ_2017.parquet   (251 filas)
# ▲ NASDAQ 2018 -> bronze/indices/NASDAQ/year=2018/NASDAQ_2018.parquet   (251 filas)
# ▲ NASDAQ 2019 -> bronze/indices/NASDAQ/year=2019/NASDAQ_2019.parquet   (252 filas)
# ▲ NASDAQ 2020 -> bronze/indices/NASDAQ/year=2020/NASDAQ_2020.parquet   (253 filas)
# ▲ NASDAQ 2021 -> bronze/indices/NASDAQ/year=2021/NASDAQ_2021.parquet   (252 filas)
# ▲ NASDAQ 2022 -> bronze/indices/NASDAQ/year=2022/NASDAQ_2022.parquet   (251 filas)
# ▲ WILSHIRE5000 2003 -> bronze/indices/WILSHIRE5000/year=2003/WILSHIRE5000_2003.parquet   (252 filas)
# ▲ WILSHIRE5000 2004 -> bronze/indices/WILSHIRE5000/year=2004/WILSHIRE5000_2004.parquet   (252 filas)
# ▲ WILSHIRE5000 2005 -> bronze/indices/WILSHIRE5000/year=2005/WILSHIRE5000_2005.parquet   (252 filas)
# ▲ WILSHIRE5000 2006 -> bronze/indices/WILSHIRE5000/year=2006/WILSHIRE5000_2006.parquet   (251 filas)
# ▲ WILSHIRE5000 2007 -> bronze/indices/WILSHIRE5000/year=2007/WILSHIRE5000_2007.parquet   (251 filas)
# ▲ WILSHIRE5000 2008 -> bronze/indices/WILSHIRE5000/year=2008/WILSHIRE5000_2008.parquet   (253 filas)
# ▲ WILSHIRE5000 2009 -> bronze/indices/WILSHIRE5000/year=2009/WILSHIRE5000_2009.parquet   (252 filas)
# ▲ WILSHIRE5000 2010 -> bronze/indices/WILSHIRE5000/year=2010/WILSHIRE5000_2010.parquet   (252 filas)
# ▲ WILSHIRE5000 2011 -> bronze/indices/WILSHIRE5000/year=2011/WILSHIRE5000_2011.parquet   (252 filas)
# ▲ WILSHIRE5000 2012 -> bronze/indices/WILSHIRE5000/year=2012/WILSHIRE5000_2012.parquet   (250 filas)
# ▲ WILSHIRE5000 2013 -> bronze/indices/WILSHIRE5000/year=2013/WILSHIRE5000_2013.parquet   (252 filas)
# ▲ WILSHIRE5000 2014 -> bronze/indices/WILSHIRE5000/year=2014/WILSHIRE5000_2014.parquet   (252 filas)
# ▲ WILSHIRE5000 2015 -> bronze/indices/WILSHIRE5000/year=2015/WILSHIRE5000_2015.parquet   (252 filas)
# ▲ WILSHIRE5000 2016 -> bronze/indices/WILSHIRE5000/year=2016/WILSHIRE5000_2016.parquet   (246 filas)
# ▲ WILSHIRE5000 2017 -> bronze/indices/WILSHIRE5000/year=2017/WILSHIRE5000_2017.parquet   (251 filas)
# ▲ WILSHIRE5000 2018 -> bronze/indices/WILSHIRE5000/year=2018/WILSHIRE5000_2018.parquet   (251 filas)
# ▲ WILSHIRE5000 2019 -> bronze/indices/WILSHIRE5000/year=2019/WILSHIRE5000_2019.parquet   (252 filas)
# ▲ WILSHIRE5000 2020 -> bronze/indices/WILSHIRE5000/year=2020/WILSHIRE5000_2020.parquet   (253 filas)
# ▲ WILSHIRE5000 2021 -> bronze/indices/WILSHIRE5000/year=2021/WILSHIRE5000_2021.parquet   (252 filas)
# ▲ WILSHIRE5000 2022 -> bronze/indices/WILSHIRE5000/year=2022/WILSHIRE5000_2022.parquet   (251 filas)
# ▲ WILSHIRE5000 2023 -> bronze/indices/WILSHIRE5000/year=2023/WILSHIRE5000_2023.parquet   (249 filas)
# ▲ WILSHIRE5000 2024 -> bronze/indices/WILSHIRE5000/year=2024/WILSHIRE5000_2024.parquet   (252 filas)
# ▲ WILSHIRE5000 2025 -> bronze/indices/WILSHIRE5000/year=2025/WILSHIRE5000_2025.parquet   (140 filas)
#
# Proceso completado ✅
